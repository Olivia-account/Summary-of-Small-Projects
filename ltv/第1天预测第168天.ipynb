# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torch
import torch.utils.data as Data
data = pd.read_csv('test3.csv', encoding='gbk')

# %%
dataX = []  # 属性
dataY = []  # 标签

for index, rows in data.iterrows():
    temp_data = [rows['pay_num'], rows['payment_orders'], rows['refund_orders'], rows['cancel_orders'],
                 rows['income'], rows['refund_income'], rows['actual_orders'], rows['续费率'], rows['实际收入'],
                 rows['保留率'], rows['ltv']]

    if int(rows['week']) == 0:
        dataX.append(temp_data)

    if int(rows['week']) == 168:
        dataY.append(temp_data)

# %%
# 将"order_dt"列转换为日期类型
data['order_dt'] = pd.to_datetime(data['order_dt'])

# 创建条件来选择在指定日期范围内的数据
start_date = pd.to_datetime("2022-09-01")
end_date = pd.to_datetime("2022-09-30")
mask_train = (data['order_dt'] >= start_date) & (data['order_dt'] <= end_date)
mask_test = (~(data['order_dt'] >= start_date) & (data['order_dt'] <= end_date))

test1 = data[mask_test]

# %%
dataX1 = []  # 测试属性
dataY1 = []  # 测试标签
tempX = []  # 储存某个历史第0天数据
tempY = []  # 储存某个未来第1到168天数据

for index, rows in test1.iterrows():
    temp_data = [rows['pay_num'], rows['payment_orders'], rows['refund_orders'], rows['cancel_orders'],
                 rows['income'], rows['refund_income'], rows['actual_orders'], rows['续费率'], rows['实际收入'],
                 rows['保留率'], rows['ltv']]

    if int(rows['week']) == 0:
        dataX1.append(temp_data)

    if int(rows['week']) == 168:
        dataY1.append(temp_data)

# %%
dataX=torch.tensor(dataX)#列表转Tensor
dataY=torch.tensor(dataY)#列表转Tensor
 
dataset=Data.TensorDataset(dataX,dataY)
train_size=int(0.8*len(dataset))
test_size=len(dataset)-train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])#以8:2比例划分训练集和测试集
 
train_loader = Data.DataLoader(
            dataset=train_dataset,
            batch_size=500,
            shuffle=True
        )
test_loader = Data.DataLoader(
            dataset=test_dataset,
            batch_size=500,
            shuffle=False
        )

# %%
from torch.nn import LSTM,Module,Linear
class MyModel(Module):
    def __init__(self):
        super(MyModel,self).__init__()
        self.lstm=LSTM(input_size=11,hidden_size=11,num_layers=3,batch_first=True)
        self.linear=Linear(1*11,1*11)#将结果映射到第1到168天数据
    def forward(self,x):
        return self.linear(self.lstm(x)[0].reshape(-1,1*11))

# %%
loaded_model = torch.load('0predict168_v3.pkl')
model=MyModel()
model.load_state_dict(loaded_model)
# Out:
# <All keys matched successfully>

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
lossList=[]#记录训练loss
lossListTest=[]#记录测试loss
epochs = 10000
for epoch in range(epochs):
    loss_nowEpoch=[]
    model.train()
    for step, (batch_x, batch_y) in enumerate(train_loader):
        out=model(batch_x)#模型输入
        # Loss = F.mse_loss(out,batch_y.view(-1,1*11))#loss计算，将batch_y从(100,1,11)变形为(100,1*11)
        Loss = F.l1_loss(out, batch_y.view(-1,1*11))

        optimizer.zero_grad()#当前batch的梯度不会再用到，所以清除梯度
        Loss.backward()#反向传播计算梯度
        optimizer.step()#更新参数
        loss_nowEpoch.append(Loss.item())
        break
    lossList.append(sum(loss_nowEpoch)/len(loss_nowEpoch))
 
    loss_nowEpochTest = []
    model.eval()
    for step, (batch_x, batch_y) in enumerate(test_loader):
        out = model(batch_x)
        # Loss = F.mse_loss(out, batch_y.view(-1, 1*11))  # 将batch_y从(100,1,11)变形为(100,1*11)
        Loss = F.l1_loss(out, batch_y.view(-1,1*11))
        loss_nowEpochTest.append(Loss.item())
        break
    lossListTest.append(sum(loss_nowEpochTest)/len(loss_nowEpochTest))
 
    print(">>> EPOCH:{} averTrainLoss:{:.3f} averTestLoss:{:.3f}".format(epoch+1, lossList[-1],lossListTest[-1]))

torch.save(model.state_dict(), '0predict168_v3.pkl')
# Out:
# >>> EPOCH:1 averTrainLoss:0.462 averTestLoss:0.513
# >>> EPOCH:2 averTrainLoss:0.475 averTestLoss:0.507
# >>> EPOCH:3 averTrainLoss:0.474 averTestLoss:0.511
# >>> EPOCH:4 averTrainLoss:0.440 averTestLoss:0.520
# >>> EPOCH:5 averTrainLoss:0.471 averTestLoss:0.526
# >>> EPOCH:6 averTrainLoss:0.462 averTestLoss:0.523
# >>> EPOCH:7 averTrainLoss:0.454 averTestLoss:0.516
# >>> EPOCH:8 averTrainLoss:0.466 averTestLoss:0.512
# >>> EPOCH:9 averTrainLoss:0.450 averTestLoss:0.508
# >>> EPOCH:10 averTrainLoss:0.459 averTestLoss:0.506
# >>> EPOCH:11 averTrainLoss:0.442 averTestLoss:0.507
# >>> EPOCH:12 averTrainLoss:0.435 averTestLoss:0.511
# >>> EPOCH:13 averTrainLoss:0.455 averTestLoss:0.515
# >>> EPOCH:14 averTrainLoss:0.452 averTestLoss:0.517
# >>> EPOCH:15 averTrainLoss:0.443 averTestLoss:0.519
# >>> EPOCH:16 averTrainLoss:0.457 averTestLoss:0.519
# >>> EPOCH:17 averTrainLoss:0.463 averTestLoss:0.518
# >>> EPOCH:18 averTrainLoss:0.437 averTestLoss:0.517
# >>> EPOCH:19 averTrainLoss:0.454 averTestLoss:0.517
# >>> EPOCH:20 averTrainLoss:0.447 averTestLoss:0.515
# >>> EPOCH:21 averTrainLoss:0.427 averTestLoss:0.514
# >>> EPOCH:22 averTrainLoss:0.435 averTestLoss:0.511
# >>> EPOCH:23 averTrainLoss:0.448 averTestLoss:0.507
# >>> EPOCH:24 averTrainLoss:0.449 averTestLoss:0.504
# >>> EPOCH:25 averTrainLoss:0.453 averTestLoss:0.505
# >>> EPOCH:26 averTrainLoss:0.455 averTestLoss:0.508
# >>> EPOCH:27 averTrainLoss:0.443 averTestLoss:0.511
# >>> EPOCH:28 averTrainLoss:0.435 averTestLoss:0.513
# >>> EPOCH:29 averTrainLoss:0.446 averTestLoss:0.513
# >>> EPOCH:30 averTrainLoss:0.488 averTestLoss:0.513
# >>> EPOCH:31 averTrainLoss:0.452 averTestLoss:0.511
# >>> EPOCH:32 averTrainLoss:0.463 averTestLoss:0.509
# >>> EPOCH:33 averTrainLoss:0.455 averTestLoss:0.508
# >>> EPOCH:34 averTrainLoss:0.451 averTestLoss:0.509
# >>> EPOCH:35 averTrainLoss:0.465 averTestLoss:0.509
# >>> EPOCH:36 averTrainLoss:0.441 averTestLoss:0.512
# >>> EPOCH:37 averTrainLoss:0.444 averTestLoss:0.512
# >>> EPOCH:38 averTrainLoss:0.449 averTestLoss:0.510
# >>> EPOCH:39 averTrainLoss:0.457 averTestLoss:0.507
# >>> EPOCH:40 averTrainLoss:0.479 averTestLoss:0.506
# >>> EPOCH:41 averTrainLoss:0.440 averTestLoss:0.507
# >>> EPOCH:42 averTrainLoss:0.429 averTestLoss:0.511
# >>> EPOCH:43 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:44 averTrainLoss:0.485 averTestLoss:0.510
# >>> EPOCH:45 averTrainLoss:0.434 averTestLoss:0.509
# >>> EPOCH:46 averTrainLoss:0.442 averTestLoss:0.509
# >>> EPOCH:47 averTrainLoss:0.476 averTestLoss:0.510
# >>> EPOCH:48 averTrainLoss:0.420 averTestLoss:0.510
# >>> EPOCH:49 averTrainLoss:0.452 averTestLoss:0.510
# >>> EPOCH:50 averTrainLoss:0.479 averTestLoss:0.510
# >>> EPOCH:51 averTrainLoss:0.447 averTestLoss:0.511
# >>> EPOCH:52 averTrainLoss:0.441 averTestLoss:0.512
# >>> EPOCH:53 averTrainLoss:0.439 averTestLoss:0.512
# >>> EPOCH:54 averTrainLoss:0.461 averTestLoss:0.511
# >>> EPOCH:55 averTrainLoss:0.452 averTestLoss:0.509
# >>> EPOCH:56 averTrainLoss:0.440 averTestLoss:0.510
# >>> EPOCH:57 averTrainLoss:0.442 averTestLoss:0.512
# >>> EPOCH:58 averTrainLoss:0.463 averTestLoss:0.513
# >>> EPOCH:59 averTrainLoss:0.456 averTestLoss:0.515
# >>> EPOCH:60 averTrainLoss:0.457 averTestLoss:0.515
# >>> EPOCH:61 averTrainLoss:0.450 averTestLoss:0.513
# >>> EPOCH:62 averTrainLoss:0.462 averTestLoss:0.513
# >>> EPOCH:63 averTrainLoss:0.434 averTestLoss:0.514
# >>> EPOCH:64 averTrainLoss:0.459 averTestLoss:0.514
# >>> EPOCH:65 averTrainLoss:0.437 averTestLoss:0.514
# >>> EPOCH:66 averTrainLoss:0.447 averTestLoss:0.513
# >>> EPOCH:67 averTrainLoss:0.457 averTestLoss:0.513
# >>> EPOCH:68 averTrainLoss:0.434 averTestLoss:0.514
# >>> EPOCH:69 averTrainLoss:0.458 averTestLoss:0.514
# >>> EPOCH:70 averTrainLoss:0.450 averTestLoss:0.512
# >>> EPOCH:71 averTrainLoss:0.440 averTestLoss:0.513
# >>> EPOCH:72 averTrainLoss:0.454 averTestLoss:0.514
# >>> EPOCH:73 averTrainLoss:0.460 averTestLoss:0.514
# >>> EPOCH:74 averTrainLoss:0.451 averTestLoss:0.513
# >>> EPOCH:75 averTrainLoss:0.452 averTestLoss:0.513
# >>> EPOCH:76 averTrainLoss:0.465 averTestLoss:0.513
# >>> EPOCH:77 averTrainLoss:0.451 averTestLoss:0.513
# >>> EPOCH:78 averTrainLoss:0.476 averTestLoss:0.513
# >>> EPOCH:79 averTrainLoss:0.451 averTestLoss:0.512
# >>> EPOCH:80 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:81 averTrainLoss:0.456 averTestLoss:0.511
# >>> EPOCH:82 averTrainLoss:0.438 averTestLoss:0.512
# >>> EPOCH:83 averTrainLoss:0.455 averTestLoss:0.515
# >>> EPOCH:84 averTrainLoss:0.420 averTestLoss:0.517
# >>> EPOCH:85 averTrainLoss:0.446 averTestLoss:0.517
# >>> EPOCH:86 averTrainLoss:0.440 averTestLoss:0.516
# >>> EPOCH:87 averTrainLoss:0.444 averTestLoss:0.513
# >>> EPOCH:88 averTrainLoss:0.475 averTestLoss:0.508
# >>> EPOCH:89 averTrainLoss:0.447 averTestLoss:0.507
# >>> EPOCH:90 averTrainLoss:0.450 averTestLoss:0.507
# >>> EPOCH:91 averTrainLoss:0.475 averTestLoss:0.509
# >>> EPOCH:92 averTrainLoss:0.481 averTestLoss:0.514
# >>> EPOCH:93 averTrainLoss:0.462 averTestLoss:0.517
# >>> EPOCH:94 averTrainLoss:0.446 averTestLoss:0.517
# >>> EPOCH:95 averTrainLoss:0.447 averTestLoss:0.515
# >>> EPOCH:96 averTrainLoss:0.471 averTestLoss:0.513
# >>> EPOCH:97 averTrainLoss:0.432 averTestLoss:0.514
# >>> EPOCH:98 averTrainLoss:0.478 averTestLoss:0.515
# >>> EPOCH:99 averTrainLoss:0.459 averTestLoss:0.516
# >>> EPOCH:100 averTrainLoss:0.446 averTestLoss:0.516
# >>> EPOCH:101 averTrainLoss:0.462 averTestLoss:0.513
# >>> EPOCH:102 averTrainLoss:0.448 averTestLoss:0.510
# >>> EPOCH:103 averTrainLoss:0.464 averTestLoss:0.508
# >>> EPOCH:104 averTrainLoss:0.455 averTestLoss:0.507
# >>> EPOCH:105 averTrainLoss:0.436 averTestLoss:0.506
# >>> EPOCH:106 averTrainLoss:0.462 averTestLoss:0.507
# >>> EPOCH:107 averTrainLoss:0.438 averTestLoss:0.508
# >>> EPOCH:108 averTrainLoss:0.452 averTestLoss:0.510
# >>> EPOCH:109 averTrainLoss:0.463 averTestLoss:0.515
# >>> EPOCH:110 averTrainLoss:0.466 averTestLoss:0.518
# >>> EPOCH:111 averTrainLoss:0.455 averTestLoss:0.518
# >>> EPOCH:112 averTrainLoss:0.462 averTestLoss:0.517
# >>> EPOCH:113 averTrainLoss:0.425 averTestLoss:0.513
# >>> EPOCH:114 averTrainLoss:0.461 averTestLoss:0.510
# >>> EPOCH:115 averTrainLoss:0.446 averTestLoss:0.509
# >>> EPOCH:116 averTrainLoss:0.441 averTestLoss:0.510
# >>> EPOCH:117 averTrainLoss:0.438 averTestLoss:0.512
# >>> EPOCH:118 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:119 averTrainLoss:0.466 averTestLoss:0.510
# >>> EPOCH:120 averTrainLoss:0.449 averTestLoss:0.510
# >>> EPOCH:121 averTrainLoss:0.466 averTestLoss:0.511
# >>> EPOCH:122 averTrainLoss:0.470 averTestLoss:0.511
# >>> EPOCH:123 averTrainLoss:0.421 averTestLoss:0.511
# >>> EPOCH:124 averTrainLoss:0.431 averTestLoss:0.511
# >>> EPOCH:125 averTrainLoss:0.453 averTestLoss:0.510
# >>> EPOCH:126 averTrainLoss:0.449 averTestLoss:0.509
# >>> EPOCH:127 averTrainLoss:0.439 averTestLoss:0.507
# >>> EPOCH:128 averTrainLoss:0.447 averTestLoss:0.507
# >>> EPOCH:129 averTrainLoss:0.453 averTestLoss:0.508
# >>> EPOCH:130 averTrainLoss:0.480 averTestLoss:0.509
# >>> EPOCH:131 averTrainLoss:0.469 averTestLoss:0.513
# >>> EPOCH:132 averTrainLoss:0.441 averTestLoss:0.518
# >>> EPOCH:133 averTrainLoss:0.456 averTestLoss:0.521
# >>> EPOCH:134 averTrainLoss:0.461 averTestLoss:0.518
# >>> EPOCH:135 averTrainLoss:0.431 averTestLoss:0.514
# >>> EPOCH:136 averTrainLoss:0.450 averTestLoss:0.510
# >>> EPOCH:137 averTrainLoss:0.471 averTestLoss:0.510
# >>> EPOCH:138 averTrainLoss:0.442 averTestLoss:0.508
# >>> EPOCH:139 averTrainLoss:0.472 averTestLoss:0.509
# >>> EPOCH:140 averTrainLoss:0.462 averTestLoss:0.512
# >>> EPOCH:141 averTrainLoss:0.466 averTestLoss:0.517
# >>> EPOCH:142 averTrainLoss:0.447 averTestLoss:0.519
# >>> EPOCH:143 averTrainLoss:0.451 averTestLoss:0.518
# >>> EPOCH:144 averTrainLoss:0.462 averTestLoss:0.516
# >>> EPOCH:145 averTrainLoss:0.445 averTestLoss:0.512
# >>> EPOCH:146 averTrainLoss:0.475 averTestLoss:0.511
# >>> EPOCH:147 averTrainLoss:0.445 averTestLoss:0.509
# >>> EPOCH:148 averTrainLoss:0.450 averTestLoss:0.508
# >>> EPOCH:149 averTrainLoss:0.444 averTestLoss:0.510
# >>> EPOCH:150 averTrainLoss:0.465 averTestLoss:0.512
# >>> EPOCH:151 averTrainLoss:0.473 averTestLoss:0.516
# >>> EPOCH:152 averTrainLoss:0.483 averTestLoss:0.515
# >>> EPOCH:153 averTrainLoss:0.456 averTestLoss:0.512
# >>> EPOCH:154 averTrainLoss:0.439 averTestLoss:0.510
# >>> EPOCH:155 averTrainLoss:0.439 averTestLoss:0.511
# >>> EPOCH:156 averTrainLoss:0.475 averTestLoss:0.511
# >>> EPOCH:157 averTrainLoss:0.443 averTestLoss:0.511
# >>> EPOCH:158 averTrainLoss:0.465 averTestLoss:0.512
# >>> EPOCH:159 averTrainLoss:0.438 averTestLoss:0.512
# >>> EPOCH:160 averTrainLoss:0.473 averTestLoss:0.513
# >>> EPOCH:161 averTrainLoss:0.431 averTestLoss:0.513
# >>> EPOCH:162 averTrainLoss:0.446 averTestLoss:0.513
# >>> EPOCH:163 averTrainLoss:0.438 averTestLoss:0.512
# >>> EPOCH:164 averTrainLoss:0.429 averTestLoss:0.510
# >>> EPOCH:165 averTrainLoss:0.432 averTestLoss:0.509
# >>> EPOCH:166 averTrainLoss:0.458 averTestLoss:0.509
# >>> EPOCH:167 averTrainLoss:0.433 averTestLoss:0.508
# >>> EPOCH:168 averTrainLoss:0.448 averTestLoss:0.509
# >>> EPOCH:169 averTrainLoss:0.453 averTestLoss:0.512
# >>> EPOCH:170 averTrainLoss:0.443 averTestLoss:0.514
# >>> EPOCH:171 averTrainLoss:0.443 averTestLoss:0.515
# >>> EPOCH:172 averTrainLoss:0.450 averTestLoss:0.513
# >>> EPOCH:173 averTrainLoss:0.456 averTestLoss:0.513
# >>> EPOCH:174 averTrainLoss:0.429 averTestLoss:0.512
# >>> EPOCH:175 averTrainLoss:0.444 averTestLoss:0.512
# >>> EPOCH:176 averTrainLoss:0.450 averTestLoss:0.513
# >>> EPOCH:177 averTrainLoss:0.466 averTestLoss:0.513
# >>> EPOCH:178 averTrainLoss:0.477 averTestLoss:0.513
# >>> EPOCH:179 averTrainLoss:0.441 averTestLoss:0.514
# >>> EPOCH:180 averTrainLoss:0.457 averTestLoss:0.513
# >>> EPOCH:181 averTrainLoss:0.454 averTestLoss:0.514
# >>> EPOCH:182 averTrainLoss:0.474 averTestLoss:0.516
# >>> EPOCH:183 averTrainLoss:0.439 averTestLoss:0.516
# >>> EPOCH:184 averTrainLoss:0.477 averTestLoss:0.514
# >>> EPOCH:185 averTrainLoss:0.452 averTestLoss:0.511
# >>> EPOCH:186 averTrainLoss:0.461 averTestLoss:0.509
# >>> EPOCH:187 averTrainLoss:0.448 averTestLoss:0.509
# >>> EPOCH:188 averTrainLoss:0.454 averTestLoss:0.510
# >>> EPOCH:189 averTrainLoss:0.431 averTestLoss:0.513
# >>> EPOCH:190 averTrainLoss:0.451 averTestLoss:0.515
# >>> EPOCH:191 averTrainLoss:0.445 averTestLoss:0.516
# >>> EPOCH:192 averTrainLoss:0.492 averTestLoss:0.514
# >>> EPOCH:193 averTrainLoss:0.460 averTestLoss:0.511
# >>> EPOCH:194 averTrainLoss:0.455 averTestLoss:0.511
# >>> EPOCH:195 averTrainLoss:0.450 averTestLoss:0.512
# >>> EPOCH:196 averTrainLoss:0.456 averTestLoss:0.513
# >>> EPOCH:197 averTrainLoss:0.458 averTestLoss:0.515
# >>> EPOCH:198 averTrainLoss:0.472 averTestLoss:0.516
# >>> EPOCH:199 averTrainLoss:0.460 averTestLoss:0.518
# >>> EPOCH:200 averTrainLoss:0.430 averTestLoss:0.517
# >>> EPOCH:201 averTrainLoss:0.442 averTestLoss:0.514
# >>> EPOCH:202 averTrainLoss:0.479 averTestLoss:0.511
# >>> EPOCH:203 averTrainLoss:0.430 averTestLoss:0.510
# >>> EPOCH:204 averTrainLoss:0.467 averTestLoss:0.510
# >>> EPOCH:205 averTrainLoss:0.448 averTestLoss:0.510
# >>> EPOCH:206 averTrainLoss:0.440 averTestLoss:0.511
# >>> EPOCH:207 averTrainLoss:0.470 averTestLoss:0.511
# >>> EPOCH:208 averTrainLoss:0.459 averTestLoss:0.511
# >>> EPOCH:209 averTrainLoss:0.484 averTestLoss:0.513
# >>> EPOCH:210 averTrainLoss:0.470 averTestLoss:0.515
# >>> EPOCH:211 averTrainLoss:0.465 averTestLoss:0.515
# >>> EPOCH:212 averTrainLoss:0.436 averTestLoss:0.514
# >>> EPOCH:213 averTrainLoss:0.461 averTestLoss:0.512
# >>> EPOCH:214 averTrainLoss:0.458 averTestLoss:0.511
# >>> EPOCH:215 averTrainLoss:0.432 averTestLoss:0.512
# >>> EPOCH:216 averTrainLoss:0.437 averTestLoss:0.513
# >>> EPOCH:217 averTrainLoss:0.479 averTestLoss:0.514
# >>> EPOCH:218 averTrainLoss:0.471 averTestLoss:0.517
# >>> EPOCH:219 averTrainLoss:0.421 averTestLoss:0.520
# >>> EPOCH:220 averTrainLoss:0.445 averTestLoss:0.521
# >>> EPOCH:221 averTrainLoss:0.464 averTestLoss:0.520
# >>> EPOCH:222 averTrainLoss:0.469 averTestLoss:0.517
# >>> EPOCH:223 averTrainLoss:0.444 averTestLoss:0.513
# >>> EPOCH:224 averTrainLoss:0.451 averTestLoss:0.510
# >>> EPOCH:225 averTrainLoss:0.442 averTestLoss:0.509
# >>> EPOCH:226 averTrainLoss:0.479 averTestLoss:0.510
# >>> EPOCH:227 averTrainLoss:0.439 averTestLoss:0.511
# >>> EPOCH:228 averTrainLoss:0.460 averTestLoss:0.514
# >>> EPOCH:229 averTrainLoss:0.451 averTestLoss:0.517
# >>> EPOCH:230 averTrainLoss:0.464 averTestLoss:0.520
# >>> EPOCH:231 averTrainLoss:0.455 averTestLoss:0.519
# >>> EPOCH:232 averTrainLoss:0.440 averTestLoss:0.517
# >>> EPOCH:233 averTrainLoss:0.448 averTestLoss:0.514
# >>> EPOCH:234 averTrainLoss:0.453 averTestLoss:0.511
# >>> EPOCH:235 averTrainLoss:0.461 averTestLoss:0.510
# >>> EPOCH:236 averTrainLoss:0.435 averTestLoss:0.510
# >>> EPOCH:237 averTrainLoss:0.458 averTestLoss:0.510
# >>> EPOCH:238 averTrainLoss:0.444 averTestLoss:0.512
# >>> EPOCH:239 averTrainLoss:0.454 averTestLoss:0.515
# >>> EPOCH:240 averTrainLoss:0.481 averTestLoss:0.515
# >>> EPOCH:241 averTrainLoss:0.464 averTestLoss:0.512
# >>> EPOCH:242 averTrainLoss:0.456 averTestLoss:0.509
# >>> EPOCH:243 averTrainLoss:0.462 averTestLoss:0.507
# >>> EPOCH:244 averTrainLoss:0.455 averTestLoss:0.508
# >>> EPOCH:245 averTrainLoss:0.446 averTestLoss:0.511
# >>> EPOCH:246 averTrainLoss:0.456 averTestLoss:0.512
# >>> EPOCH:247 averTrainLoss:0.451 averTestLoss:0.514
# >>> EPOCH:248 averTrainLoss:0.476 averTestLoss:0.517
# >>> EPOCH:249 averTrainLoss:0.462 averTestLoss:0.518
# >>> EPOCH:250 averTrainLoss:0.468 averTestLoss:0.515
# >>> EPOCH:251 averTrainLoss:0.454 averTestLoss:0.512
# >>> EPOCH:252 averTrainLoss:0.452 averTestLoss:0.510
# >>> EPOCH:253 averTrainLoss:0.458 averTestLoss:0.509
# >>> EPOCH:254 averTrainLoss:0.450 averTestLoss:0.509
# >>> EPOCH:255 averTrainLoss:0.471 averTestLoss:0.511
# >>> EPOCH:256 averTrainLoss:0.454 averTestLoss:0.512
# >>> EPOCH:257 averTrainLoss:0.434 averTestLoss:0.514
# >>> EPOCH:258 averTrainLoss:0.467 averTestLoss:0.514
# >>> EPOCH:259 averTrainLoss:0.446 averTestLoss:0.511
# >>> EPOCH:260 averTrainLoss:0.426 averTestLoss:0.508
# >>> EPOCH:261 averTrainLoss:0.455 averTestLoss:0.510
# >>> EPOCH:262 averTrainLoss:0.439 averTestLoss:0.512
# >>> EPOCH:263 averTrainLoss:0.454 averTestLoss:0.511
# >>> EPOCH:264 averTrainLoss:0.437 averTestLoss:0.511
# >>> EPOCH:265 averTrainLoss:0.449 averTestLoss:0.512
# >>> EPOCH:266 averTrainLoss:0.451 averTestLoss:0.512
# >>> EPOCH:267 averTrainLoss:0.445 averTestLoss:0.514
# >>> EPOCH:268 averTrainLoss:0.457 averTestLoss:0.517
# >>> EPOCH:269 averTrainLoss:0.457 averTestLoss:0.517
# >>> EPOCH:270 averTrainLoss:0.468 averTestLoss:0.515
# >>> EPOCH:271 averTrainLoss:0.466 averTestLoss:0.513
# >>> EPOCH:272 averTrainLoss:0.450 averTestLoss:0.510
# >>> EPOCH:273 averTrainLoss:0.471 averTestLoss:0.510
# >>> EPOCH:274 averTrainLoss:0.428 averTestLoss:0.513
# >>> EPOCH:275 averTrainLoss:0.430 averTestLoss:0.514
# >>> EPOCH:276 averTrainLoss:0.428 averTestLoss:0.516
# >>> EPOCH:277 averTrainLoss:0.447 averTestLoss:0.517
# >>> EPOCH:278 averTrainLoss:0.441 averTestLoss:0.517
# >>> EPOCH:279 averTrainLoss:0.477 averTestLoss:0.517
# >>> EPOCH:280 averTrainLoss:0.466 averTestLoss:0.517
# >>> EPOCH:281 averTrainLoss:0.452 averTestLoss:0.516
# >>> EPOCH:282 averTrainLoss:0.461 averTestLoss:0.516
# >>> EPOCH:283 averTrainLoss:0.447 averTestLoss:0.515
# >>> EPOCH:284 averTrainLoss:0.450 averTestLoss:0.514
# >>> EPOCH:285 averTrainLoss:0.438 averTestLoss:0.513
# >>> EPOCH:286 averTrainLoss:0.462 averTestLoss:0.513
# >>> EPOCH:287 averTrainLoss:0.424 averTestLoss:0.513
# >>> EPOCH:288 averTrainLoss:0.465 averTestLoss:0.514
# >>> EPOCH:289 averTrainLoss:0.420 averTestLoss:0.514
# >>> EPOCH:290 averTrainLoss:0.455 averTestLoss:0.511
# >>> EPOCH:291 averTrainLoss:0.440 averTestLoss:0.512
# >>> EPOCH:292 averTrainLoss:0.466 averTestLoss:0.512
# >>> EPOCH:293 averTrainLoss:0.474 averTestLoss:0.512
# >>> EPOCH:294 averTrainLoss:0.439 averTestLoss:0.512
# >>> EPOCH:295 averTrainLoss:0.451 averTestLoss:0.510
# >>> EPOCH:296 averTrainLoss:0.471 averTestLoss:0.510
# >>> EPOCH:297 averTrainLoss:0.453 averTestLoss:0.512
# >>> EPOCH:298 averTrainLoss:0.449 averTestLoss:0.515
# >>> EPOCH:299 averTrainLoss:0.454 averTestLoss:0.518
# >>> EPOCH:300 averTrainLoss:0.438 averTestLoss:0.521
# >>> EPOCH:301 averTrainLoss:0.461 averTestLoss:0.521
# >>> EPOCH:302 averTrainLoss:0.457 averTestLoss:0.518
# >>> EPOCH:303 averTrainLoss:0.446 averTestLoss:0.512
# >>> EPOCH:304 averTrainLoss:0.441 averTestLoss:0.510
# >>> EPOCH:305 averTrainLoss:0.446 averTestLoss:0.509
# >>> EPOCH:306 averTrainLoss:0.449 averTestLoss:0.510
# >>> EPOCH:307 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:308 averTrainLoss:0.436 averTestLoss:0.513
# >>> EPOCH:309 averTrainLoss:0.440 averTestLoss:0.514
# >>> EPOCH:310 averTrainLoss:0.452 averTestLoss:0.513
# >>> EPOCH:311 averTrainLoss:0.460 averTestLoss:0.511
# >>> EPOCH:312 averTrainLoss:0.456 averTestLoss:0.512
# >>> EPOCH:313 averTrainLoss:0.482 averTestLoss:0.512
# >>> EPOCH:314 averTrainLoss:0.454 averTestLoss:0.513
# >>> EPOCH:315 averTrainLoss:0.446 averTestLoss:0.513
# >>> EPOCH:316 averTrainLoss:0.470 averTestLoss:0.513
# >>> EPOCH:317 averTrainLoss:0.430 averTestLoss:0.513
# >>> EPOCH:318 averTrainLoss:0.440 averTestLoss:0.514
# >>> EPOCH:319 averTrainLoss:0.486 averTestLoss:0.514
# >>> EPOCH:320 averTrainLoss:0.464 averTestLoss:0.515
# >>> EPOCH:321 averTrainLoss:0.470 averTestLoss:0.514
# >>> EPOCH:322 averTrainLoss:0.482 averTestLoss:0.514
# >>> EPOCH:323 averTrainLoss:0.455 averTestLoss:0.514
# >>> EPOCH:324 averTrainLoss:0.465 averTestLoss:0.512
# >>> EPOCH:325 averTrainLoss:0.456 averTestLoss:0.513
# >>> EPOCH:326 averTrainLoss:0.472 averTestLoss:0.512
# >>> EPOCH:327 averTrainLoss:0.451 averTestLoss:0.511
# >>> EPOCH:328 averTrainLoss:0.469 averTestLoss:0.510
# >>> EPOCH:329 averTrainLoss:0.470 averTestLoss:0.510
# >>> EPOCH:330 averTrainLoss:0.447 averTestLoss:0.513
# >>> EPOCH:331 averTrainLoss:0.479 averTestLoss:0.516
# >>> EPOCH:332 averTrainLoss:0.480 averTestLoss:0.518
# >>> EPOCH:333 averTrainLoss:0.447 averTestLoss:0.519
# >>> EPOCH:334 averTrainLoss:0.463 averTestLoss:0.518
# >>> EPOCH:335 averTrainLoss:0.438 averTestLoss:0.516
# >>> EPOCH:336 averTrainLoss:0.439 averTestLoss:0.515
# >>> EPOCH:337 averTrainLoss:0.469 averTestLoss:0.514
# >>> EPOCH:338 averTrainLoss:0.447 averTestLoss:0.514
# >>> EPOCH:339 averTrainLoss:0.437 averTestLoss:0.516
# >>> EPOCH:340 averTrainLoss:0.458 averTestLoss:0.517
# >>> EPOCH:341 averTrainLoss:0.448 averTestLoss:0.517
# >>> EPOCH:342 averTrainLoss:0.443 averTestLoss:0.516
# >>> EPOCH:343 averTrainLoss:0.454 averTestLoss:0.515
# >>> EPOCH:344 averTrainLoss:0.443 averTestLoss:0.515
# >>> EPOCH:345 averTrainLoss:0.448 averTestLoss:0.513
# >>> EPOCH:346 averTrainLoss:0.454 averTestLoss:0.512
# >>> EPOCH:347 averTrainLoss:0.460 averTestLoss:0.512
# >>> EPOCH:348 averTrainLoss:0.430 averTestLoss:0.513
# >>> EPOCH:349 averTrainLoss:0.461 averTestLoss:0.516
# >>> EPOCH:350 averTrainLoss:0.440 averTestLoss:0.517
# >>> EPOCH:351 averTrainLoss:0.452 averTestLoss:0.514
# >>> EPOCH:352 averTrainLoss:0.471 averTestLoss:0.511
# >>> EPOCH:353 averTrainLoss:0.456 averTestLoss:0.509
# >>> EPOCH:354 averTrainLoss:0.490 averTestLoss:0.509
# >>> EPOCH:355 averTrainLoss:0.458 averTestLoss:0.509
# >>> EPOCH:356 averTrainLoss:0.437 averTestLoss:0.509
# >>> EPOCH:357 averTrainLoss:0.470 averTestLoss:0.513
# >>> EPOCH:358 averTrainLoss:0.470 averTestLoss:0.519
# >>> EPOCH:359 averTrainLoss:0.472 averTestLoss:0.525
# >>> EPOCH:360 averTrainLoss:0.456 averTestLoss:0.527
# >>> EPOCH:361 averTrainLoss:0.469 averTestLoss:0.523
# >>> EPOCH:362 averTrainLoss:0.484 averTestLoss:0.516
# >>> EPOCH:363 averTrainLoss:0.456 averTestLoss:0.511
# >>> EPOCH:364 averTrainLoss:0.452 averTestLoss:0.509
# >>> EPOCH:365 averTrainLoss:0.458 averTestLoss:0.508
# >>> EPOCH:366 averTrainLoss:0.442 averTestLoss:0.506
# >>> EPOCH:367 averTrainLoss:0.443 averTestLoss:0.506
# >>> EPOCH:368 averTrainLoss:0.465 averTestLoss:0.510
# >>> EPOCH:369 averTrainLoss:0.452 averTestLoss:0.515
# >>> EPOCH:370 averTrainLoss:0.460 averTestLoss:0.516
# >>> EPOCH:371 averTrainLoss:0.469 averTestLoss:0.515
# >>> EPOCH:372 averTrainLoss:0.451 averTestLoss:0.513
# >>> EPOCH:373 averTrainLoss:0.453 averTestLoss:0.511
# >>> EPOCH:374 averTrainLoss:0.434 averTestLoss:0.511
# >>> EPOCH:375 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:376 averTrainLoss:0.461 averTestLoss:0.512
# >>> EPOCH:377 averTrainLoss:0.436 averTestLoss:0.515
# >>> EPOCH:378 averTrainLoss:0.443 averTestLoss:0.518
# >>> EPOCH:379 averTrainLoss:0.456 averTestLoss:0.518
# >>> EPOCH:380 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:381 averTrainLoss:0.434 averTestLoss:0.514
# >>> EPOCH:382 averTrainLoss:0.439 averTestLoss:0.512
# >>> EPOCH:383 averTrainLoss:0.451 averTestLoss:0.514
# >>> EPOCH:384 averTrainLoss:0.445 averTestLoss:0.515
# >>> EPOCH:385 averTrainLoss:0.460 averTestLoss:0.514
# >>> EPOCH:386 averTrainLoss:0.424 averTestLoss:0.514
# >>> EPOCH:387 averTrainLoss:0.450 averTestLoss:0.513
# >>> EPOCH:388 averTrainLoss:0.442 averTestLoss:0.511
# >>> EPOCH:389 averTrainLoss:0.441 averTestLoss:0.510
# >>> EPOCH:390 averTrainLoss:0.454 averTestLoss:0.510
# >>> EPOCH:391 averTrainLoss:0.431 averTestLoss:0.510
# >>> EPOCH:392 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:393 averTrainLoss:0.448 averTestLoss:0.512
# >>> EPOCH:394 averTrainLoss:0.448 averTestLoss:0.511
# >>> EPOCH:395 averTrainLoss:0.462 averTestLoss:0.509
# >>> EPOCH:396 averTrainLoss:0.444 averTestLoss:0.506
# >>> EPOCH:397 averTrainLoss:0.446 averTestLoss:0.505
# >>> EPOCH:398 averTrainLoss:0.457 averTestLoss:0.508
# >>> EPOCH:399 averTrainLoss:0.433 averTestLoss:0.511
# >>> EPOCH:400 averTrainLoss:0.455 averTestLoss:0.512
# >>> EPOCH:401 averTrainLoss:0.442 averTestLoss:0.513
# >>> EPOCH:402 averTrainLoss:0.457 averTestLoss:0.515
# >>> EPOCH:403 averTrainLoss:0.501 averTestLoss:0.515
# >>> EPOCH:404 averTrainLoss:0.420 averTestLoss:0.513
# >>> EPOCH:405 averTrainLoss:0.477 averTestLoss:0.511
# >>> EPOCH:406 averTrainLoss:0.450 averTestLoss:0.511
# >>> EPOCH:407 averTrainLoss:0.434 averTestLoss:0.513
# >>> EPOCH:408 averTrainLoss:0.444 averTestLoss:0.515
# >>> EPOCH:409 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:410 averTrainLoss:0.451 averTestLoss:0.517
# >>> EPOCH:411 averTrainLoss:0.453 averTestLoss:0.513
# >>> EPOCH:412 averTrainLoss:0.447 averTestLoss:0.510
# >>> EPOCH:413 averTrainLoss:0.453 averTestLoss:0.509
# >>> EPOCH:414 averTrainLoss:0.438 averTestLoss:0.509
# >>> EPOCH:415 averTrainLoss:0.470 averTestLoss:0.510
# >>> EPOCH:416 averTrainLoss:0.463 averTestLoss:0.512
# >>> EPOCH:417 averTrainLoss:0.484 averTestLoss:0.514
# >>> EPOCH:418 averTrainLoss:0.427 averTestLoss:0.515
# >>> EPOCH:419 averTrainLoss:0.445 averTestLoss:0.515
# >>> EPOCH:420 averTrainLoss:0.436 averTestLoss:0.516
# >>> EPOCH:421 averTrainLoss:0.452 averTestLoss:0.516
# >>> EPOCH:422 averTrainLoss:0.443 averTestLoss:0.515
# >>> EPOCH:423 averTrainLoss:0.430 averTestLoss:0.514
# >>> EPOCH:424 averTrainLoss:0.473 averTestLoss:0.515
# >>> EPOCH:425 averTrainLoss:0.431 averTestLoss:0.515
# >>> EPOCH:426 averTrainLoss:0.459 averTestLoss:0.515
# >>> EPOCH:427 averTrainLoss:0.441 averTestLoss:0.515
# >>> EPOCH:428 averTrainLoss:0.461 averTestLoss:0.515
# >>> EPOCH:429 averTrainLoss:0.449 averTestLoss:0.515
# >>> EPOCH:430 averTrainLoss:0.436 averTestLoss:0.514
# >>> EPOCH:431 averTrainLoss:0.456 averTestLoss:0.512
# >>> EPOCH:432 averTrainLoss:0.462 averTestLoss:0.512
# >>> EPOCH:433 averTrainLoss:0.473 averTestLoss:0.512
# >>> EPOCH:434 averTrainLoss:0.462 averTestLoss:0.513
# >>> EPOCH:435 averTrainLoss:0.459 averTestLoss:0.515
# >>> EPOCH:436 averTrainLoss:0.445 averTestLoss:0.517
# >>> EPOCH:437 averTrainLoss:0.458 averTestLoss:0.518
# >>> EPOCH:438 averTrainLoss:0.480 averTestLoss:0.516
# >>> EPOCH:439 averTrainLoss:0.430 averTestLoss:0.514
# >>> EPOCH:440 averTrainLoss:0.459 averTestLoss:0.514
# >>> EPOCH:441 averTrainLoss:0.457 averTestLoss:0.514
# >>> EPOCH:442 averTrainLoss:0.465 averTestLoss:0.515
# >>> EPOCH:443 averTrainLoss:0.455 averTestLoss:0.516
# >>> EPOCH:444 averTrainLoss:0.442 averTestLoss:0.515
# >>> EPOCH:445 averTrainLoss:0.438 averTestLoss:0.513
# >>> EPOCH:446 averTrainLoss:0.468 averTestLoss:0.510
# >>> EPOCH:447 averTrainLoss:0.464 averTestLoss:0.511
# >>> EPOCH:448 averTrainLoss:0.467 averTestLoss:0.513
# >>> EPOCH:449 averTrainLoss:0.481 averTestLoss:0.514
# >>> EPOCH:450 averTrainLoss:0.467 averTestLoss:0.516
# >>> EPOCH:451 averTrainLoss:0.455 averTestLoss:0.517
# >>> EPOCH:452 averTrainLoss:0.457 averTestLoss:0.520
# >>> EPOCH:453 averTrainLoss:0.453 averTestLoss:0.521
# >>> EPOCH:454 averTrainLoss:0.458 averTestLoss:0.521
# >>> EPOCH:455 averTrainLoss:0.465 averTestLoss:0.518
# >>> EPOCH:456 averTrainLoss:0.423 averTestLoss:0.515
# >>> EPOCH:457 averTrainLoss:0.473 averTestLoss:0.510
# >>> EPOCH:458 averTrainLoss:0.457 averTestLoss:0.507
# >>> EPOCH:459 averTrainLoss:0.471 averTestLoss:0.509
# >>> EPOCH:460 averTrainLoss:0.460 averTestLoss:0.511
# >>> EPOCH:461 averTrainLoss:0.456 averTestLoss:0.514
# >>> EPOCH:462 averTrainLoss:0.452 averTestLoss:0.517
# >>> EPOCH:463 averTrainLoss:0.457 averTestLoss:0.520
# >>> EPOCH:464 averTrainLoss:0.472 averTestLoss:0.521
# >>> EPOCH:465 averTrainLoss:0.445 averTestLoss:0.519
# >>> EPOCH:466 averTrainLoss:0.455 averTestLoss:0.515
# >>> EPOCH:467 averTrainLoss:0.446 averTestLoss:0.512
# >>> EPOCH:468 averTrainLoss:0.457 averTestLoss:0.509
# >>> EPOCH:469 averTrainLoss:0.435 averTestLoss:0.507
# >>> EPOCH:470 averTrainLoss:0.467 averTestLoss:0.508
# >>> EPOCH:471 averTrainLoss:0.441 averTestLoss:0.509
# >>> EPOCH:472 averTrainLoss:0.456 averTestLoss:0.511
# >>> EPOCH:473 averTrainLoss:0.458 averTestLoss:0.513
# >>> EPOCH:474 averTrainLoss:0.441 averTestLoss:0.517
# >>> EPOCH:475 averTrainLoss:0.441 averTestLoss:0.520
# >>> EPOCH:476 averTrainLoss:0.460 averTestLoss:0.520
# >>> EPOCH:477 averTrainLoss:0.472 averTestLoss:0.518
# >>> EPOCH:478 averTrainLoss:0.441 averTestLoss:0.513
# >>> EPOCH:479 averTrainLoss:0.447 averTestLoss:0.511
# >>> EPOCH:480 averTrainLoss:0.436 averTestLoss:0.511
# >>> EPOCH:481 averTrainLoss:0.442 averTestLoss:0.511
# >>> EPOCH:482 averTrainLoss:0.469 averTestLoss:0.512
# >>> EPOCH:483 averTrainLoss:0.457 averTestLoss:0.514
# >>> EPOCH:484 averTrainLoss:0.454 averTestLoss:0.517
# >>> EPOCH:485 averTrainLoss:0.449 averTestLoss:0.519
# >>> EPOCH:486 averTrainLoss:0.460 averTestLoss:0.521
# >>> EPOCH:487 averTrainLoss:0.459 averTestLoss:0.519
# >>> EPOCH:488 averTrainLoss:0.445 averTestLoss:0.517
# >>> EPOCH:489 averTrainLoss:0.427 averTestLoss:0.515
# >>> EPOCH:490 averTrainLoss:0.470 averTestLoss:0.515
# >>> EPOCH:491 averTrainLoss:0.470 averTestLoss:0.516
# >>> EPOCH:492 averTrainLoss:0.427 averTestLoss:0.516
# >>> EPOCH:493 averTrainLoss:0.465 averTestLoss:0.513
# >>> EPOCH:494 averTrainLoss:0.455 averTestLoss:0.514
# >>> EPOCH:495 averTrainLoss:0.445 averTestLoss:0.513
# >>> EPOCH:496 averTrainLoss:0.434 averTestLoss:0.512
# >>> EPOCH:497 averTrainLoss:0.440 averTestLoss:0.511
# >>> EPOCH:498 averTrainLoss:0.446 averTestLoss:0.511
# >>> EPOCH:499 averTrainLoss:0.443 averTestLoss:0.510
# >>> EPOCH:500 averTrainLoss:0.471 averTestLoss:0.511
# >>> EPOCH:501 averTrainLoss:0.460 averTestLoss:0.511
# >>> EPOCH:502 averTrainLoss:0.431 averTestLoss:0.511
# >>> EPOCH:503 averTrainLoss:0.444 averTestLoss:0.513
# >>> EPOCH:504 averTrainLoss:0.450 averTestLoss:0.513
# >>> EPOCH:505 averTrainLoss:0.446 averTestLoss:0.516
# >>> EPOCH:506 averTrainLoss:0.436 averTestLoss:0.517
# >>> EPOCH:507 averTrainLoss:0.460 averTestLoss:0.518
# >>> EPOCH:508 averTrainLoss:0.478 averTestLoss:0.518
# >>> EPOCH:509 averTrainLoss:0.482 averTestLoss:0.516
# >>> EPOCH:510 averTrainLoss:0.460 averTestLoss:0.513
# >>> EPOCH:511 averTrainLoss:0.439 averTestLoss:0.511
# >>> EPOCH:512 averTrainLoss:0.466 averTestLoss:0.510
# >>> EPOCH:513 averTrainLoss:0.446 averTestLoss:0.509
# >>> EPOCH:514 averTrainLoss:0.446 averTestLoss:0.509
# >>> EPOCH:515 averTrainLoss:0.452 averTestLoss:0.512
# >>> EPOCH:516 averTrainLoss:0.451 averTestLoss:0.516
# >>> EPOCH:517 averTrainLoss:0.439 averTestLoss:0.518
# >>> EPOCH:518 averTrainLoss:0.461 averTestLoss:0.517
# >>> EPOCH:519 averTrainLoss:0.457 averTestLoss:0.517
# >>> EPOCH:520 averTrainLoss:0.472 averTestLoss:0.515
# >>> EPOCH:521 averTrainLoss:0.452 averTestLoss:0.513
# >>> EPOCH:522 averTrainLoss:0.445 averTestLoss:0.512
# >>> EPOCH:523 averTrainLoss:0.450 averTestLoss:0.512
# >>> EPOCH:524 averTrainLoss:0.452 averTestLoss:0.513
# >>> EPOCH:525 averTrainLoss:0.455 averTestLoss:0.513
# >>> EPOCH:526 averTrainLoss:0.454 averTestLoss:0.514
# >>> EPOCH:527 averTrainLoss:0.443 averTestLoss:0.515
# >>> EPOCH:528 averTrainLoss:0.445 averTestLoss:0.513
# >>> EPOCH:529 averTrainLoss:0.463 averTestLoss:0.514
# >>> EPOCH:530 averTrainLoss:0.457 averTestLoss:0.516
# >>> EPOCH:531 averTrainLoss:0.445 averTestLoss:0.517
# >>> EPOCH:532 averTrainLoss:0.451 averTestLoss:0.517
# >>> EPOCH:533 averTrainLoss:0.462 averTestLoss:0.514
# >>> EPOCH:534 averTrainLoss:0.464 averTestLoss:0.512
# >>> EPOCH:535 averTrainLoss:0.433 averTestLoss:0.511
# >>> EPOCH:536 averTrainLoss:0.454 averTestLoss:0.509
# >>> EPOCH:537 averTrainLoss:0.461 averTestLoss:0.511
# >>> EPOCH:538 averTrainLoss:0.458 averTestLoss:0.514
# >>> EPOCH:539 averTrainLoss:0.460 averTestLoss:0.517
# >>> EPOCH:540 averTrainLoss:0.447 averTestLoss:0.519
# >>> EPOCH:541 averTrainLoss:0.462 averTestLoss:0.518
# >>> EPOCH:542 averTrainLoss:0.451 averTestLoss:0.516
# >>> EPOCH:543 averTrainLoss:0.453 averTestLoss:0.515
# >>> EPOCH:544 averTrainLoss:0.442 averTestLoss:0.515
# >>> EPOCH:545 averTrainLoss:0.468 averTestLoss:0.514
# >>> EPOCH:546 averTrainLoss:0.452 averTestLoss:0.515
# >>> EPOCH:547 averTrainLoss:0.450 averTestLoss:0.516
# >>> EPOCH:548 averTrainLoss:0.457 averTestLoss:0.516
# >>> EPOCH:549 averTrainLoss:0.439 averTestLoss:0.516
# >>> EPOCH:550 averTrainLoss:0.454 averTestLoss:0.515
# >>> EPOCH:551 averTrainLoss:0.474 averTestLoss:0.515
# >>> EPOCH:552 averTrainLoss:0.455 averTestLoss:0.514
# >>> EPOCH:553 averTrainLoss:0.428 averTestLoss:0.513
# >>> EPOCH:554 averTrainLoss:0.466 averTestLoss:0.513
# >>> EPOCH:555 averTrainLoss:0.458 averTestLoss:0.514
# >>> EPOCH:556 averTrainLoss:0.440 averTestLoss:0.514
# >>> EPOCH:557 averTrainLoss:0.444 averTestLoss:0.514
# >>> EPOCH:558 averTrainLoss:0.483 averTestLoss:0.513
# >>> EPOCH:559 averTrainLoss:0.453 averTestLoss:0.513
# >>> EPOCH:560 averTrainLoss:0.464 averTestLoss:0.512
# >>> EPOCH:561 averTrainLoss:0.481 averTestLoss:0.512
# >>> EPOCH:562 averTrainLoss:0.447 averTestLoss:0.512
# >>> EPOCH:563 averTrainLoss:0.449 averTestLoss:0.513
# >>> EPOCH:564 averTrainLoss:0.455 averTestLoss:0.514
# >>> EPOCH:565 averTrainLoss:0.446 averTestLoss:0.514
# >>> EPOCH:566 averTrainLoss:0.463 averTestLoss:0.513
# >>> EPOCH:567 averTrainLoss:0.460 averTestLoss:0.512
# >>> EPOCH:568 averTrainLoss:0.441 averTestLoss:0.511
# >>> EPOCH:569 averTrainLoss:0.456 averTestLoss:0.510
# >>> EPOCH:570 averTrainLoss:0.454 averTestLoss:0.511
# >>> EPOCH:571 averTrainLoss:0.451 averTestLoss:0.513
# >>> EPOCH:572 averTrainLoss:0.434 averTestLoss:0.513
# >>> EPOCH:573 averTrainLoss:0.466 averTestLoss:0.513
# >>> EPOCH:574 averTrainLoss:0.454 averTestLoss:0.512
# >>> EPOCH:575 averTrainLoss:0.447 averTestLoss:0.512
# >>> EPOCH:576 averTrainLoss:0.470 averTestLoss:0.511
# >>> EPOCH:577 averTrainLoss:0.451 averTestLoss:0.511
# >>> EPOCH:578 averTrainLoss:0.464 averTestLoss:0.512
# >>> EPOCH:579 averTrainLoss:0.455 averTestLoss:0.512
# >>> EPOCH:580 averTrainLoss:0.440 averTestLoss:0.513
# >>> EPOCH:581 averTrainLoss:0.454 averTestLoss:0.512
# >>> EPOCH:582 averTrainLoss:0.463 averTestLoss:0.512
# >>> EPOCH:583 averTrainLoss:0.405 averTestLoss:0.511
# >>> EPOCH:584 averTrainLoss:0.439 averTestLoss:0.511
# >>> EPOCH:585 averTrainLoss:0.442 averTestLoss:0.513
# >>> EPOCH:586 averTrainLoss:0.441 averTestLoss:0.515
# >>> EPOCH:587 averTrainLoss:0.479 averTestLoss:0.518
# >>> EPOCH:588 averTrainLoss:0.456 averTestLoss:0.520
# >>> EPOCH:589 averTrainLoss:0.471 averTestLoss:0.522
# >>> EPOCH:590 averTrainLoss:0.454 averTestLoss:0.521
# >>> EPOCH:591 averTrainLoss:0.411 averTestLoss:0.519
# >>> EPOCH:592 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:593 averTrainLoss:0.456 averTestLoss:0.516
# >>> EPOCH:594 averTrainLoss:0.459 averTestLoss:0.515
# >>> EPOCH:595 averTrainLoss:0.448 averTestLoss:0.513
# >>> EPOCH:596 averTrainLoss:0.462 averTestLoss:0.513
# >>> EPOCH:597 averTrainLoss:0.430 averTestLoss:0.512
# >>> EPOCH:598 averTrainLoss:0.464 averTestLoss:0.512
# >>> EPOCH:599 averTrainLoss:0.454 averTestLoss:0.511
# >>> EPOCH:600 averTrainLoss:0.467 averTestLoss:0.514
# >>> EPOCH:601 averTrainLoss:0.448 averTestLoss:0.515
# >>> EPOCH:602 averTrainLoss:0.449 averTestLoss:0.516
# >>> EPOCH:603 averTrainLoss:0.450 averTestLoss:0.516
# >>> EPOCH:604 averTrainLoss:0.458 averTestLoss:0.515
# >>> EPOCH:605 averTrainLoss:0.439 averTestLoss:0.515
# >>> EPOCH:606 averTrainLoss:0.458 averTestLoss:0.515
# >>> EPOCH:607 averTrainLoss:0.433 averTestLoss:0.515
# >>> EPOCH:608 averTrainLoss:0.453 averTestLoss:0.515
# >>> EPOCH:609 averTrainLoss:0.458 averTestLoss:0.512
# >>> EPOCH:610 averTrainLoss:0.452 averTestLoss:0.512
# >>> EPOCH:611 averTrainLoss:0.443 averTestLoss:0.512
# >>> EPOCH:612 averTrainLoss:0.438 averTestLoss:0.512
# >>> EPOCH:613 averTrainLoss:0.440 averTestLoss:0.511
# >>> EPOCH:614 averTrainLoss:0.457 averTestLoss:0.510
# >>> EPOCH:615 averTrainLoss:0.440 averTestLoss:0.510
# >>> EPOCH:616 averTrainLoss:0.460 averTestLoss:0.510
# >>> EPOCH:617 averTrainLoss:0.435 averTestLoss:0.511
# >>> EPOCH:618 averTrainLoss:0.457 averTestLoss:0.512
# >>> EPOCH:619 averTrainLoss:0.439 averTestLoss:0.513
# >>> EPOCH:620 averTrainLoss:0.439 averTestLoss:0.517
# >>> EPOCH:621 averTrainLoss:0.461 averTestLoss:0.520
# >>> EPOCH:622 averTrainLoss:0.473 averTestLoss:0.521
# >>> EPOCH:623 averTrainLoss:0.463 averTestLoss:0.519
# >>> EPOCH:624 averTrainLoss:0.457 averTestLoss:0.516
# >>> EPOCH:625 averTrainLoss:0.451 averTestLoss:0.514
# >>> EPOCH:626 averTrainLoss:0.477 averTestLoss:0.513
# >>> EPOCH:627 averTrainLoss:0.427 averTestLoss:0.509
# >>> EPOCH:628 averTrainLoss:0.463 averTestLoss:0.508
# >>> EPOCH:629 averTrainLoss:0.450 averTestLoss:0.514
# >>> EPOCH:630 averTrainLoss:0.466 averTestLoss:0.519
# >>> EPOCH:631 averTrainLoss:0.456 averTestLoss:0.519
# >>> EPOCH:632 averTrainLoss:0.446 averTestLoss:0.516
# >>> EPOCH:633 averTrainLoss:0.431 averTestLoss:0.512
# >>> EPOCH:634 averTrainLoss:0.473 averTestLoss:0.509
# >>> EPOCH:635 averTrainLoss:0.461 averTestLoss:0.509
# >>> EPOCH:636 averTrainLoss:0.476 averTestLoss:0.509
# >>> EPOCH:637 averTrainLoss:0.465 averTestLoss:0.510
# >>> EPOCH:638 averTrainLoss:0.488 averTestLoss:0.510
# >>> EPOCH:639 averTrainLoss:0.458 averTestLoss:0.513
# >>> EPOCH:640 averTrainLoss:0.473 averTestLoss:0.517
# >>> EPOCH:641 averTrainLoss:0.446 averTestLoss:0.518
# >>> EPOCH:642 averTrainLoss:0.423 averTestLoss:0.516
# >>> EPOCH:643 averTrainLoss:0.427 averTestLoss:0.512
# >>> EPOCH:644 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:645 averTrainLoss:0.454 averTestLoss:0.511
# >>> EPOCH:646 averTrainLoss:0.459 averTestLoss:0.511
# >>> EPOCH:647 averTrainLoss:0.445 averTestLoss:0.512
# >>> EPOCH:648 averTrainLoss:0.449 averTestLoss:0.514
# >>> EPOCH:649 averTrainLoss:0.449 averTestLoss:0.516
# >>> EPOCH:650 averTrainLoss:0.454 averTestLoss:0.516
# >>> EPOCH:651 averTrainLoss:0.473 averTestLoss:0.516
# >>> EPOCH:652 averTrainLoss:0.446 averTestLoss:0.515
# >>> EPOCH:653 averTrainLoss:0.436 averTestLoss:0.513
# >>> EPOCH:654 averTrainLoss:0.449 averTestLoss:0.512
# >>> EPOCH:655 averTrainLoss:0.438 averTestLoss:0.512
# >>> EPOCH:656 averTrainLoss:0.456 averTestLoss:0.513
# >>> EPOCH:657 averTrainLoss:0.450 averTestLoss:0.514
# >>> EPOCH:658 averTrainLoss:0.452 averTestLoss:0.516
# >>> EPOCH:659 averTrainLoss:0.454 averTestLoss:0.518
# >>> EPOCH:660 averTrainLoss:0.462 averTestLoss:0.517
# >>> EPOCH:661 averTrainLoss:0.465 averTestLoss:0.515
# >>> EPOCH:662 averTrainLoss:0.466 averTestLoss:0.512
# >>> EPOCH:663 averTrainLoss:0.437 averTestLoss:0.508
# >>> EPOCH:664 averTrainLoss:0.474 averTestLoss:0.508
# >>> EPOCH:665 averTrainLoss:0.452 averTestLoss:0.511
# >>> EPOCH:666 averTrainLoss:0.462 averTestLoss:0.512
# >>> EPOCH:667 averTrainLoss:0.454 averTestLoss:0.513
# >>> EPOCH:668 averTrainLoss:0.451 averTestLoss:0.515
# >>> EPOCH:669 averTrainLoss:0.450 averTestLoss:0.515
# >>> EPOCH:670 averTrainLoss:0.473 averTestLoss:0.516
# >>> EPOCH:671 averTrainLoss:0.462 averTestLoss:0.517
# >>> EPOCH:672 averTrainLoss:0.453 averTestLoss:0.516
# >>> EPOCH:673 averTrainLoss:0.448 averTestLoss:0.515
# >>> EPOCH:674 averTrainLoss:0.433 averTestLoss:0.511
# >>> EPOCH:675 averTrainLoss:0.456 averTestLoss:0.508
# >>> EPOCH:676 averTrainLoss:0.463 averTestLoss:0.508
# >>> EPOCH:677 averTrainLoss:0.466 averTestLoss:0.509
# >>> EPOCH:678 averTrainLoss:0.425 averTestLoss:0.514
# >>> EPOCH:679 averTrainLoss:0.489 averTestLoss:0.517
# >>> EPOCH:680 averTrainLoss:0.465 averTestLoss:0.518
# >>> EPOCH:681 averTrainLoss:0.459 averTestLoss:0.516
# >>> EPOCH:682 averTrainLoss:0.453 averTestLoss:0.514
# >>> EPOCH:683 averTrainLoss:0.442 averTestLoss:0.513
# >>> EPOCH:684 averTrainLoss:0.443 averTestLoss:0.512
# >>> EPOCH:685 averTrainLoss:0.436 averTestLoss:0.513
# >>> EPOCH:686 averTrainLoss:0.446 averTestLoss:0.514
# >>> EPOCH:687 averTrainLoss:0.437 averTestLoss:0.516
# >>> EPOCH:688 averTrainLoss:0.469 averTestLoss:0.515
# >>> EPOCH:689 averTrainLoss:0.450 averTestLoss:0.514
# >>> EPOCH:690 averTrainLoss:0.474 averTestLoss:0.510
# >>> EPOCH:691 averTrainLoss:0.448 averTestLoss:0.506
# >>> EPOCH:692 averTrainLoss:0.452 averTestLoss:0.504
# >>> EPOCH:693 averTrainLoss:0.467 averTestLoss:0.507
# >>> EPOCH:694 averTrainLoss:0.451 averTestLoss:0.510
# >>> EPOCH:695 averTrainLoss:0.436 averTestLoss:0.512
# >>> EPOCH:696 averTrainLoss:0.484 averTestLoss:0.517
# >>> EPOCH:697 averTrainLoss:0.457 averTestLoss:0.520
# >>> EPOCH:698 averTrainLoss:0.458 averTestLoss:0.523
# >>> EPOCH:699 averTrainLoss:0.466 averTestLoss:0.523
# >>> EPOCH:700 averTrainLoss:0.448 averTestLoss:0.520
# >>> EPOCH:701 averTrainLoss:0.435 averTestLoss:0.515
# >>> EPOCH:702 averTrainLoss:0.465 averTestLoss:0.510
# >>> EPOCH:703 averTrainLoss:0.467 averTestLoss:0.508
# >>> EPOCH:704 averTrainLoss:0.451 averTestLoss:0.505
# >>> EPOCH:705 averTrainLoss:0.475 averTestLoss:0.505
# >>> EPOCH:706 averTrainLoss:0.445 averTestLoss:0.508
# >>> EPOCH:707 averTrainLoss:0.465 averTestLoss:0.511
# >>> EPOCH:708 averTrainLoss:0.451 averTestLoss:0.516
# >>> EPOCH:709 averTrainLoss:0.448 averTestLoss:0.519
# >>> EPOCH:710 averTrainLoss:0.459 averTestLoss:0.524
# >>> EPOCH:711 averTrainLoss:0.471 averTestLoss:0.525
# >>> EPOCH:712 averTrainLoss:0.439 averTestLoss:0.523
# >>> EPOCH:713 averTrainLoss:0.451 averTestLoss:0.521
# >>> EPOCH:714 averTrainLoss:0.460 averTestLoss:0.519
# >>> EPOCH:715 averTrainLoss:0.441 averTestLoss:0.517
# >>> EPOCH:716 averTrainLoss:0.452 averTestLoss:0.515
# >>> EPOCH:717 averTrainLoss:0.448 averTestLoss:0.513
# >>> EPOCH:718 averTrainLoss:0.450 averTestLoss:0.512
# >>> EPOCH:719 averTrainLoss:0.452 averTestLoss:0.513
# >>> EPOCH:720 averTrainLoss:0.440 averTestLoss:0.513
# >>> EPOCH:721 averTrainLoss:0.444 averTestLoss:0.514
# >>> EPOCH:722 averTrainLoss:0.452 averTestLoss:0.514
# >>> EPOCH:723 averTrainLoss:0.433 averTestLoss:0.513
# >>> EPOCH:724 averTrainLoss:0.436 averTestLoss:0.513
# >>> EPOCH:725 averTrainLoss:0.443 averTestLoss:0.513
# >>> EPOCH:726 averTrainLoss:0.461 averTestLoss:0.513
# >>> EPOCH:727 averTrainLoss:0.474 averTestLoss:0.514
# >>> EPOCH:728 averTrainLoss:0.460 averTestLoss:0.518
# >>> EPOCH:729 averTrainLoss:0.450 averTestLoss:0.519
# >>> EPOCH:730 averTrainLoss:0.451 averTestLoss:0.520
# >>> EPOCH:731 averTrainLoss:0.442 averTestLoss:0.520
# >>> EPOCH:732 averTrainLoss:0.474 averTestLoss:0.519
# >>> EPOCH:733 averTrainLoss:0.443 averTestLoss:0.517
# >>> EPOCH:734 averTrainLoss:0.457 averTestLoss:0.515
# >>> EPOCH:735 averTrainLoss:0.464 averTestLoss:0.512
# >>> EPOCH:736 averTrainLoss:0.482 averTestLoss:0.512
# >>> EPOCH:737 averTrainLoss:0.456 averTestLoss:0.514
# >>> EPOCH:738 averTrainLoss:0.456 averTestLoss:0.517
# >>> EPOCH:739 averTrainLoss:0.431 averTestLoss:0.519
# >>> EPOCH:740 averTrainLoss:0.451 averTestLoss:0.520
# >>> EPOCH:741 averTrainLoss:0.466 averTestLoss:0.518
# >>> EPOCH:742 averTrainLoss:0.448 averTestLoss:0.513
# >>> EPOCH:743 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:744 averTrainLoss:0.448 averTestLoss:0.511
# >>> EPOCH:745 averTrainLoss:0.451 averTestLoss:0.511
# >>> EPOCH:746 averTrainLoss:0.441 averTestLoss:0.511
# >>> EPOCH:747 averTrainLoss:0.463 averTestLoss:0.515
# >>> EPOCH:748 averTrainLoss:0.444 averTestLoss:0.517
# >>> EPOCH:749 averTrainLoss:0.481 averTestLoss:0.518
# >>> EPOCH:750 averTrainLoss:0.436 averTestLoss:0.517
# >>> EPOCH:751 averTrainLoss:0.463 averTestLoss:0.513
# >>> EPOCH:752 averTrainLoss:0.415 averTestLoss:0.511
# >>> EPOCH:753 averTrainLoss:0.448 averTestLoss:0.511
# >>> EPOCH:754 averTrainLoss:0.454 averTestLoss:0.511
# >>> EPOCH:755 averTrainLoss:0.450 averTestLoss:0.511
# >>> EPOCH:756 averTrainLoss:0.453 averTestLoss:0.512
# >>> EPOCH:757 averTrainLoss:0.445 averTestLoss:0.519
# >>> EPOCH:758 averTrainLoss:0.442 averTestLoss:0.527
# >>> EPOCH:759 averTrainLoss:0.451 averTestLoss:0.528
# >>> EPOCH:760 averTrainLoss:0.463 averTestLoss:0.523
# >>> EPOCH:761 averTrainLoss:0.455 averTestLoss:0.518
# >>> EPOCH:762 averTrainLoss:0.438 averTestLoss:0.514
# >>> EPOCH:763 averTrainLoss:0.463 averTestLoss:0.512
# >>> EPOCH:764 averTrainLoss:0.458 averTestLoss:0.512
# >>> EPOCH:765 averTrainLoss:0.466 averTestLoss:0.513
# >>> EPOCH:766 averTrainLoss:0.452 averTestLoss:0.515
# >>> EPOCH:767 averTrainLoss:0.432 averTestLoss:0.516
# >>> EPOCH:768 averTrainLoss:0.441 averTestLoss:0.518
# >>> EPOCH:769 averTrainLoss:0.449 averTestLoss:0.518
# >>> EPOCH:770 averTrainLoss:0.458 averTestLoss:0.518
# >>> EPOCH:771 averTrainLoss:0.468 averTestLoss:0.517
# >>> EPOCH:772 averTrainLoss:0.467 averTestLoss:0.517
# >>> EPOCH:773 averTrainLoss:0.457 averTestLoss:0.517
# >>> EPOCH:774 averTrainLoss:0.429 averTestLoss:0.517
# >>> EPOCH:775 averTrainLoss:0.456 averTestLoss:0.517
# >>> EPOCH:776 averTrainLoss:0.434 averTestLoss:0.515
# >>> EPOCH:777 averTrainLoss:0.458 averTestLoss:0.514
# >>> EPOCH:778 averTrainLoss:0.439 averTestLoss:0.512
# >>> EPOCH:779 averTrainLoss:0.467 averTestLoss:0.511
# >>> EPOCH:780 averTrainLoss:0.446 averTestLoss:0.511
# >>> EPOCH:781 averTrainLoss:0.472 averTestLoss:0.512
# >>> EPOCH:782 averTrainLoss:0.444 averTestLoss:0.514
# >>> EPOCH:783 averTrainLoss:0.444 averTestLoss:0.516
# >>> EPOCH:784 averTrainLoss:0.455 averTestLoss:0.517
# >>> EPOCH:785 averTrainLoss:0.476 averTestLoss:0.515
# >>> EPOCH:786 averTrainLoss:0.426 averTestLoss:0.513
# >>> EPOCH:787 averTrainLoss:0.464 averTestLoss:0.512
# >>> EPOCH:788 averTrainLoss:0.467 averTestLoss:0.513
# >>> EPOCH:789 averTrainLoss:0.439 averTestLoss:0.516
# >>> EPOCH:790 averTrainLoss:0.433 averTestLoss:0.518
# >>> EPOCH:791 averTrainLoss:0.460 averTestLoss:0.521
# >>> EPOCH:792 averTrainLoss:0.466 averTestLoss:0.521
# >>> EPOCH:793 averTrainLoss:0.457 averTestLoss:0.521
# >>> EPOCH:794 averTrainLoss:0.446 averTestLoss:0.519
# >>> EPOCH:795 averTrainLoss:0.453 averTestLoss:0.515
# >>> EPOCH:796 averTrainLoss:0.428 averTestLoss:0.512
# >>> EPOCH:797 averTrainLoss:0.446 averTestLoss:0.510
# >>> EPOCH:798 averTrainLoss:0.443 averTestLoss:0.508
# >>> EPOCH:799 averTrainLoss:0.455 averTestLoss:0.511
# >>> EPOCH:800 averTrainLoss:0.432 averTestLoss:0.517
# >>> EPOCH:801 averTrainLoss:0.462 averTestLoss:0.521
# >>> EPOCH:802 averTrainLoss:0.451 averTestLoss:0.525
# >>> EPOCH:803 averTrainLoss:0.452 averTestLoss:0.526
# >>> EPOCH:804 averTrainLoss:0.462 averTestLoss:0.524
# >>> EPOCH:805 averTrainLoss:0.453 averTestLoss:0.519
# >>> EPOCH:806 averTrainLoss:0.465 averTestLoss:0.515
# >>> EPOCH:807 averTrainLoss:0.443 averTestLoss:0.515
# >>> EPOCH:808 averTrainLoss:0.467 averTestLoss:0.515
# >>> EPOCH:809 averTrainLoss:0.458 averTestLoss:0.511
# >>> EPOCH:810 averTrainLoss:0.467 averTestLoss:0.510
# >>> EPOCH:811 averTrainLoss:0.442 averTestLoss:0.512
# >>> EPOCH:812 averTrainLoss:0.471 averTestLoss:0.511
# >>> EPOCH:813 averTrainLoss:0.429 averTestLoss:0.511
# >>> EPOCH:814 averTrainLoss:0.453 averTestLoss:0.514
# >>> EPOCH:815 averTrainLoss:0.455 averTestLoss:0.515
# >>> EPOCH:816 averTrainLoss:0.491 averTestLoss:0.515
# >>> EPOCH:817 averTrainLoss:0.411 averTestLoss:0.515
# >>> EPOCH:818 averTrainLoss:0.464 averTestLoss:0.515
# >>> EPOCH:819 averTrainLoss:0.449 averTestLoss:0.516
# >>> EPOCH:820 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:821 averTrainLoss:0.453 averTestLoss:0.517
# >>> EPOCH:822 averTrainLoss:0.456 averTestLoss:0.517
# >>> EPOCH:823 averTrainLoss:0.460 averTestLoss:0.514
# >>> EPOCH:824 averTrainLoss:0.457 averTestLoss:0.512
# >>> EPOCH:825 averTrainLoss:0.466 averTestLoss:0.509
# >>> EPOCH:826 averTrainLoss:0.444 averTestLoss:0.510
# >>> EPOCH:827 averTrainLoss:0.447 averTestLoss:0.510
# >>> EPOCH:828 averTrainLoss:0.484 averTestLoss:0.511
# >>> EPOCH:829 averTrainLoss:0.439 averTestLoss:0.513
# >>> EPOCH:830 averTrainLoss:0.446 averTestLoss:0.514
# >>> EPOCH:831 averTrainLoss:0.443 averTestLoss:0.515
# >>> EPOCH:832 averTrainLoss:0.424 averTestLoss:0.517
# >>> EPOCH:833 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:834 averTrainLoss:0.426 averTestLoss:0.516
# >>> EPOCH:835 averTrainLoss:0.417 averTestLoss:0.515
# >>> EPOCH:836 averTrainLoss:0.456 averTestLoss:0.513
# >>> EPOCH:837 averTrainLoss:0.469 averTestLoss:0.513
# >>> EPOCH:838 averTrainLoss:0.440 averTestLoss:0.514
# >>> EPOCH:839 averTrainLoss:0.432 averTestLoss:0.515
# >>> EPOCH:840 averTrainLoss:0.456 averTestLoss:0.517
# >>> EPOCH:841 averTrainLoss:0.433 averTestLoss:0.519
# >>> EPOCH:842 averTrainLoss:0.455 averTestLoss:0.518
# >>> EPOCH:843 averTrainLoss:0.447 averTestLoss:0.515
# >>> EPOCH:844 averTrainLoss:0.455 averTestLoss:0.513
# >>> EPOCH:845 averTrainLoss:0.472 averTestLoss:0.512
# >>> EPOCH:846 averTrainLoss:0.444 averTestLoss:0.510
# >>> EPOCH:847 averTrainLoss:0.442 averTestLoss:0.513
# >>> EPOCH:848 averTrainLoss:0.441 averTestLoss:0.519
# >>> EPOCH:849 averTrainLoss:0.456 averTestLoss:0.523
# >>> EPOCH:850 averTrainLoss:0.451 averTestLoss:0.522
# >>> EPOCH:851 averTrainLoss:0.475 averTestLoss:0.519
# >>> EPOCH:852 averTrainLoss:0.459 averTestLoss:0.515
# >>> EPOCH:853 averTrainLoss:0.452 averTestLoss:0.512
# >>> EPOCH:854 averTrainLoss:0.476 averTestLoss:0.510
# >>> EPOCH:855 averTrainLoss:0.452 averTestLoss:0.509
# >>> EPOCH:856 averTrainLoss:0.455 averTestLoss:0.509
# >>> EPOCH:857 averTrainLoss:0.449 averTestLoss:0.511
# >>> EPOCH:858 averTrainLoss:0.457 averTestLoss:0.514
# >>> EPOCH:859 averTrainLoss:0.453 averTestLoss:0.519
# >>> EPOCH:860 averTrainLoss:0.478 averTestLoss:0.521
# >>> EPOCH:861 averTrainLoss:0.437 averTestLoss:0.522
# >>> EPOCH:862 averTrainLoss:0.483 averTestLoss:0.521
# >>> EPOCH:863 averTrainLoss:0.451 averTestLoss:0.522
# >>> EPOCH:864 averTrainLoss:0.454 averTestLoss:0.523
# >>> EPOCH:865 averTrainLoss:0.418 averTestLoss:0.525
# >>> EPOCH:866 averTrainLoss:0.457 averTestLoss:0.524
# >>> EPOCH:867 averTrainLoss:0.457 averTestLoss:0.521
# >>> EPOCH:868 averTrainLoss:0.441 averTestLoss:0.518
# >>> EPOCH:869 averTrainLoss:0.445 averTestLoss:0.515
# >>> EPOCH:870 averTrainLoss:0.449 averTestLoss:0.512
# >>> EPOCH:871 averTrainLoss:0.449 averTestLoss:0.510
# >>> EPOCH:872 averTrainLoss:0.434 averTestLoss:0.510
# >>> EPOCH:873 averTrainLoss:0.452 averTestLoss:0.510
# >>> EPOCH:874 averTrainLoss:0.445 averTestLoss:0.511
# >>> EPOCH:875 averTrainLoss:0.486 averTestLoss:0.513
# >>> EPOCH:876 averTrainLoss:0.445 averTestLoss:0.515
# >>> EPOCH:877 averTrainLoss:0.439 averTestLoss:0.516
# >>> EPOCH:878 averTrainLoss:0.457 averTestLoss:0.516
# >>> EPOCH:879 averTrainLoss:0.444 averTestLoss:0.514
# >>> EPOCH:880 averTrainLoss:0.436 averTestLoss:0.511
# >>> EPOCH:881 averTrainLoss:0.469 averTestLoss:0.511
# >>> EPOCH:882 averTrainLoss:0.481 averTestLoss:0.514
# >>> EPOCH:883 averTrainLoss:0.491 averTestLoss:0.516
# >>> EPOCH:884 averTrainLoss:0.452 averTestLoss:0.515
# >>> EPOCH:885 averTrainLoss:0.423 averTestLoss:0.515
# >>> EPOCH:886 averTrainLoss:0.477 averTestLoss:0.516
# >>> EPOCH:887 averTrainLoss:0.467 averTestLoss:0.516
# >>> EPOCH:888 averTrainLoss:0.438 averTestLoss:0.517
# >>> EPOCH:889 averTrainLoss:0.444 averTestLoss:0.516
# >>> EPOCH:890 averTrainLoss:0.426 averTestLoss:0.515
# >>> EPOCH:891 averTrainLoss:0.468 averTestLoss:0.513
# >>> EPOCH:892 averTrainLoss:0.446 averTestLoss:0.509
# >>> EPOCH:893 averTrainLoss:0.436 averTestLoss:0.507
# >>> EPOCH:894 averTrainLoss:0.479 averTestLoss:0.509
# >>> EPOCH:895 averTrainLoss:0.459 averTestLoss:0.510
# >>> EPOCH:896 averTrainLoss:0.461 averTestLoss:0.514
# >>> EPOCH:897 averTrainLoss:0.424 averTestLoss:0.516
# >>> EPOCH:898 averTrainLoss:0.454 averTestLoss:0.517
# >>> EPOCH:899 averTrainLoss:0.443 averTestLoss:0.518
# >>> EPOCH:900 averTrainLoss:0.464 averTestLoss:0.518
# >>> EPOCH:901 averTrainLoss:0.445 averTestLoss:0.517
# >>> EPOCH:902 averTrainLoss:0.439 averTestLoss:0.517
# >>> EPOCH:903 averTrainLoss:0.424 averTestLoss:0.516
# >>> EPOCH:904 averTrainLoss:0.448 averTestLoss:0.514
# >>> EPOCH:905 averTrainLoss:0.449 averTestLoss:0.511
# >>> EPOCH:906 averTrainLoss:0.461 averTestLoss:0.510
# >>> EPOCH:907 averTrainLoss:0.434 averTestLoss:0.513
# ...
# >>> EPOCH:9705 averTrainLoss:0.489 averTestLoss:0.522
# >>> EPOCH:9706 averTrainLoss:0.418 averTestLoss:0.523
# >>> EPOCH:9707 averTrainLoss:0.444 averTestLoss:0.522
# >>> EPOCH:9708 averTrainLoss:0.480 averTestLoss:0.520
# >>> EPOCH:9709 averTrainLoss:0.451 averTestLoss:0.518
# >>> EPOCH:9710 averTrainLoss:0.473 averTestLoss:0.516
# >>> EPOCH:9711 averTrainLoss:0.427 averTestLoss:0.515
# >>> EPOCH:9712 averTrainLoss:0.451 averTestLoss:0.517
# >>> EPOCH:9713 averTrainLoss:0.441 averTestLoss:0.519
# >>> EPOCH:9714 averTrainLoss:0.427 averTestLoss:0.520
# >>> EPOCH:9715 averTrainLoss:0.448 averTestLoss:0.521
# >>> EPOCH:9716 averTrainLoss:0.439 averTestLoss:0.521
# >>> EPOCH:9717 averTrainLoss:0.446 averTestLoss:0.521
# >>> EPOCH:9718 averTrainLoss:0.460 averTestLoss:0.520
# >>> EPOCH:9719 averTrainLoss:0.440 averTestLoss:0.519
# >>> EPOCH:9720 averTrainLoss:0.446 averTestLoss:0.516
# >>> EPOCH:9721 averTrainLoss:0.418 averTestLoss:0.512
# >>> EPOCH:9722 averTrainLoss:0.438 averTestLoss:0.509
# >>> EPOCH:9723 averTrainLoss:0.460 averTestLoss:0.508
# >>> EPOCH:9724 averTrainLoss:0.441 averTestLoss:0.509
# >>> EPOCH:9725 averTrainLoss:0.461 averTestLoss:0.509
# >>> EPOCH:9726 averTrainLoss:0.472 averTestLoss:0.512
# >>> EPOCH:9727 averTrainLoss:0.443 averTestLoss:0.519
# >>> EPOCH:9728 averTrainLoss:0.402 averTestLoss:0.523
# >>> EPOCH:9729 averTrainLoss:0.443 averTestLoss:0.525
# >>> EPOCH:9730 averTrainLoss:0.457 averTestLoss:0.525
# >>> EPOCH:9731 averTrainLoss:0.481 averTestLoss:0.526
# >>> EPOCH:9732 averTrainLoss:0.442 averTestLoss:0.524
# >>> EPOCH:9733 averTrainLoss:0.423 averTestLoss:0.522
# >>> EPOCH:9734 averTrainLoss:0.460 averTestLoss:0.518
# >>> EPOCH:9735 averTrainLoss:0.456 averTestLoss:0.513
# >>> EPOCH:9736 averTrainLoss:0.451 averTestLoss:0.511
# >>> EPOCH:9737 averTrainLoss:0.437 averTestLoss:0.514
# >>> EPOCH:9738 averTrainLoss:0.447 averTestLoss:0.517
# >>> EPOCH:9739 averTrainLoss:0.455 averTestLoss:0.519
# >>> EPOCH:9740 averTrainLoss:0.448 averTestLoss:0.518
# >>> EPOCH:9741 averTrainLoss:0.442 averTestLoss:0.520
# >>> EPOCH:9742 averTrainLoss:0.454 averTestLoss:0.522
# >>> EPOCH:9743 averTrainLoss:0.440 averTestLoss:0.523
# >>> EPOCH:9744 averTrainLoss:0.460 averTestLoss:0.524
# >>> EPOCH:9745 averTrainLoss:0.442 averTestLoss:0.524
# >>> EPOCH:9746 averTrainLoss:0.457 averTestLoss:0.523
# >>> EPOCH:9747 averTrainLoss:0.439 averTestLoss:0.522
# >>> EPOCH:9748 averTrainLoss:0.454 averTestLoss:0.519
# >>> EPOCH:9749 averTrainLoss:0.443 averTestLoss:0.515
# >>> EPOCH:9750 averTrainLoss:0.448 averTestLoss:0.514
# >>> EPOCH:9751 averTrainLoss:0.486 averTestLoss:0.516
# >>> EPOCH:9752 averTrainLoss:0.440 averTestLoss:0.519
# >>> EPOCH:9753 averTrainLoss:0.431 averTestLoss:0.521
# >>> EPOCH:9754 averTrainLoss:0.467 averTestLoss:0.522
# >>> EPOCH:9755 averTrainLoss:0.440 averTestLoss:0.523
# >>> EPOCH:9756 averTrainLoss:0.470 averTestLoss:0.522
# >>> EPOCH:9757 averTrainLoss:0.460 averTestLoss:0.521
# >>> EPOCH:9758 averTrainLoss:0.447 averTestLoss:0.518
# >>> EPOCH:9759 averTrainLoss:0.433 averTestLoss:0.517
# >>> EPOCH:9760 averTrainLoss:0.442 averTestLoss:0.517
# >>> EPOCH:9761 averTrainLoss:0.449 averTestLoss:0.516
# >>> EPOCH:9762 averTrainLoss:0.423 averTestLoss:0.516
# >>> EPOCH:9763 averTrainLoss:0.458 averTestLoss:0.516
# >>> EPOCH:9764 averTrainLoss:0.455 averTestLoss:0.518
# >>> EPOCH:9765 averTrainLoss:0.444 averTestLoss:0.519
# >>> EPOCH:9766 averTrainLoss:0.439 averTestLoss:0.518
# >>> EPOCH:9767 averTrainLoss:0.465 averTestLoss:0.517
# >>> EPOCH:9768 averTrainLoss:0.466 averTestLoss:0.518
# >>> EPOCH:9769 averTrainLoss:0.483 averTestLoss:0.518
# >>> EPOCH:9770 averTrainLoss:0.467 averTestLoss:0.519
# >>> EPOCH:9771 averTrainLoss:0.466 averTestLoss:0.519
# >>> EPOCH:9772 averTrainLoss:0.451 averTestLoss:0.515
# >>> EPOCH:9773 averTrainLoss:0.448 averTestLoss:0.512
# >>> EPOCH:9774 averTrainLoss:0.455 averTestLoss:0.509
# >>> EPOCH:9775 averTrainLoss:0.458 averTestLoss:0.508
# >>> EPOCH:9776 averTrainLoss:0.443 averTestLoss:0.509
# >>> EPOCH:9777 averTrainLoss:0.440 averTestLoss:0.511
# >>> EPOCH:9778 averTrainLoss:0.459 averTestLoss:0.513
# >>> EPOCH:9779 averTrainLoss:0.433 averTestLoss:0.515
# >>> EPOCH:9780 averTrainLoss:0.457 averTestLoss:0.517
# >>> EPOCH:9781 averTrainLoss:0.447 averTestLoss:0.519
# >>> EPOCH:9782 averTrainLoss:0.424 averTestLoss:0.519
# >>> EPOCH:9783 averTrainLoss:0.451 averTestLoss:0.519
# >>> EPOCH:9784 averTrainLoss:0.452 averTestLoss:0.517
# >>> EPOCH:9785 averTrainLoss:0.451 averTestLoss:0.516
# >>> EPOCH:9786 averTrainLoss:0.432 averTestLoss:0.515
# >>> EPOCH:9787 averTrainLoss:0.431 averTestLoss:0.515
# >>> EPOCH:9788 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:9789 averTrainLoss:0.459 averTestLoss:0.517
# >>> EPOCH:9790 averTrainLoss:0.445 averTestLoss:0.518
# >>> EPOCH:9791 averTrainLoss:0.472 averTestLoss:0.521
# >>> EPOCH:9792 averTrainLoss:0.460 averTestLoss:0.521
# >>> EPOCH:9793 averTrainLoss:0.447 averTestLoss:0.519
# >>> EPOCH:9794 averTrainLoss:0.429 averTestLoss:0.517
# >>> EPOCH:9795 averTrainLoss:0.453 averTestLoss:0.515
# >>> EPOCH:9796 averTrainLoss:0.450 averTestLoss:0.514
# >>> EPOCH:9797 averTrainLoss:0.444 averTestLoss:0.515
# >>> EPOCH:9798 averTrainLoss:0.432 averTestLoss:0.516
# >>> EPOCH:9799 averTrainLoss:0.437 averTestLoss:0.516
# >>> EPOCH:9800 averTrainLoss:0.448 averTestLoss:0.517
# >>> EPOCH:9801 averTrainLoss:0.464 averTestLoss:0.518
# >>> EPOCH:9802 averTrainLoss:0.469 averTestLoss:0.521
# >>> EPOCH:9803 averTrainLoss:0.475 averTestLoss:0.524
# >>> EPOCH:9804 averTrainLoss:0.447 averTestLoss:0.525
# >>> EPOCH:9805 averTrainLoss:0.455 averTestLoss:0.523
# >>> EPOCH:9806 averTrainLoss:0.439 averTestLoss:0.520
# >>> EPOCH:9807 averTrainLoss:0.428 averTestLoss:0.518
# >>> EPOCH:9808 averTrainLoss:0.438 averTestLoss:0.518
# >>> EPOCH:9809 averTrainLoss:0.434 averTestLoss:0.519
# >>> EPOCH:9810 averTrainLoss:0.436 averTestLoss:0.519
# >>> EPOCH:9811 averTrainLoss:0.438 averTestLoss:0.519
# >>> EPOCH:9812 averTrainLoss:0.463 averTestLoss:0.518
# >>> EPOCH:9813 averTrainLoss:0.460 averTestLoss:0.518
# >>> EPOCH:9814 averTrainLoss:0.443 averTestLoss:0.518
# >>> EPOCH:9815 averTrainLoss:0.460 averTestLoss:0.517
# >>> EPOCH:9816 averTrainLoss:0.453 averTestLoss:0.515
# >>> EPOCH:9817 averTrainLoss:0.450 averTestLoss:0.512
# >>> EPOCH:9818 averTrainLoss:0.459 averTestLoss:0.509
# >>> EPOCH:9819 averTrainLoss:0.443 averTestLoss:0.508
# >>> EPOCH:9820 averTrainLoss:0.469 averTestLoss:0.510
# >>> EPOCH:9821 averTrainLoss:0.441 averTestLoss:0.517
# >>> EPOCH:9822 averTrainLoss:0.443 averTestLoss:0.522
# >>> EPOCH:9823 averTrainLoss:0.434 averTestLoss:0.523
# >>> EPOCH:9824 averTrainLoss:0.468 averTestLoss:0.523
# >>> EPOCH:9825 averTrainLoss:0.428 averTestLoss:0.522
# >>> EPOCH:9826 averTrainLoss:0.445 averTestLoss:0.521
# >>> EPOCH:9827 averTrainLoss:0.458 averTestLoss:0.520
# >>> EPOCH:9828 averTrainLoss:0.446 averTestLoss:0.519
# >>> EPOCH:9829 averTrainLoss:0.464 averTestLoss:0.518
# >>> EPOCH:9830 averTrainLoss:0.481 averTestLoss:0.517
# >>> EPOCH:9831 averTrainLoss:0.440 averTestLoss:0.515
# >>> EPOCH:9832 averTrainLoss:0.444 averTestLoss:0.514
# >>> EPOCH:9833 averTrainLoss:0.442 averTestLoss:0.515
# >>> EPOCH:9834 averTrainLoss:0.450 averTestLoss:0.515
# >>> EPOCH:9835 averTrainLoss:0.403 averTestLoss:0.517
# >>> EPOCH:9836 averTrainLoss:0.449 averTestLoss:0.518
# >>> EPOCH:9837 averTrainLoss:0.460 averTestLoss:0.520
# >>> EPOCH:9838 averTrainLoss:0.456 averTestLoss:0.521
# >>> EPOCH:9839 averTrainLoss:0.448 averTestLoss:0.523
# >>> EPOCH:9840 averTrainLoss:0.438 averTestLoss:0.524
# >>> EPOCH:9841 averTrainLoss:0.457 averTestLoss:0.522
# >>> EPOCH:9842 averTrainLoss:0.461 averTestLoss:0.520
# >>> EPOCH:9843 averTrainLoss:0.474 averTestLoss:0.519
# >>> EPOCH:9844 averTrainLoss:0.406 averTestLoss:0.518
# >>> EPOCH:9845 averTrainLoss:0.421 averTestLoss:0.517
# >>> EPOCH:9846 averTrainLoss:0.447 averTestLoss:0.516
# >>> EPOCH:9847 averTrainLoss:0.449 averTestLoss:0.515
# >>> EPOCH:9848 averTrainLoss:0.454 averTestLoss:0.515
# >>> EPOCH:9849 averTrainLoss:0.448 averTestLoss:0.518
# >>> EPOCH:9850 averTrainLoss:0.435 averTestLoss:0.521
# >>> EPOCH:9851 averTrainLoss:0.438 averTestLoss:0.523
# >>> EPOCH:9852 averTrainLoss:0.452 averTestLoss:0.522
# >>> EPOCH:9853 averTrainLoss:0.460 averTestLoss:0.522
# >>> EPOCH:9854 averTrainLoss:0.440 averTestLoss:0.522
# >>> EPOCH:9855 averTrainLoss:0.441 averTestLoss:0.520
# >>> EPOCH:9856 averTrainLoss:0.474 averTestLoss:0.516
# >>> EPOCH:9857 averTrainLoss:0.413 averTestLoss:0.511
# >>> EPOCH:9858 averTrainLoss:0.457 averTestLoss:0.510
# >>> EPOCH:9859 averTrainLoss:0.443 averTestLoss:0.509
# >>> EPOCH:9860 averTrainLoss:0.440 averTestLoss:0.510
# >>> EPOCH:9861 averTrainLoss:0.465 averTestLoss:0.515
# >>> EPOCH:9862 averTrainLoss:0.436 averTestLoss:0.520
# >>> EPOCH:9863 averTrainLoss:0.469 averTestLoss:0.522
# >>> EPOCH:9864 averTrainLoss:0.424 averTestLoss:0.522
# >>> EPOCH:9865 averTrainLoss:0.422 averTestLoss:0.521
# >>> EPOCH:9866 averTrainLoss:0.414 averTestLoss:0.522
# >>> EPOCH:9867 averTrainLoss:0.427 averTestLoss:0.521
# >>> EPOCH:9868 averTrainLoss:0.439 averTestLoss:0.521
# >>> EPOCH:9869 averTrainLoss:0.454 averTestLoss:0.519
# >>> EPOCH:9870 averTrainLoss:0.447 averTestLoss:0.516
# >>> EPOCH:9871 averTrainLoss:0.448 averTestLoss:0.511
# >>> EPOCH:9872 averTrainLoss:0.448 averTestLoss:0.508
# >>> EPOCH:9873 averTrainLoss:0.468 averTestLoss:0.510
# >>> EPOCH:9874 averTrainLoss:0.425 averTestLoss:0.515
# >>> EPOCH:9875 averTrainLoss:0.443 averTestLoss:0.519
# >>> EPOCH:9876 averTrainLoss:0.438 averTestLoss:0.521
# >>> EPOCH:9877 averTrainLoss:0.449 averTestLoss:0.522
# >>> EPOCH:9878 averTrainLoss:0.454 averTestLoss:0.523
# >>> EPOCH:9879 averTrainLoss:0.461 averTestLoss:0.524
# >>> EPOCH:9880 averTrainLoss:0.450 averTestLoss:0.525
# >>> EPOCH:9881 averTrainLoss:0.445 averTestLoss:0.525
# >>> EPOCH:9882 averTrainLoss:0.457 averTestLoss:0.526
# >>> EPOCH:9883 averTrainLoss:0.453 averTestLoss:0.524
# >>> EPOCH:9884 averTrainLoss:0.421 averTestLoss:0.520
# >>> EPOCH:9885 averTrainLoss:0.453 averTestLoss:0.516
# >>> EPOCH:9886 averTrainLoss:0.439 averTestLoss:0.514
# >>> EPOCH:9887 averTrainLoss:0.442 averTestLoss:0.515
# >>> EPOCH:9888 averTrainLoss:0.431 averTestLoss:0.517
# >>> EPOCH:9889 averTrainLoss:0.440 averTestLoss:0.519
# >>> EPOCH:9890 averTrainLoss:0.436 averTestLoss:0.521
# >>> EPOCH:9891 averTrainLoss:0.451 averTestLoss:0.522
# >>> EPOCH:9892 averTrainLoss:0.447 averTestLoss:0.523
# >>> EPOCH:9893 averTrainLoss:0.423 averTestLoss:0.523
# >>> EPOCH:9894 averTrainLoss:0.447 averTestLoss:0.521
# >>> EPOCH:9895 averTrainLoss:0.443 averTestLoss:0.518
# >>> EPOCH:9896 averTrainLoss:0.434 averTestLoss:0.515
# >>> EPOCH:9897 averTrainLoss:0.435 averTestLoss:0.512
# >>> EPOCH:9898 averTrainLoss:0.442 averTestLoss:0.510
# >>> EPOCH:9899 averTrainLoss:0.444 averTestLoss:0.511
# >>> EPOCH:9900 averTrainLoss:0.484 averTestLoss:0.515
# >>> EPOCH:9901 averTrainLoss:0.443 averTestLoss:0.519
# >>> EPOCH:9902 averTrainLoss:0.455 averTestLoss:0.519
# >>> EPOCH:9903 averTrainLoss:0.462 averTestLoss:0.519
# >>> EPOCH:9904 averTrainLoss:0.431 averTestLoss:0.518
# >>> EPOCH:9905 averTrainLoss:0.457 averTestLoss:0.518
# >>> EPOCH:9906 averTrainLoss:0.457 averTestLoss:0.517
# >>> EPOCH:9907 averTrainLoss:0.438 averTestLoss:0.517
# >>> EPOCH:9908 averTrainLoss:0.467 averTestLoss:0.518
# >>> EPOCH:9909 averTrainLoss:0.430 averTestLoss:0.518
# >>> EPOCH:9910 averTrainLoss:0.444 averTestLoss:0.515
# >>> EPOCH:9911 averTrainLoss:0.442 averTestLoss:0.513
# >>> EPOCH:9912 averTrainLoss:0.474 averTestLoss:0.513
# >>> EPOCH:9913 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:9914 averTrainLoss:0.450 averTestLoss:0.520
# >>> EPOCH:9915 averTrainLoss:0.442 averTestLoss:0.522
# >>> EPOCH:9916 averTrainLoss:0.466 averTestLoss:0.523
# >>> EPOCH:9917 averTrainLoss:0.428 averTestLoss:0.523
# >>> EPOCH:9918 averTrainLoss:0.438 averTestLoss:0.525
# >>> EPOCH:9919 averTrainLoss:0.456 averTestLoss:0.526
# >>> EPOCH:9920 averTrainLoss:0.457 averTestLoss:0.526
# >>> EPOCH:9921 averTrainLoss:0.475 averTestLoss:0.523
# >>> EPOCH:9922 averTrainLoss:0.455 averTestLoss:0.521
# >>> EPOCH:9923 averTrainLoss:0.432 averTestLoss:0.517
# >>> EPOCH:9924 averTrainLoss:0.447 averTestLoss:0.514
# >>> EPOCH:9925 averTrainLoss:0.442 averTestLoss:0.513
# >>> EPOCH:9926 averTrainLoss:0.436 averTestLoss:0.515
# >>> EPOCH:9927 averTrainLoss:0.440 averTestLoss:0.515
# >>> EPOCH:9928 averTrainLoss:0.456 averTestLoss:0.518
# >>> EPOCH:9929 averTrainLoss:0.431 averTestLoss:0.519
# >>> EPOCH:9930 averTrainLoss:0.453 averTestLoss:0.520
# >>> EPOCH:9931 averTrainLoss:0.459 averTestLoss:0.521
# >>> EPOCH:9932 averTrainLoss:0.447 averTestLoss:0.522
# >>> EPOCH:9933 averTrainLoss:0.455 averTestLoss:0.523
# >>> EPOCH:9934 averTrainLoss:0.445 averTestLoss:0.524
# >>> EPOCH:9935 averTrainLoss:0.426 averTestLoss:0.522
# >>> EPOCH:9936 averTrainLoss:0.418 averTestLoss:0.521
# >>> EPOCH:9937 averTrainLoss:0.444 averTestLoss:0.519
# >>> EPOCH:9938 averTrainLoss:0.438 averTestLoss:0.518
# >>> EPOCH:9939 averTrainLoss:0.423 averTestLoss:0.518
# >>> EPOCH:9940 averTrainLoss:0.438 averTestLoss:0.518
# >>> EPOCH:9941 averTrainLoss:0.444 averTestLoss:0.518
# >>> EPOCH:9942 averTrainLoss:0.445 averTestLoss:0.518
# >>> EPOCH:9943 averTrainLoss:0.437 averTestLoss:0.516
# >>> EPOCH:9944 averTrainLoss:0.439 averTestLoss:0.515
# >>> EPOCH:9945 averTrainLoss:0.445 averTestLoss:0.515
# >>> EPOCH:9946 averTrainLoss:0.450 averTestLoss:0.515
# >>> EPOCH:9947 averTrainLoss:0.435 averTestLoss:0.516
# >>> EPOCH:9948 averTrainLoss:0.419 averTestLoss:0.517
# >>> EPOCH:9949 averTrainLoss:0.448 averTestLoss:0.518
# >>> EPOCH:9950 averTrainLoss:0.476 averTestLoss:0.520
# >>> EPOCH:9951 averTrainLoss:0.458 averTestLoss:0.522
# >>> EPOCH:9952 averTrainLoss:0.451 averTestLoss:0.525
# >>> EPOCH:9953 averTrainLoss:0.457 averTestLoss:0.528
# >>> EPOCH:9954 averTrainLoss:0.441 averTestLoss:0.527
# >>> EPOCH:9955 averTrainLoss:0.450 averTestLoss:0.523
# >>> EPOCH:9956 averTrainLoss:0.416 averTestLoss:0.518
# >>> EPOCH:9957 averTrainLoss:0.431 averTestLoss:0.516
# >>> EPOCH:9958 averTrainLoss:0.451 averTestLoss:0.516
# >>> EPOCH:9959 averTrainLoss:0.428 averTestLoss:0.516
# >>> EPOCH:9960 averTrainLoss:0.454 averTestLoss:0.516
# >>> EPOCH:9961 averTrainLoss:0.432 averTestLoss:0.516
# >>> EPOCH:9962 averTrainLoss:0.460 averTestLoss:0.518
# >>> EPOCH:9963 averTrainLoss:0.441 averTestLoss:0.520
# >>> EPOCH:9964 averTrainLoss:0.446 averTestLoss:0.522
# >>> EPOCH:9965 averTrainLoss:0.464 averTestLoss:0.521
# >>> EPOCH:9966 averTrainLoss:0.438 averTestLoss:0.520
# >>> EPOCH:9967 averTrainLoss:0.428 averTestLoss:0.519
# >>> EPOCH:9968 averTrainLoss:0.449 averTestLoss:0.517
# >>> EPOCH:9969 averTrainLoss:0.452 averTestLoss:0.516
# >>> EPOCH:9970 averTrainLoss:0.466 averTestLoss:0.517
# >>> EPOCH:9971 averTrainLoss:0.438 averTestLoss:0.518
# >>> EPOCH:9972 averTrainLoss:0.478 averTestLoss:0.518
# >>> EPOCH:9973 averTrainLoss:0.445 averTestLoss:0.517
# >>> EPOCH:9974 averTrainLoss:0.469 averTestLoss:0.516
# >>> EPOCH:9975 averTrainLoss:0.433 averTestLoss:0.513
# >>> EPOCH:9976 averTrainLoss:0.428 averTestLoss:0.515
# >>> EPOCH:9977 averTrainLoss:0.437 averTestLoss:0.517
# >>> EPOCH:9978 averTrainLoss:0.436 averTestLoss:0.519
# >>> EPOCH:9979 averTrainLoss:0.444 averTestLoss:0.521
# >>> EPOCH:9980 averTrainLoss:0.454 averTestLoss:0.523
# >>> EPOCH:9981 averTrainLoss:0.456 averTestLoss:0.526
# >>> EPOCH:9982 averTrainLoss:0.435 averTestLoss:0.528
# >>> EPOCH:9983 averTrainLoss:0.463 averTestLoss:0.526
# >>> EPOCH:9984 averTrainLoss:0.461 averTestLoss:0.521
# >>> EPOCH:9985 averTrainLoss:0.439 averTestLoss:0.514
# >>> EPOCH:9986 averTrainLoss:0.425 averTestLoss:0.509
# >>> EPOCH:9987 averTrainLoss:0.453 averTestLoss:0.510
# >>> EPOCH:9988 averTrainLoss:0.456 averTestLoss:0.512
# >>> EPOCH:9989 averTrainLoss:0.439 averTestLoss:0.515
# >>> EPOCH:9990 averTrainLoss:0.450 averTestLoss:0.517
# >>> EPOCH:9991 averTrainLoss:0.459 averTestLoss:0.521
# >>> EPOCH:9992 averTrainLoss:0.428 averTestLoss:0.524
# >>> EPOCH:9993 averTrainLoss:0.435 averTestLoss:0.524
# >>> EPOCH:9994 averTrainLoss:0.448 averTestLoss:0.523
# >>> EPOCH:9995 averTrainLoss:0.455 averTestLoss:0.521
# >>> EPOCH:9996 averTrainLoss:0.441 averTestLoss:0.520
# >>> EPOCH:9997 averTrainLoss:0.440 averTestLoss:0.520
# >>> EPOCH:9998 averTrainLoss:0.443 averTestLoss:0.519
# >>> EPOCH:9999 averTrainLoss:0.471 averTestLoss:0.517
# >>> EPOCH:10000 averTrainLoss:0.444 averTestLoss:0.518

# %%
plt.plot(list(range(epochs)),lossList,label='Train')
plt.plot(list(range(epochs)),lossListTest,label='Test')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
X=torch.tensor(dataX1)
Y=model(X.view(len(dataX1),1,11).float()).reshape(len(dataX1),1*11)

# %%
a1 = []
for i in Y.tolist():
    a1.append(i[-1])
a2 = []
for i in dataY1:
    a2.append(i[-1])

a2 = np.array(a2)
a1 = np.array(a1)

# %%
Loss = F.l1_loss(torch.tensor(a2), torch.tensor(a1))

# %%
Loss
# Out:
# tensor(5.4217, dtype=torch.float64)

# %%
print(a1[0])
print(a2[0])
print(np.abs((a2[0] - a1[0]) / a2[0]))
print(np.abs((a2 - a1) / a2).mean())
# Out:
# 21.71636199951172
# 24.385
# 0.10943768712275098
# 0.30756064083060375

# %%
# 计算相对误差
relative_errors = np.abs((a2 - a1) / a2)

# 统计relative_errors中大于0.1的数量
count_greater_than_0_1 = (relative_errors > 0.1).sum()

# 统计relative_errors中小于等于0.1的数量
count_less_than_or_equal_to_0_1 = (relative_errors <= 0.1).sum()

print(f"大于0.1的数量：{count_greater_than_0_1}")
print(f"小于等于0.1的数量：{count_less_than_or_equal_to_0_1}")
print('合格率：', count_less_than_or_equal_to_0_1/(count_less_than_or_equal_to_0_1+count_greater_than_0_1))
# Out:
# 大于0.1的数量：485
# 小于等于0.1的数量：144
# 合格率： 0.2289348171701113
