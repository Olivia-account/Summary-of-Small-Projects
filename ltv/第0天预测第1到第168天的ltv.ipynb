# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torch
import torch.utils.data as Data
data = pd.read_csv('test3.csv', encoding='gbk')

# %%
# 将"order_dt"列转换为日期类型
data['order_dt'] = pd.to_datetime(data['order_dt'])

# 创建条件来选择在指定日期范围内的数据
start_date = pd.to_datetime("2022-09-01")
end_date = pd.to_datetime("2022-09-30")
mask_train = (data['order_dt'] >= start_date) & (data['order_dt'] <= end_date)
mask_test = (~(data['order_dt'] >= start_date) & (data['order_dt'] <= end_date))

test1 = data[mask_test]

# %%
dataX = []  # 属性
dataY = []  # 标签
tempX = []  # 储存某个历史第0天数据
tempY = []  # 储存某个未来第1到168天数据

for index, rows in data.iterrows():
    temp_data = [rows['pay_num'], rows['payment_orders'], rows['refund_orders'], rows['cancel_orders'],
                 rows['income'], rows['refund_income'], rows['actual_orders'], rows['续费率'], rows['实际收入'],
                 rows['保留率'], rows['ltv']]

    if len(tempX) == 0:
        tempX.append(temp_data)
    else:
        tempY.append([rows['ltv']])

    if len(tempY) == 168:
        dataX.append(tempX)
        dataY.append(tempY)
        tempX = []
        tempY = []

# %%
dataX1 = []  # 测试属性
dataY1 = []  # 测试标签
tempX = []  # 储存某个历史第0天数据
tempY = []  # 储存某个未来第1到168天数据

for index, rows in test1.iterrows():
    temp_data = [rows['pay_num'], rows['payment_orders'], rows['refund_orders'], rows['cancel_orders'],
                 rows['income'], rows['refund_income'], rows['actual_orders'], rows['续费率'], rows['实际收入'],
                 rows['保留率'], rows['ltv']]

    if len(tempX) == 0:
        tempX.append(temp_data)
    else:
        tempY.append([rows['ltv']])

    if len(tempY) == 168:
        dataX1.append(tempX)
        dataY1.append(tempY)
        tempX = []
        tempY = []

# %%
dataX=torch.tensor(dataX)#列表转Tensor
dataY=torch.tensor(dataY)#列表转Tensor
 
dataset=Data.TensorDataset(dataX,dataY)
train_size=int(0.8*len(dataset))
test_size=len(dataset)-train_size
train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])#以8:2比例划分训练集和测试集
 
train_loader = Data.DataLoader(
            dataset=train_dataset,
            batch_size=600,
            shuffle=True
        )
test_loader = Data.DataLoader(
            dataset=test_dataset,
            batch_size=600,
            shuffle=False
        )

# %%
from torch.nn import LSTM,Module,Linear
class MyModel(Module):
    def __init__(self):
        super(MyModel,self).__init__()
        self.lstm=LSTM(input_size=11,hidden_size=11,num_layers=2,batch_first=True)
        self.linear=Linear(1*11,168*1)#将结果映射到第1到168天数据
    def forward(self,x):
        return self.linear(self.lstm(x)[0].reshape(-1,11*1))

# %%
loaded_model = torch.load('0predict1to168ltv_v1.pkl')
model=MyModel()
model.load_state_dict(loaded_model)
# Out:
# <All keys matched successfully>

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
lossList=[]#记录训练loss
lossListTest=[]#记录测试loss
epochs = 10000
for epoch in range(epochs):
    loss_nowEpoch=[]
    model.train()
    for step, (batch_x, batch_y) in enumerate(train_loader):
        out=model(batch_x)#模型输入
        Loss = F.mse_loss(out,batch_y.view(-1,168*1))#loss计算，将batch_y从(100,168,1)变形为(100,168*1)
        optimizer.zero_grad()#当前batch的梯度不会再用到，所以清除梯度
        Loss.backward()#反向传播计算梯度
        optimizer.step()#更新参数
        loss_nowEpoch.append(Loss.item())
        break
    lossList.append(sum(loss_nowEpoch)/len(loss_nowEpoch))
 
    loss_nowEpochTest = []
    model.eval()
    for step, (batch_x, batch_y) in enumerate(test_loader):
        out = model(batch_x)
        Loss = F.mse_loss(out, batch_y.view(-1, 168*1))  # 将batch_y从(100,168,1)变形为(100,168*1)
        loss_nowEpochTest.append(Loss.item())
        break
    lossListTest.append(sum(loss_nowEpochTest)/len(loss_nowEpochTest))
 
    print(">>> EPOCH:{} averTrainLoss:{:.3f} averTestLoss:{:.3f}".format(epoch+1, lossList[-1],lossListTest[-1]))

torch.save(model.state_dict(), '0predict1to168ltv_v2.pkl')
# Out:
# >>> EPOCH:1 averTrainLoss:21.420 averTestLoss:19.743
# >>> EPOCH:2 averTrainLoss:22.041 averTestLoss:18.144
# >>> EPOCH:3 averTrainLoss:22.339 averTestLoss:18.248
# >>> EPOCH:4 averTrainLoss:22.434 averTestLoss:18.814
# >>> EPOCH:5 averTrainLoss:24.060 averTestLoss:18.201
# >>> EPOCH:6 averTrainLoss:20.796 averTestLoss:17.827
# >>> EPOCH:7 averTrainLoss:19.681 averTestLoss:17.898
# >>> EPOCH:8 averTrainLoss:21.519 averTestLoss:18.121
# >>> EPOCH:9 averTrainLoss:21.133 averTestLoss:18.078
# >>> EPOCH:10 averTrainLoss:21.582 averTestLoss:17.930
# >>> EPOCH:11 averTrainLoss:21.100 averTestLoss:17.861
# >>> EPOCH:12 averTrainLoss:20.750 averTestLoss:17.925
# >>> EPOCH:13 averTrainLoss:22.521 averTestLoss:18.027
# >>> EPOCH:14 averTrainLoss:22.895 averTestLoss:18.098
# >>> EPOCH:15 averTrainLoss:21.161 averTestLoss:18.104
# >>> EPOCH:16 averTrainLoss:21.753 averTestLoss:18.013
# >>> EPOCH:17 averTrainLoss:22.293 averTestLoss:17.972
# >>> EPOCH:18 averTrainLoss:20.916 averTestLoss:17.988
# >>> EPOCH:19 averTrainLoss:20.418 averTestLoss:17.922
# >>> EPOCH:20 averTrainLoss:18.648 averTestLoss:17.839
# >>> EPOCH:21 averTrainLoss:18.625 averTestLoss:17.805
# >>> EPOCH:22 averTrainLoss:20.324 averTestLoss:17.775
# >>> EPOCH:23 averTrainLoss:22.391 averTestLoss:17.776
# >>> EPOCH:24 averTrainLoss:20.426 averTestLoss:17.842
# >>> EPOCH:25 averTrainLoss:22.434 averTestLoss:17.915
# >>> EPOCH:26 averTrainLoss:22.874 averTestLoss:18.041
# >>> EPOCH:27 averTrainLoss:22.563 averTestLoss:18.134
# >>> EPOCH:28 averTrainLoss:21.841 averTestLoss:18.121
# >>> EPOCH:29 averTrainLoss:21.867 averTestLoss:18.027
# >>> EPOCH:30 averTrainLoss:22.674 averTestLoss:17.906
# >>> EPOCH:31 averTrainLoss:19.418 averTestLoss:17.831
# >>> EPOCH:32 averTrainLoss:19.567 averTestLoss:17.795
# >>> EPOCH:33 averTrainLoss:19.401 averTestLoss:17.775
# >>> EPOCH:34 averTrainLoss:20.373 averTestLoss:17.770
# >>> EPOCH:35 averTrainLoss:22.058 averTestLoss:17.799
# >>> EPOCH:36 averTrainLoss:20.962 averTestLoss:17.875
# >>> EPOCH:37 averTrainLoss:22.284 averTestLoss:17.940
# >>> EPOCH:38 averTrainLoss:20.402 averTestLoss:17.981
# >>> EPOCH:39 averTrainLoss:19.608 averTestLoss:18.020
# >>> EPOCH:40 averTrainLoss:20.750 averTestLoss:18.012
# >>> EPOCH:41 averTrainLoss:20.123 averTestLoss:17.927
# >>> EPOCH:42 averTrainLoss:21.093 averTestLoss:17.873
# >>> EPOCH:43 averTrainLoss:18.596 averTestLoss:17.844
# >>> EPOCH:44 averTrainLoss:22.885 averTestLoss:17.850
# >>> EPOCH:45 averTrainLoss:22.343 averTestLoss:17.855
# >>> EPOCH:46 averTrainLoss:19.580 averTestLoss:17.890
# >>> EPOCH:47 averTrainLoss:22.826 averTestLoss:17.969
# >>> EPOCH:48 averTrainLoss:21.123 averTestLoss:18.039
# >>> EPOCH:49 averTrainLoss:21.727 averTestLoss:18.018
# >>> EPOCH:50 averTrainLoss:20.485 averTestLoss:17.961
# >>> EPOCH:51 averTrainLoss:21.048 averTestLoss:17.866
# >>> EPOCH:52 averTrainLoss:19.473 averTestLoss:17.812
# >>> EPOCH:53 averTrainLoss:19.636 averTestLoss:17.797
# >>> EPOCH:54 averTrainLoss:21.568 averTestLoss:17.818
# >>> EPOCH:55 averTrainLoss:20.163 averTestLoss:17.817
# >>> EPOCH:56 averTrainLoss:21.382 averTestLoss:17.847
# >>> EPOCH:57 averTrainLoss:20.655 averTestLoss:17.937
# >>> EPOCH:58 averTrainLoss:19.738 averTestLoss:17.969
# >>> EPOCH:59 averTrainLoss:21.676 averTestLoss:17.949
# >>> EPOCH:60 averTrainLoss:20.584 averTestLoss:17.882
# >>> EPOCH:61 averTrainLoss:18.959 averTestLoss:17.842
# >>> EPOCH:62 averTrainLoss:21.366 averTestLoss:17.882
# >>> EPOCH:63 averTrainLoss:23.671 averTestLoss:17.854
# >>> EPOCH:64 averTrainLoss:21.559 averTestLoss:17.809
# >>> EPOCH:65 averTrainLoss:20.968 averTestLoss:17.815
# >>> EPOCH:66 averTrainLoss:22.447 averTestLoss:17.825
# >>> EPOCH:67 averTrainLoss:21.584 averTestLoss:17.862
# >>> EPOCH:68 averTrainLoss:19.706 averTestLoss:17.887
# >>> EPOCH:69 averTrainLoss:21.189 averTestLoss:17.928
# >>> EPOCH:70 averTrainLoss:21.485 averTestLoss:17.987
# >>> EPOCH:71 averTrainLoss:22.243 averTestLoss:18.038
# >>> EPOCH:72 averTrainLoss:20.723 averTestLoss:18.076
# >>> EPOCH:73 averTrainLoss:20.026 averTestLoss:18.079
# >>> EPOCH:74 averTrainLoss:22.976 averTestLoss:18.050
# >>> EPOCH:75 averTrainLoss:20.207 averTestLoss:17.946
# >>> EPOCH:76 averTrainLoss:18.931 averTestLoss:17.888
# >>> EPOCH:77 averTrainLoss:22.814 averTestLoss:17.843
# >>> EPOCH:78 averTrainLoss:21.314 averTestLoss:17.839
# >>> EPOCH:79 averTrainLoss:21.753 averTestLoss:17.859
# >>> EPOCH:80 averTrainLoss:23.046 averTestLoss:17.881
# >>> EPOCH:81 averTrainLoss:20.536 averTestLoss:17.879
# >>> EPOCH:82 averTrainLoss:20.309 averTestLoss:17.882
# >>> EPOCH:83 averTrainLoss:22.238 averTestLoss:17.870
# >>> EPOCH:84 averTrainLoss:20.562 averTestLoss:17.856
# >>> EPOCH:85 averTrainLoss:20.952 averTestLoss:17.815
# >>> EPOCH:86 averTrainLoss:20.847 averTestLoss:17.806
# >>> EPOCH:87 averTrainLoss:22.695 averTestLoss:17.830
# >>> EPOCH:88 averTrainLoss:22.351 averTestLoss:17.898
# >>> EPOCH:89 averTrainLoss:19.683 averTestLoss:17.979
# >>> EPOCH:90 averTrainLoss:22.560 averTestLoss:18.008
# >>> EPOCH:91 averTrainLoss:22.695 averTestLoss:17.988
# >>> EPOCH:92 averTrainLoss:16.590 averTestLoss:17.949
# >>> EPOCH:93 averTrainLoss:21.340 averTestLoss:17.913
# >>> EPOCH:94 averTrainLoss:20.444 averTestLoss:17.854
# >>> EPOCH:95 averTrainLoss:23.071 averTestLoss:17.796
# >>> EPOCH:96 averTrainLoss:23.731 averTestLoss:17.806
# >>> EPOCH:97 averTrainLoss:20.990 averTestLoss:17.845
# >>> EPOCH:98 averTrainLoss:20.713 averTestLoss:17.916
# >>> EPOCH:99 averTrainLoss:21.637 averTestLoss:18.021
# >>> EPOCH:100 averTrainLoss:20.709 averTestLoss:18.051
# >>> EPOCH:101 averTrainLoss:20.403 averTestLoss:17.981
# >>> EPOCH:102 averTrainLoss:21.995 averTestLoss:17.901
# >>> EPOCH:103 averTrainLoss:21.637 averTestLoss:17.861
# >>> EPOCH:104 averTrainLoss:22.327 averTestLoss:17.880
# >>> EPOCH:105 averTrainLoss:20.133 averTestLoss:17.909
# >>> EPOCH:106 averTrainLoss:22.914 averTestLoss:17.950
# >>> EPOCH:107 averTrainLoss:22.147 averTestLoss:17.984
# >>> EPOCH:108 averTrainLoss:18.781 averTestLoss:18.023
# >>> EPOCH:109 averTrainLoss:21.266 averTestLoss:18.042
# >>> EPOCH:110 averTrainLoss:20.322 averTestLoss:18.050
# >>> EPOCH:111 averTrainLoss:24.135 averTestLoss:18.023
# >>> EPOCH:112 averTrainLoss:21.009 averTestLoss:17.939
# >>> EPOCH:113 averTrainLoss:20.860 averTestLoss:17.836
# >>> EPOCH:114 averTrainLoss:21.898 averTestLoss:17.819
# >>> EPOCH:115 averTrainLoss:22.412 averTestLoss:17.826
# >>> EPOCH:116 averTrainLoss:24.330 averTestLoss:17.846
# >>> EPOCH:117 averTrainLoss:19.943 averTestLoss:17.880
# >>> EPOCH:118 averTrainLoss:21.600 averTestLoss:17.935
# >>> EPOCH:119 averTrainLoss:21.636 averTestLoss:17.967
# >>> EPOCH:120 averTrainLoss:21.240 averTestLoss:17.929
# >>> EPOCH:121 averTrainLoss:21.189 averTestLoss:17.928
# >>> EPOCH:122 averTrainLoss:21.474 averTestLoss:18.061
# >>> EPOCH:123 averTrainLoss:22.160 averTestLoss:18.002
# >>> EPOCH:124 averTrainLoss:20.598 averTestLoss:17.884
# >>> EPOCH:125 averTrainLoss:21.183 averTestLoss:17.879
# >>> EPOCH:126 averTrainLoss:21.006 averTestLoss:17.885
# >>> EPOCH:127 averTrainLoss:19.348 averTestLoss:17.809
# >>> EPOCH:128 averTrainLoss:20.829 averTestLoss:17.773
# >>> EPOCH:129 averTrainLoss:22.431 averTestLoss:17.781
# >>> EPOCH:130 averTrainLoss:23.253 averTestLoss:17.827
# >>> EPOCH:131 averTrainLoss:20.092 averTestLoss:17.879
# >>> EPOCH:132 averTrainLoss:19.715 averTestLoss:17.984
# >>> EPOCH:133 averTrainLoss:19.285 averTestLoss:18.084
# >>> EPOCH:134 averTrainLoss:22.908 averTestLoss:18.031
# >>> EPOCH:135 averTrainLoss:20.507 averTestLoss:17.916
# >>> EPOCH:136 averTrainLoss:19.763 averTestLoss:17.832
# >>> EPOCH:137 averTrainLoss:19.709 averTestLoss:17.820
# >>> EPOCH:138 averTrainLoss:22.061 averTestLoss:17.823
# >>> EPOCH:139 averTrainLoss:20.572 averTestLoss:17.885
# >>> EPOCH:140 averTrainLoss:23.134 averTestLoss:18.002
# >>> EPOCH:141 averTrainLoss:20.985 averTestLoss:18.117
# >>> EPOCH:142 averTrainLoss:22.417 averTestLoss:18.105
# >>> EPOCH:143 averTrainLoss:22.183 averTestLoss:18.009
# >>> EPOCH:144 averTrainLoss:20.193 averTestLoss:17.939
# >>> EPOCH:145 averTrainLoss:21.094 averTestLoss:17.893
# >>> EPOCH:146 averTrainLoss:21.235 averTestLoss:17.909
# >>> EPOCH:147 averTrainLoss:19.747 averTestLoss:17.939
# >>> EPOCH:148 averTrainLoss:21.353 averTestLoss:17.957
# >>> EPOCH:149 averTrainLoss:18.704 averTestLoss:18.037
# >>> EPOCH:150 averTrainLoss:18.981 averTestLoss:18.145
# >>> EPOCH:151 averTrainLoss:20.403 averTestLoss:18.181
# >>> EPOCH:152 averTrainLoss:20.612 averTestLoss:18.158
# >>> EPOCH:153 averTrainLoss:21.335 averTestLoss:18.048
# >>> EPOCH:154 averTrainLoss:22.310 averTestLoss:17.912
# >>> EPOCH:155 averTrainLoss:20.319 averTestLoss:17.863
# >>> EPOCH:156 averTrainLoss:21.241 averTestLoss:17.800
# >>> EPOCH:157 averTrainLoss:21.596 averTestLoss:17.765
# >>> EPOCH:158 averTrainLoss:22.184 averTestLoss:17.787
# >>> EPOCH:159 averTrainLoss:22.476 averTestLoss:17.902
# >>> EPOCH:160 averTrainLoss:21.340 averTestLoss:17.896
# >>> EPOCH:161 averTrainLoss:16.821 averTestLoss:17.870
# >>> EPOCH:162 averTrainLoss:21.724 averTestLoss:17.851
# >>> EPOCH:163 averTrainLoss:17.721 averTestLoss:17.984
# >>> EPOCH:164 averTrainLoss:20.341 averTestLoss:18.133
# >>> EPOCH:165 averTrainLoss:19.883 averTestLoss:18.134
# >>> EPOCH:166 averTrainLoss:22.415 averTestLoss:18.150
# >>> EPOCH:167 averTrainLoss:20.652 averTestLoss:18.160
# >>> EPOCH:168 averTrainLoss:24.397 averTestLoss:18.191
# >>> EPOCH:169 averTrainLoss:20.615 averTestLoss:18.065
# >>> EPOCH:170 averTrainLoss:19.557 averTestLoss:17.880
# >>> EPOCH:171 averTrainLoss:22.858 averTestLoss:17.837
# >>> EPOCH:172 averTrainLoss:22.129 averTestLoss:17.864
# >>> EPOCH:173 averTrainLoss:21.325 averTestLoss:17.782
# >>> EPOCH:174 averTrainLoss:21.306 averTestLoss:17.769
# >>> EPOCH:175 averTrainLoss:21.055 averTestLoss:17.834
# >>> EPOCH:176 averTrainLoss:19.811 averTestLoss:17.878
# >>> EPOCH:177 averTrainLoss:19.544 averTestLoss:17.901
# >>> EPOCH:178 averTrainLoss:20.626 averTestLoss:17.913
# >>> EPOCH:179 averTrainLoss:20.768 averTestLoss:17.944
# >>> EPOCH:180 averTrainLoss:22.950 averTestLoss:18.020
# >>> EPOCH:181 averTrainLoss:19.550 averTestLoss:18.108
# >>> EPOCH:182 averTrainLoss:21.043 averTestLoss:18.068
# >>> EPOCH:183 averTrainLoss:22.636 averTestLoss:17.994
# >>> EPOCH:184 averTrainLoss:21.664 averTestLoss:17.935
# >>> EPOCH:185 averTrainLoss:20.733 averTestLoss:17.927
# >>> EPOCH:186 averTrainLoss:22.045 averTestLoss:17.870
# >>> EPOCH:187 averTrainLoss:21.836 averTestLoss:17.859
# >>> EPOCH:188 averTrainLoss:21.632 averTestLoss:17.940
# >>> EPOCH:189 averTrainLoss:19.960 averTestLoss:17.979
# >>> EPOCH:190 averTrainLoss:22.583 averTestLoss:17.986
# >>> EPOCH:191 averTrainLoss:19.295 averTestLoss:17.999
# >>> EPOCH:192 averTrainLoss:21.833 averTestLoss:17.979
# >>> EPOCH:193 averTrainLoss:21.584 averTestLoss:17.911
# >>> EPOCH:194 averTrainLoss:22.997 averTestLoss:17.824
# >>> EPOCH:195 averTrainLoss:21.817 averTestLoss:17.790
# >>> EPOCH:196 averTrainLoss:21.469 averTestLoss:17.796
# >>> EPOCH:197 averTrainLoss:22.904 averTestLoss:17.851
# >>> EPOCH:198 averTrainLoss:21.743 averTestLoss:17.901
# >>> EPOCH:199 averTrainLoss:20.889 averTestLoss:17.900
# >>> EPOCH:200 averTrainLoss:23.108 averTestLoss:17.975
# >>> EPOCH:201 averTrainLoss:20.882 averTestLoss:18.205
# >>> EPOCH:202 averTrainLoss:22.319 averTestLoss:18.150
# >>> EPOCH:203 averTrainLoss:19.325 averTestLoss:18.004
# >>> EPOCH:204 averTrainLoss:20.782 averTestLoss:17.966
# >>> EPOCH:205 averTrainLoss:20.699 averTestLoss:18.026
# >>> EPOCH:206 averTrainLoss:22.979 averTestLoss:18.024
# >>> EPOCH:207 averTrainLoss:19.551 averTestLoss:17.891
# >>> EPOCH:208 averTrainLoss:21.988 averTestLoss:17.893
# >>> EPOCH:209 averTrainLoss:22.490 averTestLoss:18.073
# >>> EPOCH:210 averTrainLoss:22.017 averTestLoss:18.107
# >>> EPOCH:211 averTrainLoss:18.952 averTestLoss:17.946
# >>> EPOCH:212 averTrainLoss:22.536 averTestLoss:17.914
# >>> EPOCH:213 averTrainLoss:19.921 averTestLoss:18.054
# >>> EPOCH:214 averTrainLoss:18.819 averTestLoss:18.090
# >>> EPOCH:215 averTrainLoss:23.002 averTestLoss:18.042
# >>> EPOCH:216 averTrainLoss:20.324 averTestLoss:18.045
# >>> EPOCH:217 averTrainLoss:22.402 averTestLoss:18.070
# >>> EPOCH:218 averTrainLoss:20.001 averTestLoss:18.006
# >>> EPOCH:219 averTrainLoss:19.473 averTestLoss:17.954
# >>> EPOCH:220 averTrainLoss:21.573 averTestLoss:17.918
# >>> EPOCH:221 averTrainLoss:20.585 averTestLoss:17.956
# >>> EPOCH:222 averTrainLoss:21.722 averTestLoss:18.031
# >>> EPOCH:223 averTrainLoss:22.687 averTestLoss:17.949
# >>> EPOCH:224 averTrainLoss:19.968 averTestLoss:17.899
# >>> EPOCH:225 averTrainLoss:19.555 averTestLoss:17.912
# >>> EPOCH:226 averTrainLoss:22.812 averTestLoss:17.917
# >>> EPOCH:227 averTrainLoss:20.192 averTestLoss:17.942
# >>> EPOCH:228 averTrainLoss:19.818 averTestLoss:17.965
# >>> EPOCH:229 averTrainLoss:21.131 averTestLoss:17.994
# >>> EPOCH:230 averTrainLoss:21.163 averTestLoss:17.984
# >>> EPOCH:231 averTrainLoss:22.099 averTestLoss:17.964
# >>> EPOCH:232 averTrainLoss:18.881 averTestLoss:17.937
# >>> EPOCH:233 averTrainLoss:21.026 averTestLoss:17.906
# >>> EPOCH:234 averTrainLoss:20.143 averTestLoss:17.902
# >>> EPOCH:235 averTrainLoss:21.634 averTestLoss:17.921
# >>> EPOCH:236 averTrainLoss:21.470 averTestLoss:17.958
# >>> EPOCH:237 averTrainLoss:21.488 averTestLoss:17.990
# >>> EPOCH:238 averTrainLoss:22.365 averTestLoss:17.987
# >>> EPOCH:239 averTrainLoss:20.343 averTestLoss:17.988
# >>> EPOCH:240 averTrainLoss:23.424 averTestLoss:17.940
# >>> EPOCH:241 averTrainLoss:19.896 averTestLoss:17.849
# >>> EPOCH:242 averTrainLoss:20.396 averTestLoss:17.841
# >>> EPOCH:243 averTrainLoss:22.641 averTestLoss:17.972
# >>> EPOCH:244 averTrainLoss:19.744 averTestLoss:17.970
# >>> EPOCH:245 averTrainLoss:20.234 averTestLoss:18.001
# >>> EPOCH:246 averTrainLoss:21.242 averTestLoss:18.124
# >>> EPOCH:247 averTrainLoss:20.399 averTestLoss:18.276
# >>> EPOCH:248 averTrainLoss:18.351 averTestLoss:18.314
# >>> EPOCH:249 averTrainLoss:21.505 averTestLoss:18.084
# >>> EPOCH:250 averTrainLoss:21.738 averTestLoss:17.883
# >>> EPOCH:251 averTrainLoss:22.751 averTestLoss:17.971
# >>> EPOCH:252 averTrainLoss:22.089 averTestLoss:18.157
# >>> EPOCH:253 averTrainLoss:21.722 averTestLoss:18.020
# >>> EPOCH:254 averTrainLoss:21.093 averTestLoss:17.873
# >>> EPOCH:255 averTrainLoss:20.619 averTestLoss:18.109
# >>> EPOCH:256 averTrainLoss:21.754 averTestLoss:18.258
# >>> EPOCH:257 averTrainLoss:20.364 averTestLoss:18.155
# >>> EPOCH:258 averTrainLoss:23.666 averTestLoss:18.050
# >>> EPOCH:259 averTrainLoss:20.704 averTestLoss:18.031
# >>> EPOCH:260 averTrainLoss:22.164 averTestLoss:18.044
# >>> EPOCH:261 averTrainLoss:19.863 averTestLoss:17.930
# >>> EPOCH:262 averTrainLoss:21.655 averTestLoss:17.858
# >>> EPOCH:263 averTrainLoss:20.984 averTestLoss:17.895
# >>> EPOCH:264 averTrainLoss:19.697 averTestLoss:17.978
# >>> EPOCH:265 averTrainLoss:22.000 averTestLoss:18.013
# >>> EPOCH:266 averTrainLoss:22.485 averTestLoss:17.956
# >>> EPOCH:267 averTrainLoss:21.527 averTestLoss:17.981
# >>> EPOCH:268 averTrainLoss:20.224 averTestLoss:17.988
# >>> EPOCH:269 averTrainLoss:21.348 averTestLoss:17.886
# >>> EPOCH:270 averTrainLoss:21.641 averTestLoss:17.906
# >>> EPOCH:271 averTrainLoss:20.746 averTestLoss:17.970
# >>> EPOCH:272 averTrainLoss:19.896 averTestLoss:18.051
# >>> EPOCH:273 averTrainLoss:19.936 averTestLoss:17.979
# >>> EPOCH:274 averTrainLoss:24.765 averTestLoss:17.888
# >>> EPOCH:275 averTrainLoss:21.850 averTestLoss:17.989
# >>> EPOCH:276 averTrainLoss:20.361 averTestLoss:18.090
# >>> EPOCH:277 averTrainLoss:20.833 averTestLoss:18.007
# >>> EPOCH:278 averTrainLoss:21.806 averTestLoss:18.006
# >>> EPOCH:279 averTrainLoss:21.446 averTestLoss:18.015
# >>> EPOCH:280 averTrainLoss:20.465 averTestLoss:17.933
# >>> EPOCH:281 averTrainLoss:20.206 averTestLoss:17.831
# >>> EPOCH:282 averTrainLoss:18.572 averTestLoss:17.838
# >>> EPOCH:283 averTrainLoss:22.248 averTestLoss:17.951
# >>> EPOCH:284 averTrainLoss:22.713 averTestLoss:18.057
# >>> EPOCH:285 averTrainLoss:21.225 averTestLoss:18.065
# >>> EPOCH:286 averTrainLoss:21.750 averTestLoss:18.096
# >>> EPOCH:287 averTrainLoss:19.486 averTestLoss:18.101
# >>> EPOCH:288 averTrainLoss:21.743 averTestLoss:18.052
# >>> EPOCH:289 averTrainLoss:18.228 averTestLoss:17.924
# >>> EPOCH:290 averTrainLoss:21.646 averTestLoss:17.918
# >>> EPOCH:291 averTrainLoss:20.247 averTestLoss:18.018
# >>> EPOCH:292 averTrainLoss:22.384 averTestLoss:18.016
# >>> EPOCH:293 averTrainLoss:20.994 averTestLoss:17.953
# >>> EPOCH:294 averTrainLoss:21.635 averTestLoss:17.952
# >>> EPOCH:295 averTrainLoss:20.582 averTestLoss:18.082
# >>> EPOCH:296 averTrainLoss:19.174 averTestLoss:18.054
# >>> EPOCH:297 averTrainLoss:21.344 averTestLoss:17.899
# >>> EPOCH:298 averTrainLoss:21.024 averTestLoss:17.860
# >>> EPOCH:299 averTrainLoss:21.856 averTestLoss:17.915
# >>> EPOCH:300 averTrainLoss:20.031 averTestLoss:17.957
# >>> EPOCH:301 averTrainLoss:21.533 averTestLoss:17.971
# >>> EPOCH:302 averTrainLoss:21.785 averTestLoss:17.982
# >>> EPOCH:303 averTrainLoss:20.501 averTestLoss:18.016
# >>> EPOCH:304 averTrainLoss:20.854 averTestLoss:18.008
# >>> EPOCH:305 averTrainLoss:21.213 averTestLoss:17.953
# >>> EPOCH:306 averTrainLoss:19.518 averTestLoss:17.925
# >>> EPOCH:307 averTrainLoss:22.152 averTestLoss:17.943
# >>> EPOCH:308 averTrainLoss:18.449 averTestLoss:17.937
# >>> EPOCH:309 averTrainLoss:21.885 averTestLoss:17.844
# >>> EPOCH:310 averTrainLoss:19.802 averTestLoss:17.855
# >>> EPOCH:311 averTrainLoss:21.575 averTestLoss:17.966
# >>> EPOCH:312 averTrainLoss:21.362 averTestLoss:17.971
# >>> EPOCH:313 averTrainLoss:21.798 averTestLoss:17.833
# >>> EPOCH:314 averTrainLoss:24.013 averTestLoss:18.021
# >>> EPOCH:315 averTrainLoss:21.871 averTestLoss:18.542
# >>> EPOCH:316 averTrainLoss:23.243 averTestLoss:18.780
# >>> EPOCH:317 averTrainLoss:20.521 averTestLoss:18.422
# >>> EPOCH:318 averTrainLoss:21.377 averTestLoss:18.387
# >>> EPOCH:319 averTrainLoss:22.992 averTestLoss:18.472
# >>> EPOCH:320 averTrainLoss:20.825 averTestLoss:18.484
# >>> EPOCH:321 averTrainLoss:23.367 averTestLoss:18.245
# >>> EPOCH:322 averTrainLoss:22.171 averTestLoss:18.023
# >>> EPOCH:323 averTrainLoss:17.514 averTestLoss:18.181
# >>> EPOCH:324 averTrainLoss:20.693 averTestLoss:18.241
# >>> EPOCH:325 averTrainLoss:21.352 averTestLoss:18.095
# >>> EPOCH:326 averTrainLoss:20.521 averTestLoss:18.038
# >>> EPOCH:327 averTrainLoss:20.786 averTestLoss:18.166
# >>> EPOCH:328 averTrainLoss:19.408 averTestLoss:18.254
# >>> EPOCH:329 averTrainLoss:24.357 averTestLoss:18.118
# >>> EPOCH:330 averTrainLoss:24.104 averTestLoss:17.836
# >>> EPOCH:331 averTrainLoss:22.580 averTestLoss:17.855
# >>> EPOCH:332 averTrainLoss:20.743 averTestLoss:17.998
# >>> EPOCH:333 averTrainLoss:20.929 averTestLoss:17.979
# >>> EPOCH:334 averTrainLoss:22.746 averTestLoss:17.934
# >>> EPOCH:335 averTrainLoss:22.468 averTestLoss:17.999
# >>> EPOCH:336 averTrainLoss:19.396 averTestLoss:18.139
# >>> EPOCH:337 averTrainLoss:21.441 averTestLoss:18.188
# >>> EPOCH:338 averTrainLoss:22.113 averTestLoss:18.086
# >>> EPOCH:339 averTrainLoss:18.112 averTestLoss:18.107
# >>> EPOCH:340 averTrainLoss:21.833 averTestLoss:18.113
# >>> EPOCH:341 averTrainLoss:22.824 averTestLoss:18.044
# >>> EPOCH:342 averTrainLoss:21.281 averTestLoss:17.957
# >>> EPOCH:343 averTrainLoss:20.092 averTestLoss:17.936
# >>> EPOCH:344 averTrainLoss:23.113 averTestLoss:17.955
# >>> EPOCH:345 averTrainLoss:23.279 averTestLoss:17.918
# >>> EPOCH:346 averTrainLoss:20.058 averTestLoss:17.864
# >>> EPOCH:347 averTrainLoss:19.514 averTestLoss:17.826
# >>> EPOCH:348 averTrainLoss:21.961 averTestLoss:17.812
# >>> EPOCH:349 averTrainLoss:24.157 averTestLoss:17.829
# >>> EPOCH:350 averTrainLoss:20.738 averTestLoss:17.876
# >>> EPOCH:351 averTrainLoss:21.974 averTestLoss:17.921
# >>> EPOCH:352 averTrainLoss:19.024 averTestLoss:17.995
# >>> EPOCH:353 averTrainLoss:21.706 averTestLoss:18.035
# >>> EPOCH:354 averTrainLoss:21.393 averTestLoss:18.043
# >>> EPOCH:355 averTrainLoss:21.579 averTestLoss:18.029
# >>> EPOCH:356 averTrainLoss:21.050 averTestLoss:18.021
# >>> EPOCH:357 averTrainLoss:22.672 averTestLoss:17.947
# >>> EPOCH:358 averTrainLoss:22.187 averTestLoss:17.923
# >>> EPOCH:359 averTrainLoss:23.162 averTestLoss:17.922
# >>> EPOCH:360 averTrainLoss:19.967 averTestLoss:17.900
# >>> EPOCH:361 averTrainLoss:20.607 averTestLoss:17.863
# >>> EPOCH:362 averTrainLoss:21.132 averTestLoss:17.862
# >>> EPOCH:363 averTrainLoss:22.670 averTestLoss:17.909
# >>> EPOCH:364 averTrainLoss:20.773 averTestLoss:17.924
# >>> EPOCH:365 averTrainLoss:20.693 averTestLoss:17.922
# >>> EPOCH:366 averTrainLoss:20.621 averTestLoss:17.935
# >>> EPOCH:367 averTrainLoss:21.408 averTestLoss:17.982
# >>> EPOCH:368 averTrainLoss:21.910 averTestLoss:18.040
# >>> EPOCH:369 averTrainLoss:22.868 averTestLoss:18.103
# >>> EPOCH:370 averTrainLoss:21.323 averTestLoss:18.109
# >>> EPOCH:371 averTrainLoss:20.451 averTestLoss:18.044
# >>> EPOCH:372 averTrainLoss:21.654 averTestLoss:17.974
# >>> EPOCH:373 averTrainLoss:20.783 averTestLoss:17.916
# >>> EPOCH:374 averTrainLoss:21.023 averTestLoss:17.864
# >>> EPOCH:375 averTrainLoss:21.182 averTestLoss:17.844
# >>> EPOCH:376 averTrainLoss:21.236 averTestLoss:17.848
# >>> EPOCH:377 averTrainLoss:21.862 averTestLoss:17.889
# >>> EPOCH:378 averTrainLoss:20.747 averTestLoss:17.966
# >>> EPOCH:379 averTrainLoss:21.436 averTestLoss:18.013
# >>> EPOCH:380 averTrainLoss:21.898 averTestLoss:18.077
# >>> EPOCH:381 averTrainLoss:22.071 averTestLoss:18.112
# >>> EPOCH:382 averTrainLoss:22.607 averTestLoss:18.136
# >>> EPOCH:383 averTrainLoss:20.206 averTestLoss:18.128
# >>> EPOCH:384 averTrainLoss:19.451 averTestLoss:18.063
# >>> EPOCH:385 averTrainLoss:19.203 averTestLoss:17.985
# >>> EPOCH:386 averTrainLoss:21.978 averTestLoss:17.941
# >>> EPOCH:387 averTrainLoss:23.978 averTestLoss:17.912
# >>> EPOCH:388 averTrainLoss:22.208 averTestLoss:17.902
# >>> EPOCH:389 averTrainLoss:20.907 averTestLoss:17.915
# >>> EPOCH:390 averTrainLoss:21.707 averTestLoss:17.937
# >>> EPOCH:391 averTrainLoss:20.170 averTestLoss:17.963
# >>> EPOCH:392 averTrainLoss:21.484 averTestLoss:18.023
# >>> EPOCH:393 averTrainLoss:21.309 averTestLoss:18.040
# >>> EPOCH:394 averTrainLoss:21.905 averTestLoss:18.014
# >>> EPOCH:395 averTrainLoss:21.491 averTestLoss:18.017
# >>> EPOCH:396 averTrainLoss:20.470 averTestLoss:18.024
# >>> EPOCH:397 averTrainLoss:21.600 averTestLoss:18.020
# >>> EPOCH:398 averTrainLoss:21.761 averTestLoss:17.996
# >>> EPOCH:399 averTrainLoss:24.594 averTestLoss:17.959
# >>> EPOCH:400 averTrainLoss:22.392 averTestLoss:17.981
# >>> EPOCH:401 averTrainLoss:21.983 averTestLoss:18.009
# >>> EPOCH:402 averTrainLoss:20.471 averTestLoss:17.969
# >>> EPOCH:403 averTrainLoss:22.783 averTestLoss:17.900
# >>> EPOCH:404 averTrainLoss:18.825 averTestLoss:17.864
# >>> EPOCH:405 averTrainLoss:23.067 averTestLoss:17.918
# >>> EPOCH:406 averTrainLoss:20.060 averTestLoss:18.058
# >>> EPOCH:407 averTrainLoss:20.898 averTestLoss:18.024
# >>> EPOCH:408 averTrainLoss:20.331 averTestLoss:18.025
# >>> EPOCH:409 averTrainLoss:19.104 averTestLoss:18.261
# >>> EPOCH:410 averTrainLoss:21.936 averTestLoss:18.290
# >>> EPOCH:411 averTrainLoss:20.218 averTestLoss:18.040
# >>> EPOCH:412 averTrainLoss:22.241 averTestLoss:17.955
# >>> EPOCH:413 averTrainLoss:20.553 averTestLoss:18.146
# >>> EPOCH:414 averTrainLoss:21.437 averTestLoss:18.253
# >>> EPOCH:415 averTrainLoss:21.275 averTestLoss:18.075
# >>> EPOCH:416 averTrainLoss:21.884 averTestLoss:17.994
# >>> EPOCH:417 averTrainLoss:22.275 averTestLoss:18.080
# >>> EPOCH:418 averTrainLoss:19.707 averTestLoss:18.300
# >>> EPOCH:419 averTrainLoss:20.174 averTestLoss:18.188
# >>> EPOCH:420 averTrainLoss:19.819 averTestLoss:17.903
# >>> EPOCH:421 averTrainLoss:20.804 averTestLoss:17.804
# >>> EPOCH:422 averTrainLoss:22.641 averTestLoss:17.938
# >>> EPOCH:423 averTrainLoss:19.564 averTestLoss:18.103
# >>> EPOCH:424 averTrainLoss:20.740 averTestLoss:18.009
# >>> EPOCH:425 averTrainLoss:23.231 averTestLoss:17.921
# >>> EPOCH:426 averTrainLoss:19.901 averTestLoss:18.019
# >>> EPOCH:427 averTrainLoss:21.072 averTestLoss:18.302
# >>> EPOCH:428 averTrainLoss:23.082 averTestLoss:18.423
# >>> EPOCH:429 averTrainLoss:20.892 averTestLoss:18.404
# >>> EPOCH:430 averTrainLoss:22.578 averTestLoss:18.259
# >>> EPOCH:431 averTrainLoss:21.942 averTestLoss:18.115
# >>> EPOCH:432 averTrainLoss:20.528 averTestLoss:18.004
# >>> EPOCH:433 averTrainLoss:20.049 averTestLoss:17.893
# >>> EPOCH:434 averTrainLoss:20.541 averTestLoss:17.820
# >>> EPOCH:435 averTrainLoss:19.389 averTestLoss:17.825
# >>> EPOCH:436 averTrainLoss:20.922 averTestLoss:17.860
# >>> EPOCH:437 averTrainLoss:21.495 averTestLoss:17.846
# >>> EPOCH:438 averTrainLoss:19.446 averTestLoss:17.879
# >>> EPOCH:439 averTrainLoss:19.024 averTestLoss:18.029
# >>> EPOCH:440 averTrainLoss:20.461 averTestLoss:18.108
# >>> EPOCH:441 averTrainLoss:21.569 averTestLoss:18.146
# >>> EPOCH:442 averTrainLoss:20.757 averTestLoss:18.099
# >>> EPOCH:443 averTrainLoss:21.346 averTestLoss:18.056
# >>> EPOCH:444 averTrainLoss:20.105 averTestLoss:18.027
# >>> EPOCH:445 averTrainLoss:20.784 averTestLoss:18.033
# >>> EPOCH:446 averTrainLoss:19.879 averTestLoss:18.031
# >>> EPOCH:447 averTrainLoss:20.546 averTestLoss:18.000
# >>> EPOCH:448 averTrainLoss:19.263 averTestLoss:17.959
# >>> EPOCH:449 averTrainLoss:21.081 averTestLoss:17.968
# >>> EPOCH:450 averTrainLoss:21.380 averTestLoss:17.900
# >>> EPOCH:451 averTrainLoss:21.567 averTestLoss:17.850
# >>> EPOCH:452 averTrainLoss:18.551 averTestLoss:17.825
# >>> EPOCH:453 averTrainLoss:21.320 averTestLoss:17.831
# >>> EPOCH:454 averTrainLoss:19.603 averTestLoss:17.868
# >>> EPOCH:455 averTrainLoss:21.191 averTestLoss:17.886
# >>> EPOCH:456 averTrainLoss:21.129 averTestLoss:17.938
# >>> EPOCH:457 averTrainLoss:20.740 averTestLoss:18.022
# >>> EPOCH:458 averTrainLoss:20.499 averTestLoss:18.044
# >>> EPOCH:459 averTrainLoss:21.036 averTestLoss:18.030
# >>> EPOCH:460 averTrainLoss:20.392 averTestLoss:17.976
# >>> EPOCH:461 averTrainLoss:20.015 averTestLoss:17.940
# >>> EPOCH:462 averTrainLoss:21.272 averTestLoss:17.882
# >>> EPOCH:463 averTrainLoss:20.431 averTestLoss:17.877
# >>> EPOCH:464 averTrainLoss:21.019 averTestLoss:17.925
# >>> EPOCH:465 averTrainLoss:20.855 averTestLoss:17.982
# >>> EPOCH:466 averTrainLoss:21.828 averTestLoss:17.936
# >>> EPOCH:467 averTrainLoss:20.671 averTestLoss:17.876
# >>> EPOCH:468 averTrainLoss:20.032 averTestLoss:17.937
# >>> EPOCH:469 averTrainLoss:20.900 averTestLoss:17.998
# >>> EPOCH:470 averTrainLoss:20.739 averTestLoss:18.032
# >>> EPOCH:471 averTrainLoss:20.498 averTestLoss:17.945
# >>> EPOCH:472 averTrainLoss:20.151 averTestLoss:17.970
# >>> EPOCH:473 averTrainLoss:19.817 averTestLoss:18.147
# >>> EPOCH:474 averTrainLoss:21.681 averTestLoss:18.396
# >>> EPOCH:475 averTrainLoss:21.319 averTestLoss:18.256
# >>> EPOCH:476 averTrainLoss:19.454 averTestLoss:18.037
# >>> EPOCH:477 averTrainLoss:21.788 averTestLoss:17.983
# >>> EPOCH:478 averTrainLoss:21.653 averTestLoss:17.984
# >>> EPOCH:479 averTrainLoss:21.122 averTestLoss:17.995
# >>> EPOCH:480 averTrainLoss:20.337 averTestLoss:17.846
# >>> EPOCH:481 averTrainLoss:20.875 averTestLoss:17.817
# >>> EPOCH:482 averTrainLoss:19.378 averTestLoss:17.940
# >>> EPOCH:483 averTrainLoss:20.663 averTestLoss:17.934
# >>> EPOCH:484 averTrainLoss:21.329 averTestLoss:17.909
# >>> EPOCH:485 averTrainLoss:21.716 averTestLoss:17.955
# >>> EPOCH:486 averTrainLoss:21.455 averTestLoss:18.013
# >>> EPOCH:487 averTrainLoss:17.604 averTestLoss:18.134
# >>> EPOCH:488 averTrainLoss:19.107 averTestLoss:18.229
# >>> EPOCH:489 averTrainLoss:19.858 averTestLoss:18.167
# >>> EPOCH:490 averTrainLoss:20.182 averTestLoss:18.077
# >>> EPOCH:491 averTrainLoss:22.002 averTestLoss:18.139
# >>> EPOCH:492 averTrainLoss:20.101 averTestLoss:18.229
# >>> EPOCH:493 averTrainLoss:21.142 averTestLoss:18.092
# >>> EPOCH:494 averTrainLoss:22.793 averTestLoss:17.913
# >>> EPOCH:495 averTrainLoss:18.434 averTestLoss:17.952
# >>> EPOCH:496 averTrainLoss:23.675 averTestLoss:18.061
# >>> EPOCH:497 averTrainLoss:19.168 averTestLoss:18.023
# >>> EPOCH:498 averTrainLoss:20.625 averTestLoss:17.943
# >>> EPOCH:499 averTrainLoss:21.148 averTestLoss:17.903
# >>> EPOCH:500 averTrainLoss:21.803 averTestLoss:18.013
# >>> EPOCH:501 averTrainLoss:23.736 averTestLoss:18.227
# >>> EPOCH:502 averTrainLoss:21.347 averTestLoss:18.138
# >>> EPOCH:503 averTrainLoss:21.062 averTestLoss:18.029
# >>> EPOCH:504 averTrainLoss:20.051 averTestLoss:18.036
# >>> EPOCH:505 averTrainLoss:21.257 averTestLoss:18.160
# >>> EPOCH:506 averTrainLoss:21.544 averTestLoss:18.116
# >>> EPOCH:507 averTrainLoss:21.933 averTestLoss:17.973
# >>> EPOCH:508 averTrainLoss:21.855 averTestLoss:17.969
# >>> EPOCH:509 averTrainLoss:21.612 averTestLoss:18.017
# >>> EPOCH:510 averTrainLoss:21.882 averTestLoss:17.888
# >>> EPOCH:511 averTrainLoss:22.563 averTestLoss:17.817
# >>> EPOCH:512 averTrainLoss:22.129 averTestLoss:17.854
# >>> EPOCH:513 averTrainLoss:21.181 averTestLoss:17.828
# >>> EPOCH:514 averTrainLoss:20.227 averTestLoss:17.805
# >>> EPOCH:515 averTrainLoss:22.606 averTestLoss:17.830
# >>> EPOCH:516 averTrainLoss:20.777 averTestLoss:17.935
# >>> EPOCH:517 averTrainLoss:23.347 averTestLoss:18.075
# >>> EPOCH:518 averTrainLoss:20.990 averTestLoss:18.082
# >>> EPOCH:519 averTrainLoss:20.490 averTestLoss:18.138
# >>> EPOCH:520 averTrainLoss:21.819 averTestLoss:18.260
# >>> EPOCH:521 averTrainLoss:21.731 averTestLoss:18.230
# >>> EPOCH:522 averTrainLoss:20.911 averTestLoss:18.035
# >>> EPOCH:523 averTrainLoss:20.053 averTestLoss:17.946
# >>> EPOCH:524 averTrainLoss:20.455 averTestLoss:17.911
# >>> EPOCH:525 averTrainLoss:20.381 averTestLoss:17.868
# >>> EPOCH:526 averTrainLoss:21.511 averTestLoss:17.857
# >>> EPOCH:527 averTrainLoss:21.287 averTestLoss:17.882
# >>> EPOCH:528 averTrainLoss:20.297 averTestLoss:17.917
# >>> EPOCH:529 averTrainLoss:21.855 averTestLoss:17.896
# >>> EPOCH:530 averTrainLoss:19.759 averTestLoss:17.859
# >>> EPOCH:531 averTrainLoss:21.361 averTestLoss:17.844
# >>> EPOCH:532 averTrainLoss:21.621 averTestLoss:17.839
# >>> EPOCH:533 averTrainLoss:21.570 averTestLoss:17.846
# >>> EPOCH:534 averTrainLoss:19.890 averTestLoss:17.893
# >>> EPOCH:535 averTrainLoss:19.812 averTestLoss:17.996
# >>> EPOCH:536 averTrainLoss:21.011 averTestLoss:18.138
# >>> EPOCH:537 averTrainLoss:21.311 averTestLoss:18.172
# >>> EPOCH:538 averTrainLoss:22.295 averTestLoss:18.070
# >>> EPOCH:539 averTrainLoss:23.115 averTestLoss:18.009
# >>> EPOCH:540 averTrainLoss:22.458 averTestLoss:17.966
# >>> EPOCH:541 averTrainLoss:21.707 averTestLoss:17.955
# >>> EPOCH:542 averTrainLoss:21.537 averTestLoss:17.917
# >>> EPOCH:543 averTrainLoss:22.848 averTestLoss:17.932
# >>> EPOCH:544 averTrainLoss:19.941 averTestLoss:18.031
# >>> EPOCH:545 averTrainLoss:21.872 averTestLoss:18.169
# >>> EPOCH:546 averTrainLoss:21.106 averTestLoss:18.146
# >>> EPOCH:547 averTrainLoss:19.628 averTestLoss:18.040
# >>> EPOCH:548 averTrainLoss:22.504 averTestLoss:17.927
# >>> EPOCH:549 averTrainLoss:21.261 averTestLoss:17.920
# >>> EPOCH:550 averTrainLoss:19.785 averTestLoss:17.942
# >>> EPOCH:551 averTrainLoss:21.826 averTestLoss:17.882
# >>> EPOCH:552 averTrainLoss:19.586 averTestLoss:17.848
# >>> EPOCH:553 averTrainLoss:24.448 averTestLoss:17.874
# >>> EPOCH:554 averTrainLoss:21.151 averTestLoss:17.929
# >>> EPOCH:555 averTrainLoss:21.177 averTestLoss:18.032
# >>> EPOCH:556 averTrainLoss:21.640 averTestLoss:18.168
# >>> EPOCH:557 averTrainLoss:21.048 averTestLoss:18.217
# >>> EPOCH:558 averTrainLoss:22.113 averTestLoss:18.131
# >>> EPOCH:559 averTrainLoss:20.071 averTestLoss:18.127
# >>> EPOCH:560 averTrainLoss:22.276 averTestLoss:18.058
# >>> EPOCH:561 averTrainLoss:22.524 averTestLoss:17.922
# >>> EPOCH:562 averTrainLoss:18.938 averTestLoss:17.903
# >>> EPOCH:563 averTrainLoss:20.577 averTestLoss:17.934
# >>> EPOCH:564 averTrainLoss:21.173 averTestLoss:17.949
# >>> EPOCH:565 averTrainLoss:20.167 averTestLoss:17.916
# >>> EPOCH:566 averTrainLoss:19.285 averTestLoss:17.927
# >>> EPOCH:567 averTrainLoss:22.483 averTestLoss:18.021
# >>> EPOCH:568 averTrainLoss:21.944 averTestLoss:18.262
# >>> EPOCH:569 averTrainLoss:20.473 averTestLoss:18.216
# >>> EPOCH:570 averTrainLoss:22.756 averTestLoss:18.021
# >>> EPOCH:571 averTrainLoss:19.932 averTestLoss:17.894
# >>> EPOCH:572 averTrainLoss:22.168 averTestLoss:17.982
# >>> EPOCH:573 averTrainLoss:22.304 averTestLoss:18.137
# >>> EPOCH:574 averTrainLoss:20.788 averTestLoss:18.197
# >>> EPOCH:575 averTrainLoss:22.300 averTestLoss:18.209
# >>> EPOCH:576 averTrainLoss:22.667 averTestLoss:18.256
# >>> EPOCH:577 averTrainLoss:21.480 averTestLoss:18.232
# >>> EPOCH:578 averTrainLoss:22.349 averTestLoss:18.100
# >>> EPOCH:579 averTrainLoss:20.065 averTestLoss:17.935
# >>> EPOCH:580 averTrainLoss:20.231 averTestLoss:17.866
# >>> EPOCH:581 averTrainLoss:22.979 averTestLoss:17.868
# >>> EPOCH:582 averTrainLoss:22.666 averTestLoss:17.904
# >>> EPOCH:583 averTrainLoss:19.986 averTestLoss:17.882
# >>> EPOCH:584 averTrainLoss:20.058 averTestLoss:17.878
# >>> EPOCH:585 averTrainLoss:22.802 averTestLoss:17.972
# >>> EPOCH:586 averTrainLoss:21.146 averTestLoss:17.993
# >>> EPOCH:587 averTrainLoss:20.714 averTestLoss:17.901
# >>> EPOCH:588 averTrainLoss:23.123 averTestLoss:17.841
# >>> EPOCH:589 averTrainLoss:21.690 averTestLoss:17.866
# >>> EPOCH:590 averTrainLoss:23.153 averTestLoss:17.880
# >>> EPOCH:591 averTrainLoss:20.613 averTestLoss:17.899
# >>> EPOCH:592 averTrainLoss:18.913 averTestLoss:17.931
# >>> EPOCH:593 averTrainLoss:20.027 averTestLoss:18.001
# >>> EPOCH:594 averTrainLoss:22.059 averTestLoss:18.037
# >>> EPOCH:595 averTrainLoss:18.363 averTestLoss:18.047
# >>> EPOCH:596 averTrainLoss:21.286 averTestLoss:18.010
# >>> EPOCH:597 averTrainLoss:20.718 averTestLoss:17.969
# >>> EPOCH:598 averTrainLoss:22.102 averTestLoss:17.943
# >>> EPOCH:599 averTrainLoss:21.584 averTestLoss:17.939
# >>> EPOCH:600 averTrainLoss:19.017 averTestLoss:17.965
# >>> EPOCH:601 averTrainLoss:20.903 averTestLoss:18.006
# >>> EPOCH:602 averTrainLoss:19.498 averTestLoss:18.009
# >>> EPOCH:603 averTrainLoss:21.434 averTestLoss:17.955
# >>> EPOCH:604 averTrainLoss:19.351 averTestLoss:17.917
# >>> EPOCH:605 averTrainLoss:22.385 averTestLoss:17.906
# >>> EPOCH:606 averTrainLoss:20.049 averTestLoss:17.925
# >>> EPOCH:607 averTrainLoss:18.975 averTestLoss:17.908
# >>> EPOCH:608 averTrainLoss:20.805 averTestLoss:17.913
# >>> EPOCH:609 averTrainLoss:21.330 averTestLoss:17.953
# >>> EPOCH:610 averTrainLoss:19.116 averTestLoss:17.990
# >>> EPOCH:611 averTrainLoss:19.875 averTestLoss:18.047
# >>> EPOCH:612 averTrainLoss:20.071 averTestLoss:18.063
# >>> EPOCH:613 averTrainLoss:20.927 averTestLoss:18.050
# >>> EPOCH:614 averTrainLoss:21.061 averTestLoss:18.047
# >>> EPOCH:615 averTrainLoss:19.260 averTestLoss:17.997
# >>> EPOCH:616 averTrainLoss:20.672 averTestLoss:17.949
# >>> EPOCH:617 averTrainLoss:22.410 averTestLoss:17.933
# >>> EPOCH:618 averTrainLoss:21.612 averTestLoss:17.974
# >>> EPOCH:619 averTrainLoss:19.901 averTestLoss:18.007
# >>> EPOCH:620 averTrainLoss:19.212 averTestLoss:18.049
# >>> EPOCH:621 averTrainLoss:22.163 averTestLoss:18.117
# >>> EPOCH:622 averTrainLoss:20.987 averTestLoss:18.123
# >>> EPOCH:623 averTrainLoss:20.656 averTestLoss:18.053
# >>> EPOCH:624 averTrainLoss:23.802 averTestLoss:17.937
# >>> EPOCH:625 averTrainLoss:22.522 averTestLoss:17.958
# >>> EPOCH:626 averTrainLoss:22.093 averTestLoss:18.022
# >>> EPOCH:627 averTrainLoss:23.066 averTestLoss:18.026
# >>> EPOCH:628 averTrainLoss:23.483 averTestLoss:18.021
# >>> EPOCH:629 averTrainLoss:20.933 averTestLoss:18.116
# >>> EPOCH:630 averTrainLoss:22.072 averTestLoss:18.291
# >>> EPOCH:631 averTrainLoss:22.352 averTestLoss:18.281
# >>> EPOCH:632 averTrainLoss:19.610 averTestLoss:18.133
# >>> EPOCH:633 averTrainLoss:21.612 averTestLoss:17.989
# >>> EPOCH:634 averTrainLoss:22.289 averTestLoss:17.995
# >>> EPOCH:635 averTrainLoss:23.090 averTestLoss:18.020
# >>> EPOCH:636 averTrainLoss:21.843 averTestLoss:17.953
# >>> EPOCH:637 averTrainLoss:18.333 averTestLoss:17.904
# >>> EPOCH:638 averTrainLoss:22.123 averTestLoss:17.950
# >>> EPOCH:639 averTrainLoss:20.554 averTestLoss:17.969
# >>> EPOCH:640 averTrainLoss:21.403 averTestLoss:17.954
# >>> EPOCH:641 averTrainLoss:20.938 averTestLoss:18.028
# >>> EPOCH:642 averTrainLoss:20.616 averTestLoss:18.087
# >>> EPOCH:643 averTrainLoss:21.975 averTestLoss:18.046
# >>> EPOCH:644 averTrainLoss:22.772 averTestLoss:17.976
# >>> EPOCH:645 averTrainLoss:22.191 averTestLoss:17.962
# >>> EPOCH:646 averTrainLoss:20.747 averTestLoss:17.972
# >>> EPOCH:647 averTrainLoss:20.824 averTestLoss:17.963
# >>> EPOCH:648 averTrainLoss:20.606 averTestLoss:17.924
# >>> EPOCH:649 averTrainLoss:20.536 averTestLoss:17.917
# >>> EPOCH:650 averTrainLoss:21.016 averTestLoss:17.941
# >>> EPOCH:651 averTrainLoss:19.920 averTestLoss:17.985
# >>> EPOCH:652 averTrainLoss:20.672 averTestLoss:18.042
# >>> EPOCH:653 averTrainLoss:20.084 averTestLoss:18.090
# >>> EPOCH:654 averTrainLoss:20.276 averTestLoss:18.108
# >>> EPOCH:655 averTrainLoss:21.921 averTestLoss:18.078
# >>> EPOCH:656 averTrainLoss:20.539 averTestLoss:18.125
# >>> EPOCH:657 averTrainLoss:20.222 averTestLoss:18.175
# >>> EPOCH:658 averTrainLoss:19.576 averTestLoss:18.129
# >>> EPOCH:659 averTrainLoss:21.152 averTestLoss:18.007
# >>> EPOCH:660 averTrainLoss:21.935 averTestLoss:17.978
# >>> EPOCH:661 averTrainLoss:18.867 averTestLoss:18.047
# >>> EPOCH:662 averTrainLoss:23.188 averTestLoss:17.984
# >>> EPOCH:663 averTrainLoss:23.624 averTestLoss:17.843
# >>> EPOCH:664 averTrainLoss:19.097 averTestLoss:17.840
# >>> EPOCH:665 averTrainLoss:20.860 averTestLoss:17.879
# >>> EPOCH:666 averTrainLoss:18.806 averTestLoss:17.911
# >>> EPOCH:667 averTrainLoss:20.725 averTestLoss:17.891
# >>> EPOCH:668 averTrainLoss:20.385 averTestLoss:17.917
# >>> EPOCH:669 averTrainLoss:18.242 averTestLoss:18.008
# >>> EPOCH:670 averTrainLoss:21.200 averTestLoss:18.099
# >>> EPOCH:671 averTrainLoss:20.653 averTestLoss:18.101
# >>> EPOCH:672 averTrainLoss:21.888 averTestLoss:18.122
# >>> EPOCH:673 averTrainLoss:21.497 averTestLoss:18.177
# >>> EPOCH:674 averTrainLoss:19.823 averTestLoss:18.191
# >>> EPOCH:675 averTrainLoss:22.267 averTestLoss:18.149
# >>> EPOCH:676 averTrainLoss:22.116 averTestLoss:18.122
# >>> EPOCH:677 averTrainLoss:21.329 averTestLoss:18.030
# >>> EPOCH:678 averTrainLoss:22.039 averTestLoss:18.034
# >>> EPOCH:679 averTrainLoss:19.331 averTestLoss:18.080
# >>> EPOCH:680 averTrainLoss:20.718 averTestLoss:17.962
# >>> EPOCH:681 averTrainLoss:19.949 averTestLoss:17.869
# >>> EPOCH:682 averTrainLoss:21.733 averTestLoss:17.846
# >>> EPOCH:683 averTrainLoss:23.347 averTestLoss:17.882
# >>> EPOCH:684 averTrainLoss:18.801 averTestLoss:17.917
# >>> EPOCH:685 averTrainLoss:19.485 averTestLoss:17.934
# >>> EPOCH:686 averTrainLoss:20.220 averTestLoss:17.937
# >>> EPOCH:687 averTrainLoss:23.486 averTestLoss:17.996
# >>> EPOCH:688 averTrainLoss:21.597 averTestLoss:18.093
# >>> EPOCH:689 averTrainLoss:20.790 averTestLoss:18.119
# >>> EPOCH:690 averTrainLoss:21.357 averTestLoss:18.143
# >>> EPOCH:691 averTrainLoss:21.721 averTestLoss:18.130
# >>> EPOCH:692 averTrainLoss:20.456 averTestLoss:18.033
# >>> EPOCH:693 averTrainLoss:20.837 averTestLoss:17.962
# >>> EPOCH:694 averTrainLoss:20.106 averTestLoss:17.942
# >>> EPOCH:695 averTrainLoss:23.234 averTestLoss:17.952
# >>> EPOCH:696 averTrainLoss:19.510 averTestLoss:17.945
# >>> EPOCH:697 averTrainLoss:23.622 averTestLoss:17.950
# >>> EPOCH:698 averTrainLoss:19.050 averTestLoss:17.962
# >>> EPOCH:699 averTrainLoss:21.043 averTestLoss:18.002
# >>> EPOCH:700 averTrainLoss:23.112 averTestLoss:18.034
# >>> EPOCH:701 averTrainLoss:22.540 averTestLoss:18.010
# >>> EPOCH:702 averTrainLoss:24.100 averTestLoss:17.970
# >>> EPOCH:703 averTrainLoss:18.616 averTestLoss:17.948
# >>> EPOCH:704 averTrainLoss:20.481 averTestLoss:17.945
# >>> EPOCH:705 averTrainLoss:22.260 averTestLoss:17.957
# >>> EPOCH:706 averTrainLoss:20.518 averTestLoss:17.994
# >>> EPOCH:707 averTrainLoss:20.882 averTestLoss:18.046
# >>> EPOCH:708 averTrainLoss:20.124 averTestLoss:18.056
# >>> EPOCH:709 averTrainLoss:22.253 averTestLoss:18.086
# >>> EPOCH:710 averTrainLoss:19.687 averTestLoss:18.151
# >>> EPOCH:711 averTrainLoss:18.562 averTestLoss:18.080
# >>> EPOCH:712 averTrainLoss:20.355 averTestLoss:17.989
# >>> EPOCH:713 averTrainLoss:19.192 averTestLoss:17.931
# >>> EPOCH:714 averTrainLoss:23.222 averTestLoss:17.895
# >>> EPOCH:715 averTrainLoss:20.246 averTestLoss:17.898
# >>> EPOCH:716 averTrainLoss:18.806 averTestLoss:17.898
# >>> EPOCH:717 averTrainLoss:21.083 averTestLoss:17.893
# >>> EPOCH:718 averTrainLoss:18.871 averTestLoss:17.923
# >>> EPOCH:719 averTrainLoss:19.573 averTestLoss:18.001
# >>> EPOCH:720 averTrainLoss:20.491 averTestLoss:18.071
# >>> EPOCH:721 averTrainLoss:21.531 averTestLoss:18.117
# >>> EPOCH:722 averTrainLoss:22.387 averTestLoss:18.106
# >>> EPOCH:723 averTrainLoss:20.297 averTestLoss:18.018
# >>> EPOCH:724 averTrainLoss:21.620 averTestLoss:17.941
# >>> EPOCH:725 averTrainLoss:19.178 averTestLoss:17.903
# >>> EPOCH:726 averTrainLoss:20.481 averTestLoss:17.904
# >>> EPOCH:727 averTrainLoss:22.052 averTestLoss:17.939
# >>> EPOCH:728 averTrainLoss:20.254 averTestLoss:17.933
# >>> EPOCH:729 averTrainLoss:21.074 averTestLoss:17.986
# >>> EPOCH:730 averTrainLoss:22.155 averTestLoss:18.101
# >>> EPOCH:731 averTrainLoss:20.233 averTestLoss:18.062
# >>> EPOCH:732 averTrainLoss:18.633 averTestLoss:17.971
# >>> EPOCH:733 averTrainLoss:22.140 averTestLoss:17.914
# >>> EPOCH:734 averTrainLoss:21.343 averTestLoss:17.955
# >>> EPOCH:735 averTrainLoss:20.028 averTestLoss:18.039
# >>> EPOCH:736 averTrainLoss:20.186 averTestLoss:18.082
# >>> EPOCH:737 averTrainLoss:20.692 averTestLoss:18.081
# >>> EPOCH:738 averTrainLoss:23.082 averTestLoss:18.090
# >>> EPOCH:739 averTrainLoss:20.729 averTestLoss:18.116
# >>> EPOCH:740 averTrainLoss:19.385 averTestLoss:18.040
# >>> EPOCH:741 averTrainLoss:19.851 averTestLoss:17.946
# >>> EPOCH:742 averTrainLoss:21.293 averTestLoss:17.934
# >>> EPOCH:743 averTrainLoss:18.917 averTestLoss:17.980
# >>> EPOCH:744 averTrainLoss:20.676 averTestLoss:18.051
# >>> EPOCH:745 averTrainLoss:19.689 averTestLoss:18.053
# >>> EPOCH:746 averTrainLoss:20.797 averTestLoss:18.135
# >>> EPOCH:747 averTrainLoss:19.454 averTestLoss:18.282
# >>> EPOCH:748 averTrainLoss:21.103 averTestLoss:18.290
# >>> EPOCH:749 averTrainLoss:21.028 averTestLoss:18.131
# >>> EPOCH:750 averTrainLoss:21.911 averTestLoss:17.984
# >>> EPOCH:751 averTrainLoss:19.672 averTestLoss:17.905
# >>> EPOCH:752 averTrainLoss:20.581 averTestLoss:17.878
# >>> EPOCH:753 averTrainLoss:18.279 averTestLoss:17.873
# >>> EPOCH:754 averTrainLoss:21.336 averTestLoss:17.878
# >>> EPOCH:755 averTrainLoss:21.538 averTestLoss:17.899
# >>> EPOCH:756 averTrainLoss:21.508 averTestLoss:17.993
# >>> EPOCH:757 averTrainLoss:20.814 averTestLoss:18.110
# >>> EPOCH:758 averTrainLoss:20.203 averTestLoss:18.262
# >>> EPOCH:759 averTrainLoss:20.706 averTestLoss:18.240
# >>> EPOCH:760 averTrainLoss:21.021 averTestLoss:18.086
# >>> EPOCH:761 averTrainLoss:21.850 averTestLoss:17.949
# >>> EPOCH:762 averTrainLoss:21.474 averTestLoss:17.925
# >>> EPOCH:763 averTrainLoss:19.222 averTestLoss:17.897
# >>> EPOCH:764 averTrainLoss:21.455 averTestLoss:17.914
# >>> EPOCH:765 averTrainLoss:19.693 averTestLoss:17.972
# >>> EPOCH:766 averTrainLoss:18.968 averTestLoss:18.065
# >>> EPOCH:767 averTrainLoss:18.267 averTestLoss:18.111
# >>> EPOCH:768 averTrainLoss:18.809 averTestLoss:18.126
# >>> EPOCH:769 averTrainLoss:20.875 averTestLoss:18.080
# >>> EPOCH:770 averTrainLoss:23.022 averTestLoss:18.025
# >>> EPOCH:771 averTrainLoss:22.377 averTestLoss:18.017
# >>> EPOCH:772 averTrainLoss:23.121 averTestLoss:17.956
# >>> EPOCH:773 averTrainLoss:20.922 averTestLoss:17.943
# >>> EPOCH:774 averTrainLoss:20.624 averTestLoss:18.023
# >>> EPOCH:775 averTrainLoss:18.843 averTestLoss:18.125
# >>> EPOCH:776 averTrainLoss:20.676 averTestLoss:18.114
# >>> EPOCH:777 averTrainLoss:19.861 averTestLoss:18.101
# >>> EPOCH:778 averTrainLoss:23.614 averTestLoss:18.118
# >>> EPOCH:779 averTrainLoss:22.187 averTestLoss:18.045
# >>> EPOCH:780 averTrainLoss:22.139 averTestLoss:17.984
# >>> EPOCH:781 averTrainLoss:21.961 averTestLoss:17.960
# >>> EPOCH:782 averTrainLoss:22.541 averTestLoss:17.974
# >>> EPOCH:783 averTrainLoss:24.223 averTestLoss:17.978
# >>> EPOCH:784 averTrainLoss:20.504 averTestLoss:18.015
# >>> EPOCH:785 averTrainLoss:22.012 averTestLoss:18.058
# >>> EPOCH:786 averTrainLoss:20.697 averTestLoss:18.090
# >>> EPOCH:787 averTrainLoss:21.033 averTestLoss:18.077
# >>> EPOCH:788 averTrainLoss:21.866 averTestLoss:18.057
# >>> EPOCH:789 averTrainLoss:20.434 averTestLoss:18.055
# >>> EPOCH:790 averTrainLoss:19.473 averTestLoss:18.058
# >>> EPOCH:791 averTrainLoss:21.538 averTestLoss:17.936
# >>> EPOCH:792 averTrainLoss:18.716 averTestLoss:17.900
# >>> EPOCH:793 averTrainLoss:22.222 averTestLoss:18.018
# >>> EPOCH:794 averTrainLoss:22.759 averTestLoss:18.095
# >>> EPOCH:795 averTrainLoss:21.136 averTestLoss:18.098
# >>> EPOCH:796 averTrainLoss:22.307 averTestLoss:18.151
# >>> EPOCH:797 averTrainLoss:22.273 averTestLoss:18.366
# >>> EPOCH:798 averTrainLoss:23.025 averTestLoss:18.409
# >>> EPOCH:799 averTrainLoss:19.016 averTestLoss:18.154
# >>> EPOCH:800 averTrainLoss:20.396 averTestLoss:17.907
# >>> EPOCH:801 averTrainLoss:21.617 averTestLoss:17.897
# >>> EPOCH:802 averTrainLoss:21.242 averTestLoss:18.038
# >>> EPOCH:803 averTrainLoss:22.925 averTestLoss:18.111
# >>> EPOCH:804 averTrainLoss:22.028 averTestLoss:18.016
# >>> EPOCH:805 averTrainLoss:22.631 averTestLoss:17.919
# >>> EPOCH:806 averTrainLoss:21.569 averTestLoss:17.991
# >>> EPOCH:807 averTrainLoss:21.432 averTestLoss:18.295
# >>> EPOCH:808 averTrainLoss:20.954 averTestLoss:18.281
# >>> EPOCH:809 averTrainLoss:22.043 averTestLoss:18.059
# >>> EPOCH:810 averTrainLoss:23.019 averTestLoss:17.911
# >>> EPOCH:811 averTrainLoss:23.023 averTestLoss:17.904
# >>> EPOCH:812 averTrainLoss:20.877 averTestLoss:17.920
# >>> EPOCH:813 averTrainLoss:20.873 averTestLoss:17.885
# >>> EPOCH:814 averTrainLoss:19.598 averTestLoss:17.880
# >>> EPOCH:815 averTrainLoss:21.033 averTestLoss:17.879
# >>> EPOCH:816 averTrainLoss:21.377 averTestLoss:17.936
# >>> EPOCH:817 averTrainLoss:20.501 averTestLoss:18.015
# >>> EPOCH:818 averTrainLoss:21.087 averTestLoss:18.007
# >>> EPOCH:819 averTrainLoss:20.996 averTestLoss:17.945
# >>> EPOCH:820 averTrainLoss:22.080 averTestLoss:17.909
# >>> EPOCH:821 averTrainLoss:19.959 averTestLoss:17.920
# >>> EPOCH:822 averTrainLoss:20.081 averTestLoss:17.936
# >>> EPOCH:823 averTrainLoss:19.577 averTestLoss:17.949
# >>> EPOCH:824 averTrainLoss:18.329 averTestLoss:17.966
# >>> EPOCH:825 averTrainLoss:21.028 averTestLoss:18.048
# >>> EPOCH:826 averTrainLoss:21.601 averTestLoss:18.113
# >>> EPOCH:827 averTrainLoss:19.041 averTestLoss:18.117
# >>> EPOCH:828 averTrainLoss:23.361 averTestLoss:18.056
# >>> EPOCH:829 averTrainLoss:21.125 averTestLoss:18.018
# >>> EPOCH:830 averTrainLoss:21.027 averTestLoss:18.000
# >>> EPOCH:831 averTrainLoss:23.779 averTestLoss:17.911
# >>> EPOCH:832 averTrainLoss:21.057 averTestLoss:17.852
# >>> EPOCH:833 averTrainLoss:19.143 averTestLoss:17.902
# >>> EPOCH:834 averTrainLoss:23.699 averTestLoss:18.014
# >>> EPOCH:835 averTrainLoss:20.964 averTestLoss:18.035
# >>> EPOCH:836 averTrainLoss:20.971 averTestLoss:18.014
# >>> EPOCH:837 averTrainLoss:20.818 averTestLoss:18.013
# >>> EPOCH:838 averTrainLoss:18.539 averTestLoss:18.097
# >>> EPOCH:839 averTrainLoss:22.196 averTestLoss:18.134
# >>> EPOCH:840 averTrainLoss:22.356 averTestLoss:18.065
# >>> EPOCH:841 averTrainLoss:22.392 averTestLoss:18.021
# >>> EPOCH:842 averTrainLoss:21.827 averTestLoss:18.161
# >>> EPOCH:843 averTrainLoss:21.896 averTestLoss:18.151
# >>> EPOCH:844 averTrainLoss:23.040 averTestLoss:17.976
# >>> EPOCH:845 averTrainLoss:22.330 averTestLoss:17.913
# >>> EPOCH:846 averTrainLoss:21.273 averTestLoss:17.980
# >>> EPOCH:847 averTrainLoss:20.427 averTestLoss:17.999
# >>> EPOCH:848 averTrainLoss:21.347 averTestLoss:17.962
# >>> EPOCH:849 averTrainLoss:22.998 averTestLoss:17.972
# >>> EPOCH:850 averTrainLoss:18.660 averTestLoss:18.008
# >>> EPOCH:851 averTrainLoss:21.684 averTestLoss:18.012
# >>> EPOCH:852 averTrainLoss:18.670 averTestLoss:17.993
# >>> EPOCH:853 averTrainLoss:20.208 averTestLoss:17.974
# >>> EPOCH:854 averTrainLoss:22.807 averTestLoss:17.969
# >>> EPOCH:855 averTrainLoss:21.803 averTestLoss:17.963
# >>> EPOCH:856 averTrainLoss:20.507 averTestLoss:17.957
# >>> EPOCH:857 averTrainLoss:20.312 averTestLoss:17.939
# >>> EPOCH:858 averTrainLoss:20.200 averTestLoss:17.954
# >>> EPOCH:859 averTrainLoss:19.328 averTestLoss:17.950
# >>> EPOCH:860 averTrainLoss:21.875 averTestLoss:17.984
# >>> EPOCH:861 averTrainLoss:24.354 averTestLoss:17.998
# >>> EPOCH:862 averTrainLoss:19.831 averTestLoss:17.982
# >>> EPOCH:863 averTrainLoss:17.526 averTestLoss:17.969
# >>> EPOCH:864 averTrainLoss:20.335 averTestLoss:17.980
# >>> EPOCH:865 averTrainLoss:20.098 averTestLoss:17.992
# >>> EPOCH:866 averTrainLoss:20.563 averTestLoss:17.967
# >>> EPOCH:867 averTrainLoss:20.201 averTestLoss:17.995
# >>> EPOCH:868 averTrainLoss:21.132 averTestLoss:18.022
# >>> EPOCH:869 averTrainLoss:20.338 averTestLoss:17.988
# >>> EPOCH:870 averTrainLoss:20.914 averTestLoss:17.964
# >>> EPOCH:871 averTrainLoss:20.821 averTestLoss:17.988
# >>> EPOCH:872 averTrainLoss:21.325 averTestLoss:17.984
# >>> EPOCH:873 averTrainLoss:21.654 averTestLoss:17.967
# >>> EPOCH:874 averTrainLoss:21.555 averTestLoss:17.984
# ...
# >>> EPOCH:9716 averTrainLoss:17.895 averTestLoss:18.393
# >>> EPOCH:9717 averTrainLoss:18.855 averTestLoss:18.266
# >>> EPOCH:9718 averTrainLoss:19.978 averTestLoss:18.247
# >>> EPOCH:9719 averTrainLoss:18.444 averTestLoss:18.285
# >>> EPOCH:9720 averTrainLoss:16.959 averTestLoss:18.387
# >>> EPOCH:9721 averTrainLoss:18.040 averTestLoss:18.502
# >>> EPOCH:9722 averTrainLoss:18.678 averTestLoss:18.408
# >>> EPOCH:9723 averTrainLoss:19.171 averTestLoss:18.328
# >>> EPOCH:9724 averTrainLoss:17.166 averTestLoss:18.226
# >>> EPOCH:9725 averTrainLoss:19.175 averTestLoss:18.165
# >>> EPOCH:9726 averTrainLoss:18.101 averTestLoss:18.218
# >>> EPOCH:9727 averTrainLoss:17.736 averTestLoss:18.316
# >>> EPOCH:9728 averTrainLoss:19.209 averTestLoss:18.467
# >>> EPOCH:9729 averTrainLoss:18.075 averTestLoss:18.737
# >>> EPOCH:9730 averTrainLoss:18.475 averTestLoss:18.932
# >>> EPOCH:9731 averTrainLoss:18.625 averTestLoss:19.100
# >>> EPOCH:9732 averTrainLoss:18.255 averTestLoss:19.548
# >>> EPOCH:9733 averTrainLoss:19.167 averTestLoss:18.720
# >>> EPOCH:9734 averTrainLoss:18.544 averTestLoss:18.366
# >>> EPOCH:9735 averTrainLoss:17.722 averTestLoss:18.318
# >>> EPOCH:9736 averTrainLoss:17.842 averTestLoss:18.342
# >>> EPOCH:9737 averTrainLoss:18.847 averTestLoss:18.463
# >>> EPOCH:9738 averTrainLoss:18.589 averTestLoss:18.664
# >>> EPOCH:9739 averTrainLoss:18.843 averTestLoss:18.717
# >>> EPOCH:9740 averTrainLoss:19.355 averTestLoss:18.559
# >>> EPOCH:9741 averTrainLoss:18.714 averTestLoss:18.341
# >>> EPOCH:9742 averTrainLoss:19.836 averTestLoss:18.215
# >>> EPOCH:9743 averTrainLoss:17.759 averTestLoss:18.128
# >>> EPOCH:9744 averTrainLoss:19.212 averTestLoss:18.159
# >>> EPOCH:9745 averTrainLoss:18.801 averTestLoss:18.107
# >>> EPOCH:9746 averTrainLoss:16.551 averTestLoss:18.111
# >>> EPOCH:9747 averTrainLoss:18.991 averTestLoss:18.237
# >>> EPOCH:9748 averTrainLoss:22.006 averTestLoss:18.396
# >>> EPOCH:9749 averTrainLoss:18.486 averTestLoss:18.585
# >>> EPOCH:9750 averTrainLoss:19.529 averTestLoss:18.718
# >>> EPOCH:9751 averTrainLoss:18.989 averTestLoss:18.680
# >>> EPOCH:9752 averTrainLoss:19.489 averTestLoss:18.536
# >>> EPOCH:9753 averTrainLoss:18.461 averTestLoss:18.418
# >>> EPOCH:9754 averTrainLoss:20.523 averTestLoss:18.381
# >>> EPOCH:9755 averTrainLoss:18.530 averTestLoss:18.413
# >>> EPOCH:9756 averTrainLoss:17.942 averTestLoss:18.512
# >>> EPOCH:9757 averTrainLoss:18.673 averTestLoss:18.604
# >>> EPOCH:9758 averTrainLoss:18.871 averTestLoss:18.676
# >>> EPOCH:9759 averTrainLoss:20.825 averTestLoss:18.668
# >>> EPOCH:9760 averTrainLoss:20.035 averTestLoss:18.481
# >>> EPOCH:9761 averTrainLoss:17.050 averTestLoss:18.352
# >>> EPOCH:9762 averTrainLoss:18.068 averTestLoss:18.268
# >>> EPOCH:9763 averTrainLoss:16.796 averTestLoss:18.220
# >>> EPOCH:9764 averTrainLoss:18.870 averTestLoss:18.237
# >>> EPOCH:9765 averTrainLoss:21.051 averTestLoss:18.328
# >>> EPOCH:9766 averTrainLoss:15.660 averTestLoss:18.418
# >>> EPOCH:9767 averTrainLoss:17.805 averTestLoss:18.521
# >>> EPOCH:9768 averTrainLoss:17.325 averTestLoss:18.616
# >>> EPOCH:9769 averTrainLoss:18.383 averTestLoss:18.742
# >>> EPOCH:9770 averTrainLoss:20.398 averTestLoss:18.625
# >>> EPOCH:9771 averTrainLoss:16.653 averTestLoss:18.615
# >>> EPOCH:9772 averTrainLoss:18.153 averTestLoss:18.573
# >>> EPOCH:9773 averTrainLoss:16.615 averTestLoss:18.351
# >>> EPOCH:9774 averTrainLoss:18.713 averTestLoss:18.182
# >>> EPOCH:9775 averTrainLoss:16.757 averTestLoss:18.189
# >>> EPOCH:9776 averTrainLoss:18.600 averTestLoss:18.254
# >>> EPOCH:9777 averTrainLoss:19.268 averTestLoss:18.281
# >>> EPOCH:9778 averTrainLoss:18.392 averTestLoss:18.414
# >>> EPOCH:9779 averTrainLoss:17.541 averTestLoss:18.558
# >>> EPOCH:9780 averTrainLoss:18.449 averTestLoss:18.544
# >>> EPOCH:9781 averTrainLoss:19.573 averTestLoss:18.545
# >>> EPOCH:9782 averTrainLoss:18.582 averTestLoss:18.585
# >>> EPOCH:9783 averTrainLoss:19.380 averTestLoss:18.509
# >>> EPOCH:9784 averTrainLoss:17.484 averTestLoss:18.464
# >>> EPOCH:9785 averTrainLoss:18.897 averTestLoss:18.457
# >>> EPOCH:9786 averTrainLoss:18.793 averTestLoss:18.420
# >>> EPOCH:9787 averTrainLoss:17.268 averTestLoss:18.419
# >>> EPOCH:9788 averTrainLoss:19.384 averTestLoss:18.506
# >>> EPOCH:9789 averTrainLoss:18.096 averTestLoss:18.551
# >>> EPOCH:9790 averTrainLoss:18.219 averTestLoss:18.643
# >>> EPOCH:9791 averTrainLoss:20.493 averTestLoss:18.766
# >>> EPOCH:9792 averTrainLoss:19.232 averTestLoss:18.728
# >>> EPOCH:9793 averTrainLoss:16.935 averTestLoss:18.543
# >>> EPOCH:9794 averTrainLoss:17.836 averTestLoss:18.316
# >>> EPOCH:9795 averTrainLoss:19.156 averTestLoss:18.124
# >>> EPOCH:9796 averTrainLoss:18.943 averTestLoss:18.040
# >>> EPOCH:9797 averTrainLoss:19.828 averTestLoss:18.198
# >>> EPOCH:9798 averTrainLoss:16.625 averTestLoss:18.492
# >>> EPOCH:9799 averTrainLoss:17.590 averTestLoss:18.653
# >>> EPOCH:9800 averTrainLoss:17.891 averTestLoss:18.571
# >>> EPOCH:9801 averTrainLoss:20.486 averTestLoss:18.402
# >>> EPOCH:9802 averTrainLoss:18.190 averTestLoss:18.402
# >>> EPOCH:9803 averTrainLoss:19.013 averTestLoss:18.357
# >>> EPOCH:9804 averTrainLoss:17.747 averTestLoss:18.290
# >>> EPOCH:9805 averTrainLoss:16.750 averTestLoss:18.373
# >>> EPOCH:9806 averTrainLoss:17.891 averTestLoss:18.650
# >>> EPOCH:9807 averTrainLoss:19.605 averTestLoss:18.852
# >>> EPOCH:9808 averTrainLoss:17.288 averTestLoss:19.016
# >>> EPOCH:9809 averTrainLoss:18.441 averTestLoss:18.921
# >>> EPOCH:9810 averTrainLoss:20.439 averTestLoss:18.775
# >>> EPOCH:9811 averTrainLoss:17.808 averTestLoss:18.770
# >>> EPOCH:9812 averTrainLoss:18.225 averTestLoss:18.621
# >>> EPOCH:9813 averTrainLoss:17.395 averTestLoss:18.423
# >>> EPOCH:9814 averTrainLoss:18.118 averTestLoss:18.397
# >>> EPOCH:9815 averTrainLoss:20.634 averTestLoss:18.448
# >>> EPOCH:9816 averTrainLoss:17.980 averTestLoss:18.305
# >>> EPOCH:9817 averTrainLoss:19.770 averTestLoss:18.331
# >>> EPOCH:9818 averTrainLoss:18.159 averTestLoss:18.431
# >>> EPOCH:9819 averTrainLoss:17.964 averTestLoss:18.505
# >>> EPOCH:9820 averTrainLoss:17.642 averTestLoss:18.567
# >>> EPOCH:9821 averTrainLoss:17.892 averTestLoss:18.591
# >>> EPOCH:9822 averTrainLoss:19.802 averTestLoss:18.635
# >>> EPOCH:9823 averTrainLoss:17.530 averTestLoss:18.680
# >>> EPOCH:9824 averTrainLoss:18.299 averTestLoss:18.716
# >>> EPOCH:9825 averTrainLoss:18.450 averTestLoss:18.871
# >>> EPOCH:9826 averTrainLoss:15.883 averTestLoss:19.059
# >>> EPOCH:9827 averTrainLoss:17.785 averTestLoss:19.074
# >>> EPOCH:9828 averTrainLoss:18.911 averTestLoss:18.919
# >>> EPOCH:9829 averTrainLoss:18.769 averTestLoss:18.655
# >>> EPOCH:9830 averTrainLoss:18.774 averTestLoss:18.533
# >>> EPOCH:9831 averTrainLoss:18.673 averTestLoss:18.507
# >>> EPOCH:9832 averTrainLoss:19.264 averTestLoss:18.384
# >>> EPOCH:9833 averTrainLoss:16.905 averTestLoss:18.259
# >>> EPOCH:9834 averTrainLoss:19.646 averTestLoss:18.243
# >>> EPOCH:9835 averTrainLoss:17.320 averTestLoss:18.306
# >>> EPOCH:9836 averTrainLoss:19.389 averTestLoss:18.376
# >>> EPOCH:9837 averTrainLoss:20.293 averTestLoss:18.436
# >>> EPOCH:9838 averTrainLoss:19.042 averTestLoss:18.477
# >>> EPOCH:9839 averTrainLoss:18.259 averTestLoss:18.260
# >>> EPOCH:9840 averTrainLoss:19.072 averTestLoss:18.272
# >>> EPOCH:9841 averTrainLoss:19.235 averTestLoss:18.282
# >>> EPOCH:9842 averTrainLoss:20.279 averTestLoss:18.510
# >>> EPOCH:9843 averTrainLoss:19.228 averTestLoss:18.601
# >>> EPOCH:9844 averTrainLoss:19.014 averTestLoss:18.483
# >>> EPOCH:9845 averTrainLoss:19.098 averTestLoss:18.592
# >>> EPOCH:9846 averTrainLoss:19.504 averTestLoss:18.663
# >>> EPOCH:9847 averTrainLoss:17.851 averTestLoss:18.693
# >>> EPOCH:9848 averTrainLoss:16.839 averTestLoss:18.676
# >>> EPOCH:9849 averTrainLoss:16.624 averTestLoss:18.633
# >>> EPOCH:9850 averTrainLoss:19.047 averTestLoss:18.554
# >>> EPOCH:9851 averTrainLoss:18.025 averTestLoss:18.590
# >>> EPOCH:9852 averTrainLoss:18.936 averTestLoss:18.724
# >>> EPOCH:9853 averTrainLoss:18.534 averTestLoss:18.760
# >>> EPOCH:9854 averTrainLoss:16.810 averTestLoss:18.670
# >>> EPOCH:9855 averTrainLoss:17.761 averTestLoss:18.462
# >>> EPOCH:9856 averTrainLoss:16.841 averTestLoss:18.372
# >>> EPOCH:9857 averTrainLoss:18.560 averTestLoss:18.449
# >>> EPOCH:9858 averTrainLoss:19.889 averTestLoss:18.428
# >>> EPOCH:9859 averTrainLoss:17.650 averTestLoss:18.299
# >>> EPOCH:9860 averTrainLoss:17.546 averTestLoss:18.255
# >>> EPOCH:9861 averTrainLoss:19.392 averTestLoss:18.309
# >>> EPOCH:9862 averTrainLoss:19.451 averTestLoss:18.214
# >>> EPOCH:9863 averTrainLoss:18.074 averTestLoss:18.054
# >>> EPOCH:9864 averTrainLoss:19.047 averTestLoss:18.080
# >>> EPOCH:9865 averTrainLoss:20.097 averTestLoss:18.363
# >>> EPOCH:9866 averTrainLoss:17.082 averTestLoss:18.613
# >>> EPOCH:9867 averTrainLoss:18.709 averTestLoss:18.870
# >>> EPOCH:9868 averTrainLoss:18.638 averTestLoss:18.872
# >>> EPOCH:9869 averTrainLoss:18.998 averTestLoss:18.803
# >>> EPOCH:9870 averTrainLoss:19.248 averTestLoss:18.710
# >>> EPOCH:9871 averTrainLoss:16.781 averTestLoss:18.691
# >>> EPOCH:9872 averTrainLoss:19.652 averTestLoss:18.632
# >>> EPOCH:9873 averTrainLoss:17.178 averTestLoss:18.564
# >>> EPOCH:9874 averTrainLoss:19.946 averTestLoss:18.567
# >>> EPOCH:9875 averTrainLoss:18.608 averTestLoss:18.602
# >>> EPOCH:9876 averTrainLoss:19.833 averTestLoss:18.739
# >>> EPOCH:9877 averTrainLoss:17.264 averTestLoss:18.691
# >>> EPOCH:9878 averTrainLoss:18.060 averTestLoss:18.886
# >>> EPOCH:9879 averTrainLoss:17.369 averTestLoss:18.907
# >>> EPOCH:9880 averTrainLoss:17.534 averTestLoss:18.299
# >>> EPOCH:9881 averTrainLoss:18.637 averTestLoss:18.186
# >>> EPOCH:9882 averTrainLoss:19.046 averTestLoss:18.160
# >>> EPOCH:9883 averTrainLoss:17.676 averTestLoss:18.074
# >>> EPOCH:9884 averTrainLoss:18.630 averTestLoss:18.068
# >>> EPOCH:9885 averTrainLoss:18.871 averTestLoss:18.101
# >>> EPOCH:9886 averTrainLoss:18.719 averTestLoss:18.149
# >>> EPOCH:9887 averTrainLoss:17.054 averTestLoss:18.282
# >>> EPOCH:9888 averTrainLoss:17.692 averTestLoss:18.456
# >>> EPOCH:9889 averTrainLoss:16.869 averTestLoss:18.630
# >>> EPOCH:9890 averTrainLoss:19.588 averTestLoss:18.654
# >>> EPOCH:9891 averTrainLoss:19.595 averTestLoss:18.523
# >>> EPOCH:9892 averTrainLoss:18.143 averTestLoss:18.434
# >>> EPOCH:9893 averTrainLoss:18.108 averTestLoss:18.332
# >>> EPOCH:9894 averTrainLoss:18.429 averTestLoss:18.427
# >>> EPOCH:9895 averTrainLoss:17.905 averTestLoss:18.683
# >>> EPOCH:9896 averTrainLoss:18.384 averTestLoss:18.941
# >>> EPOCH:9897 averTrainLoss:17.838 averTestLoss:18.945
# >>> EPOCH:9898 averTrainLoss:19.048 averTestLoss:18.882
# >>> EPOCH:9899 averTrainLoss:18.356 averTestLoss:18.687
# >>> EPOCH:9900 averTrainLoss:19.524 averTestLoss:18.549
# >>> EPOCH:9901 averTrainLoss:19.869 averTestLoss:18.386
# >>> EPOCH:9902 averTrainLoss:16.908 averTestLoss:18.275
# >>> EPOCH:9903 averTrainLoss:18.795 averTestLoss:18.210
# >>> EPOCH:9904 averTrainLoss:19.996 averTestLoss:18.212
# >>> EPOCH:9905 averTrainLoss:19.066 averTestLoss:18.198
# >>> EPOCH:9906 averTrainLoss:17.613 averTestLoss:18.276
# >>> EPOCH:9907 averTrainLoss:16.665 averTestLoss:18.362
# >>> EPOCH:9908 averTrainLoss:20.086 averTestLoss:18.225
# >>> EPOCH:9909 averTrainLoss:16.774 averTestLoss:18.160
# >>> EPOCH:9910 averTrainLoss:19.286 averTestLoss:18.133
# >>> EPOCH:9911 averTrainLoss:18.587 averTestLoss:18.146
# >>> EPOCH:9912 averTrainLoss:18.869 averTestLoss:18.276
# >>> EPOCH:9913 averTrainLoss:17.940 averTestLoss:18.379
# >>> EPOCH:9914 averTrainLoss:18.188 averTestLoss:18.479
# >>> EPOCH:9915 averTrainLoss:17.782 averTestLoss:18.629
# >>> EPOCH:9916 averTrainLoss:20.228 averTestLoss:18.719
# >>> EPOCH:9917 averTrainLoss:19.029 averTestLoss:18.746
# >>> EPOCH:9918 averTrainLoss:18.912 averTestLoss:18.589
# >>> EPOCH:9919 averTrainLoss:18.702 averTestLoss:18.452
# >>> EPOCH:9920 averTrainLoss:17.185 averTestLoss:18.394
# >>> EPOCH:9921 averTrainLoss:19.747 averTestLoss:18.399
# >>> EPOCH:9922 averTrainLoss:18.397 averTestLoss:18.448
# >>> EPOCH:9923 averTrainLoss:17.899 averTestLoss:18.579
# >>> EPOCH:9924 averTrainLoss:19.659 averTestLoss:18.628
# >>> EPOCH:9925 averTrainLoss:18.511 averTestLoss:18.681
# >>> EPOCH:9926 averTrainLoss:19.008 averTestLoss:18.672
# >>> EPOCH:9927 averTrainLoss:18.403 averTestLoss:18.503
# >>> EPOCH:9928 averTrainLoss:20.099 averTestLoss:18.267
# >>> EPOCH:9929 averTrainLoss:18.538 averTestLoss:18.087
# >>> EPOCH:9930 averTrainLoss:17.223 averTestLoss:18.000
# >>> EPOCH:9931 averTrainLoss:17.060 averTestLoss:18.017
# >>> EPOCH:9932 averTrainLoss:18.465 averTestLoss:18.114
# >>> EPOCH:9933 averTrainLoss:18.173 averTestLoss:18.257
# >>> EPOCH:9934 averTrainLoss:19.423 averTestLoss:18.375
# >>> EPOCH:9935 averTrainLoss:20.176 averTestLoss:18.579
# >>> EPOCH:9936 averTrainLoss:17.680 averTestLoss:18.708
# >>> EPOCH:9937 averTrainLoss:19.737 averTestLoss:18.711
# >>> EPOCH:9938 averTrainLoss:18.630 averTestLoss:19.018
# >>> EPOCH:9939 averTrainLoss:19.342 averTestLoss:19.291
# >>> EPOCH:9940 averTrainLoss:17.162 averTestLoss:18.509
# >>> EPOCH:9941 averTrainLoss:18.831 averTestLoss:18.388
# >>> EPOCH:9942 averTrainLoss:17.171 averTestLoss:18.407
# >>> EPOCH:9943 averTrainLoss:20.911 averTestLoss:18.440
# >>> EPOCH:9944 averTrainLoss:18.839 averTestLoss:18.461
# >>> EPOCH:9945 averTrainLoss:17.354 averTestLoss:18.499
# >>> EPOCH:9946 averTrainLoss:19.437 averTestLoss:18.662
# >>> EPOCH:9947 averTrainLoss:17.107 averTestLoss:18.696
# >>> EPOCH:9948 averTrainLoss:19.016 averTestLoss:18.404
# >>> EPOCH:9949 averTrainLoss:17.598 averTestLoss:18.219
# >>> EPOCH:9950 averTrainLoss:19.322 averTestLoss:18.137
# >>> EPOCH:9951 averTrainLoss:17.202 averTestLoss:18.073
# >>> EPOCH:9952 averTrainLoss:19.816 averTestLoss:18.075
# >>> EPOCH:9953 averTrainLoss:18.839 averTestLoss:18.142
# >>> EPOCH:9954 averTrainLoss:18.836 averTestLoss:18.228
# >>> EPOCH:9955 averTrainLoss:18.276 averTestLoss:18.431
# >>> EPOCH:9956 averTrainLoss:15.972 averTestLoss:18.546
# >>> EPOCH:9957 averTrainLoss:17.198 averTestLoss:18.578
# >>> EPOCH:9958 averTrainLoss:19.098 averTestLoss:18.491
# >>> EPOCH:9959 averTrainLoss:20.569 averTestLoss:18.418
# >>> EPOCH:9960 averTrainLoss:18.973 averTestLoss:18.334
# >>> EPOCH:9961 averTrainLoss:19.844 averTestLoss:18.342
# >>> EPOCH:9962 averTrainLoss:18.980 averTestLoss:18.422
# >>> EPOCH:9963 averTrainLoss:20.234 averTestLoss:18.475
# >>> EPOCH:9964 averTrainLoss:17.321 averTestLoss:18.547
# >>> EPOCH:9965 averTrainLoss:19.418 averTestLoss:18.614
# >>> EPOCH:9966 averTrainLoss:19.917 averTestLoss:18.660
# >>> EPOCH:9967 averTrainLoss:17.914 averTestLoss:18.606
# >>> EPOCH:9968 averTrainLoss:19.251 averTestLoss:18.542
# >>> EPOCH:9969 averTrainLoss:18.340 averTestLoss:18.467
# >>> EPOCH:9970 averTrainLoss:19.427 averTestLoss:18.433
# >>> EPOCH:9971 averTrainLoss:18.169 averTestLoss:18.452
# >>> EPOCH:9972 averTrainLoss:17.428 averTestLoss:18.501
# >>> EPOCH:9973 averTrainLoss:19.271 averTestLoss:18.541
# >>> EPOCH:9974 averTrainLoss:18.944 averTestLoss:18.615
# >>> EPOCH:9975 averTrainLoss:18.232 averTestLoss:18.497
# >>> EPOCH:9976 averTrainLoss:18.602 averTestLoss:18.237
# >>> EPOCH:9977 averTrainLoss:17.937 averTestLoss:18.161
# >>> EPOCH:9978 averTrainLoss:18.835 averTestLoss:18.160
# >>> EPOCH:9979 averTrainLoss:18.651 averTestLoss:18.188
# >>> EPOCH:9980 averTrainLoss:19.931 averTestLoss:18.237
# >>> EPOCH:9981 averTrainLoss:17.457 averTestLoss:18.386
# >>> EPOCH:9982 averTrainLoss:19.118 averTestLoss:18.552
# >>> EPOCH:9983 averTrainLoss:20.249 averTestLoss:18.821
# >>> EPOCH:9984 averTrainLoss:18.609 averTestLoss:18.891
# >>> EPOCH:9985 averTrainLoss:17.982 averTestLoss:18.890
# >>> EPOCH:9986 averTrainLoss:17.922 averTestLoss:18.596
# >>> EPOCH:9987 averTrainLoss:16.451 averTestLoss:18.355
# >>> EPOCH:9988 averTrainLoss:17.555 averTestLoss:18.267
# >>> EPOCH:9989 averTrainLoss:18.829 averTestLoss:18.263
# >>> EPOCH:9990 averTrainLoss:18.736 averTestLoss:18.354
# >>> EPOCH:9991 averTrainLoss:19.179 averTestLoss:18.486
# >>> EPOCH:9992 averTrainLoss:15.922 averTestLoss:18.562
# >>> EPOCH:9993 averTrainLoss:15.548 averTestLoss:18.630
# >>> EPOCH:9994 averTrainLoss:17.489 averTestLoss:18.557
# >>> EPOCH:9995 averTrainLoss:17.497 averTestLoss:18.345
# >>> EPOCH:9996 averTrainLoss:20.387 averTestLoss:18.199
# >>> EPOCH:9997 averTrainLoss:18.433 averTestLoss:18.166
# >>> EPOCH:9998 averTrainLoss:18.269 averTestLoss:18.230
# >>> EPOCH:9999 averTrainLoss:18.957 averTestLoss:18.350
# >>> EPOCH:10000 averTrainLoss:19.331 averTestLoss:18.451

# %%
plt.plot(list(range(epochs)),lossList,label='Train')
plt.plot(list(range(epochs)),lossListTest,label='Test')
plt.legend()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
X=torch.tensor(dataX1)
Y=model(X.view(len(dataX1),1,11).float()).reshape(len(dataX1),168*1)

# %%
a1 = []
for i in Y.tolist():
    a1.append(i[-1])
a2 = []
for i in dataY1:
    a2.append(i[-1][-1])

a2 = np.array(a2)
a1 = np.array(a1)

# %%
print(a1[0])
print(a2[0])
print(np.abs((a2[0] - a1[0]) / a2[0]))
# print(np.abs((a2 - a1) / a2))
# Out:
# 23.066614151000977
# 24.385
# 0.05406544387939409

# %%
# 计算相对误差
relative_errors = np.abs((a2 - a1) / a2)

# 统计relative_errors中大于0.1的数量
count_greater_than_0_1 = (relative_errors > 0.1).sum()

# 统计relative_errors中小于等于0.1的数量
count_less_than_or_equal_to_0_1 = (relative_errors <= 0.1).sum()

print(f"大于0.1的数量：{count_greater_than_0_1}")
print(f"小于等于0.1的数量：{count_less_than_or_equal_to_0_1}")
print('合格率：', count_less_than_or_equal_to_0_1/(count_less_than_or_equal_to_0_1+count_greater_than_0_1))
# Out:
# 大于0.1的数量：468
# 小于等于0.1的数量：161
# 合格率： 0.2559618441971383
